# %% [markdown]
# # Labeling Sentiment of Annual Filings - Lexicon Method

# %% [markdown]
# ## Import Libraries

# %%
# import necessary libraries
import pandas as pd
import time
import re
import os
import nltk
from nltk.corpus import stopwords
import string

# note: the nltk library will be used for textual preprocessing tasks
# note: the string library will be used to access a punctuation database

# %% [markdown]
# ## Read Dataset to Pandas Dataframe

# %%
# read master_filing_df.csv file into a pandas dataframe
master_filing_df = pd.read_csv('master_filing_df.csv')
# display master_filing_df
display(master_filing_df.head())
# Out:
#     CIK Ticker_Symbol Company_Name   Data_Date Filing_Date Filing_Type  \
# 0  1750           AIR     AAR CORP  2012-05-31  2012-07-19        10-K
# 1  1750           AIR     AAR CORP  2013-05-31  2013-07-26        10-K
# 2  1750           AIR     AAR CORP  2014-05-31  2014-07-17        10-K
# 3  1750           AIR     AAR CORP  2016-05-31  2016-07-13        10-K
# 4  1750           AIR     AAR CORP  2019-05-31  2019-07-18        10-K
#
#   MDA_Placement           File_Name
# 0          10-K  AIR_2012-07-19.txt
# 1          10-K  AIR_2013-07-26.txt
# 2          10-K  AIR_2014-07-17.txt
# 3          10-K  AIR_2016-07-13.txt
# 4          10-K  AIR_2019-07-18.txt

# %% [markdown]
# ## Define Function for Textual Preprocessing

# %%
# note: in order to conduct lexicon-based sentiment analysis with the loughran and mcdonald dictionary
#       the following preprocessing steps are required
#       - tokenize given text into words
#       - removal of stop words
#       - removal of punctuation
#       - convert tokens into lower case word
#       - remove empty spaces that are classed as tokens
#       - remove ' that preceeds any single character or ' or ``

# define preprocessing function
def text_preprocessing(text):
    # tokenize text
    tokenized_text = nltk.word_tokenize(text)
    # remove stop words from 'tokenized_text'
    stop_words = set(stopwords.words('english'))
    tokenized_text = [word for word in tokenized_text if word not in stop_words]
    # remove amy punctuation
    tokenized_text = [word for word in tokenized_text if word not in string.punctuation]
    # convert tokens into lower case
    tokenized_text = [word.lower() for word in tokenized_text]
    # filter empty spaces
    tokenized_text = list(filter(None, tokenized_text))
    # remove ' that preceeds any single character or ' or ``
    tokenized_text = [word for word in tokenized_text if re.sub(r'^(\'([a-z]|\')|``)', '', word)]
    return tokenized_text

# %% [markdown]
# ## Lexicon Model Implementation - Sentiment Analysis

# %%
# note: the loughran and mcdonald lexicon can be used to conduct sentiment analysis on the filing text files
# note: this will be done by counting positive and negative words in each document
# note: the sentiment score for each document will be calculated by subtracting the total number of negative words from positive words
#        and dividing by the sum of the total number of positive words and negative words
# note: the sentiment will be classed as follows:
#       - if sentiment score equal to 0 then sentiment class is neutral
#       - if sentiment score greater than 0 then sentiment class is positive
#       - if sentiment score less than 0 then sentiment class is negative

# store loughran and mcdonald positive and negative word lists in python lists
# note: these are stored in the excel file loughran_mcdonald_dictionary.xlsx
loughran_mcdonald_lexicon = pd.ExcelFile('loughran_mcdonald_dictionary.xlsx')
positive_word_df = pd.read_excel(loughran_mcdonald_lexicon, 'Positive', header=None, names=['Positive_Words'])
negative_word_df = pd.read_excel(loughran_mcdonald_lexicon, 'Negative', header=None, names=['Negative_Words'])
postive_words = positive_word_df['Positive_Words'].to_list()
negative_words = negative_word_df['Negative_Words'].to_list()
positive_words = [word.lower() for word in postive_words]
negative_words = [word.lower() for word in negative_words]

# define function to produce sentiment class
def lexicon_sentiment_class(text, positive_word_list, negative_word_list):
    # define dictionary for positive words
    positive_word_dictionary = {}
    # define dictionary for negative words
    negative_word_dictionary = {}
    
    # loop over words in positive dictionary and text
    for positive_word in positive_word_list:
        count = 0
        for word in text:
            if word==positive_word:
                count += 1
            else:
                continue
        positive_word_dictionary[positive_word] = count
    
    # loop over words in negative dictionary and text
    for negative_word in negative_word_list:
        count = 0
        for word in text:
            if word==negative_word:
                count += 1
            else:
                continue
        negative_word_dictionary[negative_word] = count
    
    # number of positive words in text
    number_of_positive_words = sum(positive_word_dictionary.values())
    # number of negative words in text
    number_of_negative_words = sum(negative_word_dictionary.values())
       
    # sentiment score calculation
    sentiment_score = (number_of_positive_words - number_of_negative_words) / (number_of_positive_words + number_of_negative_words)
    # sentiment classification
    if sentiment_score<=0:
        sentiment_class = 'Negative'
    else:
        sentiment_class = 'Positive'
    
    return number_of_positive_words, number_of_negative_words, sentiment_score, sentiment_class

# %%
# note: change directory path to 'Filing Text Files Folder'
try:
    os.chdir('Filing Text Files')
    print('directory changed')
except:
    print('already in directory!')
# Out:
# directory changed

# %%
# create new column to store the length of each text file
master_filing_df['Text_File_Length'] = ''
# create new column to store the number of positive words in master_filing_df
master_filing_df['No_of_Positive_Words'] = ''
# create new column to store the number if negative words in master_filing_df
master_filing_df['No_of_Negative_Words'] = ''
# create new column to store the sentiment score for given text in master_filing_df
master_filing_df['Sentiment_Score'] = ''
# create new column to store the sentiment class for given sentiment score in master_filing_df
master_filing_df['Sentiment_Class'] = ''

# loop through all files 
for idx, row in master_filing_df.iterrows():
    # open and read text from text file
    file_name = open(row['File_Name'], 'r')
    file_text = file_name.read()
    file_name.close()
    # calculate length of text file 
    master_filing_df.loc[idx, 'Text_File_Length'] = len(file_text)
    # preprocess text file
    preprocessed_file_text = text_preprocessing(file_text)
    # set relevamt variables in master_filing_df to 0 if list contains less than or equal to 250 tokens
    if len(preprocessed_file_text)<=250:
        master_filing_df.loc[idx, 'No_of_Positive_Words'] = 'N/A'
        master_filing_df.loc[idx, 'No_of_Negative_Words'] = 'N/A'
        master_filing_df.loc[idx, 'Sentiment_Score'] = 'N/A'
        master_filing_df.loc[idx, 'Sentiment_Class'] = 'N/A'
    else:
        # lexicon sentiement class function 
        number_of_positive_words, number_of_negative_words, sentiment_score, sentiment_class = lexicon_sentiment_class(preprocessed_file_text, positive_words,
                                                                                                                       negative_words)
        master_filing_df.loc[idx, 'No_of_Positive_Words'] = number_of_positive_words
        master_filing_df.loc[idx, 'No_of_Negative_Words'] = number_of_negative_words
        master_filing_df.loc[idx, 'Sentiment_Score'] = sentiment_score
        master_filing_df.loc[idx, 'Sentiment_Class'] = sentiment_class
    
    # provide user feedback
    print('--------------------------------------------------------------------------')
    print(idx, row['Ticker_Symbol'])
    print('text file length:', master_filing_df.loc[idx, 'Text_File_Length'])
    print('total number of positive words:', master_filing_df.loc[idx, 'No_of_Positive_Words'])
    print('total number of negative words:', master_filing_df.loc[idx, 'No_of_Negative_Words'])
    print('sentiment score:', master_filing_df.loc[idx, 'Sentiment_Score'])
    print('sentiment classification:', master_filing_df.loc[idx, 'Sentiment_Class'])
    print('\n')
# Out:
# --------------------------------------------------------------------------
# 0 AIR
# text file length: 42087
# total number of positive words: 38
# total number of negative words: 71
# sentiment score: -0.30275229357798167
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 1 AIR
# text file length: 35351
# total number of positive words: 38
# total number of negative words: 49
# sentiment score: -0.12643678160919541
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 2 AIR
# text file length: 39449
# total number of positive words: 33
# total number of negative words: 42
# sentiment score: -0.12
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 3 AIR
# text file length: 46544
# total number of positive words: 31
# total number of negative words: 73
# sentiment score: -0.40384615384615385
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 4 AIR
# text file length: 56116
# total number of positive words: 74
# total number of negative words: 98
# sentiment score: -0.13953488372093023
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 5 HES
# text file length: 73488
# total number of positive words: 50
# total number of negative words: 137
# sentiment score: -0.46524064171123
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 6 HES
# text file length: 72301
# total number of positive words: 46
# total number of negative words: 125
# sentiment score: -0.4619883040935672
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 7 HES
# text file length: 77991
# total number of positive words: 45
# total number of negative words: 122
# sentiment score: -0.46107784431137727
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 8 AP
# text file length: 38528
# total number of positive words: 59
# total number of negative words: 90
# sentiment score: -0.2080536912751678
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 9 AP
# text file length: 35558
# total number of positive words: 53
# total number of negative words: 85
# sentiment score: -0.2318840579710145
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 10 AP
# text file length: 37359
# total number of positive words: 70
# total number of negative words: 99
# sentiment score: -0.17159763313609466
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 11 AP
# text file length: 39642
# total number of positive words: 64
# total number of negative words: 93
# sentiment score: -0.18471337579617833
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 12 AP
# text file length: 58806
# total number of positive words: 87
# total number of negative words: 107
# sentiment score: -0.10309278350515463
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 13 AP
# text file length: 34601
# total number of positive words: 49
# total number of negative words: 92
# sentiment score: -0.3049645390070922
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 14 APA
# text file length: 97264
# total number of positive words: 76
# total number of negative words: 127
# sentiment score: -0.2512315270935961
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 15 APA
# text file length: 95766
# total number of positive words: 79
# total number of negative words: 119
# sentiment score: -0.20202020202020202
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 16 SSI
# text file length: 46493
# total number of positive words: 68
# total number of negative words: 62
# sentiment score: 0.046153846153846156
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 17 SSI
# text file length: 42711
# total number of positive words: 57
# total number of negative words: 37
# sentiment score: 0.2127659574468085
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 18 SSI
# text file length: 42303
# total number of positive words: 79
# total number of negative words: 52
# sentiment score: 0.20610687022900764
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 19 SSI
# text file length: 37319
# total number of positive words: 75
# total number of negative words: 54
# sentiment score: 0.16279069767441862
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 20 SSI
# text file length: 24895
# total number of positive words: 22
# total number of negative words: 46
# sentiment score: -0.35294117647058826
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 21 ARW
# text file length: 70485
# total number of positive words: 71
# total number of negative words: 141
# sentiment score: -0.330188679245283
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 22 ARW
# text file length: 68726
# total number of positive words: 69
# total number of negative words: 153
# sentiment score: -0.3783783783783784
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 23 ARW
# text file length: 64869
# total number of positive words: 72
# total number of negative words: 123
# sentiment score: -0.26153846153846155
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 24 ESTE
# text file length: 62189
# total number of positive words: 43
# total number of negative words: 151
# sentiment score: -0.5567010309278351
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 25 ESTE
# text file length: 42724
# total number of positive words: 28
# total number of negative words: 88
# sentiment score: -0.5172413793103449
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 26 BGG
# text file length: 50684
# total number of positive words: 43
# total number of negative words: 101
# sentiment score: -0.4027777777777778
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 27 CAL
# text file length: 85392
# total number of positive words: 92
# total number of negative words: 181
# sentiment score: -0.326007326007326
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 28 CBT
# text file length: 83944
# total number of positive words: 125
# total number of negative words: 184
# sentiment score: -0.19093851132686085
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 29 CBT
# text file length: 81824
# total number of positive words: 96
# total number of negative words: 155
# sentiment score: -0.2350597609561753
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 30 CACI
# text file length: 37691
# total number of positive words: 19
# total number of negative words: 41
# sentiment score: -0.36666666666666664
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 31 CACI
# text file length: 36340
# total number of positive words: 22
# total number of negative words: 26
# sentiment score: -0.08333333333333333
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 32 CACI
# text file length: 31993
# total number of positive words: 15
# total number of negative words: 27
# sentiment score: -0.2857142857142857
# sentiment classification: Negative
# --------------------------------------------------------------------------
# 33 LUB
# text file length: 89274
# total number of positive words: 118
# total number of negative words: 193
# sentiment score: -0.24115755627009647
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 34 LUB
# text file length: 91178
# total number of positive words: 131
# total number of negative words: 177
# sentiment score: -0.14935064935064934
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 35 LUB
# text file length: 105456
# total number of positive words: 134
# total number of negative words: 192
# sentiment score: -0.17791411042944785
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 36 LUB
# text file length: 91508
# total number of positive words: 108
# total number of negative words: 172
# sentiment score: -0.22857142857142856
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 37 LUB
# text file length: 90452
# total number of positive words: 118
# total number of negative words: 170
# sentiment score: -0.18055555555555555
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 38 CATO
# text file length: 30585
# total number of positive words: 15
# total number of negative words: 69
# sentiment score: -0.6428571428571429
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 39 CATO
# text file length: 33677
# total number of positive words: 16
# total number of negative words: 76
# sentiment score: -0.6521739130434783
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 40 GCO
# text file length: 102148
# total number of positive words: 123
# total number of negative words: 216
# sentiment score: -0.2743362831858407
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 41 GCO
# text file length: 93183
# total number of positive words: 109
# total number of negative words: 236
# sentiment score: -0.3681159420289855
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 42 CSS
# text file length: 36480
# total number of positive words: 20
# total number of negative words: 88
# sentiment score: -0.6296296296296297
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 43 CSS
# text file length: 41254
# total number of positive words: 21
# total number of negative words: 82
# sentiment score: -0.5922330097087378
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 44 CSS
# text file length: 43343
# total number of positive words: 29
# total number of negative words: 82
# sentiment score: -0.4774774774774775
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 45 CSS
# text file length: 41133
# total number of positive words: 22
# total number of negative words: 73
# sentiment score: -0.5368421052631579
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 46 CSS
# text file length: 37643
# total number of positive words: 19
# total number of negative words: 61
# sentiment score: -0.525
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 47 CSS
# text file length: 42796
# total number of positive words: 24
# total number of negative words: 66
# sentiment score: -0.4666666666666667
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 48 CSS
# text file length: 50387
# total number of positive words: 40
# total number of negative words: 94
# sentiment score: -0.40298507462686567
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 49 CMC
# text file length: 56628
# total number of positive words: 69
# total number of negative words: 187
# sentiment score: -0.4609375
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 50 CMC
# text file length: 59506
# total number of positive words: 80
# total number of negative words: 170
# sentiment score: -0.36
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 51 TAP
# text file length: 111549
# total number of positive words: 192
# total number of negative words: 179
# sentiment score: 0.03504043126684636
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 52 TAP
# text file length: 135612
# total number of positive words: 222
# total number of negative words: 239
# sentiment score: -0.0368763557483731
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 53 TAP
# text file length: 143741
# total number of positive words: 205
# total number of negative words: 282
# sentiment score: -0.15811088295687886
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 54 TAP
# text file length: 130724
# total number of positive words: 197
# total number of negative words: 217
# sentiment score: -0.04830917874396135
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 55 GLW
# text file length: 107396
# total number of positive words: 154
# total number of negative words: 292
# sentiment score: -0.3094170403587444
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 56 GLW
# text file length: 134877
# total number of positive words: 165
# total number of negative words: 334
# sentiment score: -0.33867735470941884
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 57 DAN
# text file length: 74856
# total number of positive words: 164
# total number of negative words: 140
# sentiment score: 0.07894736842105263
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 58 DDS
# text file length: 54342
# total number of positive words: 53
# total number of negative words: 109
# sentiment score: -0.345679012345679
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 59 DCO
# text file length: 51763
# total number of positive words: 29
# total number of negative words: 122
# sentiment score: -0.6158940397350994
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 60 DCO
# text file length: 47472
# total number of positive words: 25
# total number of negative words: 103
# sentiment score: -0.609375
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 61 DCO
# text file length: 51397
# total number of positive words: 49
# total number of negative words: 117
# sentiment score: -0.40963855421686746
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 62 KODK
# text file length: 94777
# total number of positive words: 138
# total number of negative words: 219
# sentiment score: -0.226890756302521
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 63 KODK
# text file length: 73171
# total number of positive words: 101
# total number of negative words: 167
# sentiment score: -0.2462686567164179
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 64 EBF
# text file length: 44074
# total number of positive words: 68
# total number of negative words: 99
# sentiment score: -0.18562874251497005
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 65 EBF
# text file length: 48767
# total number of positive words: 70
# total number of negative words: 106
# sentiment score: -0.20454545454545456
# sentiment classification: Negative
# --------------------------------------------------------------------------
# 66 EBF
# text file length: 44561
# total number of positive words: 54
# total number of negative words: 91
# sentiment score: -0.25517241379310346
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 67 EBF
# text file length: 54651
# total number of positive words: 75
# total number of negative words: 122
# sentiment score: -0.23857868020304568
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 68 FOE
# text file length: 71593
# total number of positive words: 71
# total number of negative words: 201
# sentiment score: -0.47794117647058826
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 69 GLT
# text file length: 40106
# total number of positive words: 40
# total number of negative words: 71
# sentiment score: -0.27927927927927926
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 70 GTN
# text file length: 73545
# total number of positive words: 63
# total number of negative words: 97
# sentiment score: -0.2125
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 71 GTN
# text file length: 73211
# total number of positive words: 62
# total number of negative words: 86
# sentiment score: -0.16216216216216217
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 72 GTN
# text file length: 63060
# total number of positive words: 62
# total number of negative words: 65
# sentiment score: -0.023622047244094488
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 73 HHS
# text file length: 66506
# total number of positive words: 68
# total number of negative words: 169
# sentiment score: -0.42616033755274263
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 74 AXE
# text file length: 59192
# total number of positive words: 96
# total number of negative words: 96
# sentiment score: 0.0
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 75 KFY
# text file length: 89718
# total number of positive words: 88
# total number of negative words: 134
# sentiment score: -0.2072072072072072
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 76 LCI
# text file length: 59616
# total number of positive words: 67
# total number of negative words: 83
# sentiment score: -0.10666666666666667
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 77 LCI
# text file length: 74231
# total number of positive words: 60
# total number of negative words: 131
# sentiment score: -0.3717277486910995
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 78 LCI
# text file length: 75813
# total number of positive words: 60
# total number of negative words: 155
# sentiment score: -0.4418604651162791
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 79 LPX
# text file length: 69903
# total number of positive words: 68
# total number of negative words: 167
# sentiment score: -0.42127659574468085
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 80 LXU
# text file length: 105659
# total number of positive words: 94
# total number of negative words: 244
# sentiment score: -0.4437869822485207
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 81 LXU
# text file length: 74136
# total number of positive words: 54
# total number of negative words: 156
# sentiment score: -0.4857142857142857
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 82 LXU
# text file length: 66775
# total number of positive words: 84
# total number of negative words: 122
# sentiment score: -0.18446601941747573
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 83 LXU
# text file length: 64834
# total number of positive words: 99
# total number of negative words: 104
# sentiment score: -0.024630541871921183
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 84 LDL
# text file length: 71578
# total number of positive words: 114
# total number of negative words: 96
# sentiment score: 0.08571428571428572
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 85 MTW
# text file length: 64517
# total number of positive words: 57
# total number of negative words: 161
# sentiment score: -0.47706422018348627
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 86 MCS
# text file length: 83212
# total number of positive words: 160
# total number of negative words: 149
# sentiment score: 0.03559870550161812
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 87 MCS
# text file length: 105624
# total number of positive words: 163
# total number of negative words: 122
# sentiment score: 0.14385964912280702
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 88 THC
# text file length: 279059
# total number of positive words: 202
# total number of negative words: 542
# sentiment score: -0.45698924731182794
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 89 THC
# text file length: 255714
# total number of positive words: 194
# total number of negative words: 518
# sentiment score: -0.4550561797752809
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 90 GPX
# text file length: 86920
# total number of positive words: 120
# total number of negative words: 101
# sentiment score: 0.08597285067873303
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 91 NR
# text file length: 67898
# total number of positive words: 61
# total number of negative words: 185
# sentiment score: -0.5040650406504065
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 92 NBL
# text file length: 90681
# total number of positive words: 84
# total number of negative words: 156
# sentiment score: -0.3
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 93 MOV
# text file length: 71849
# total number of positive words: 71
# total number of negative words: 196
# sentiment score: -0.4681647940074906
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 94 MOV
# text file length: 67729
# total number of positive words: 76
# total number of negative words: 151
# sentiment score: -0.3303964757709251
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 95 OII
# text file length: 58943
# total number of positive words: 87
# total number of negative words: 96
# sentiment score: -0.04918032786885246
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 96 OLN
# text file length: 119895
# total number of positive words: 150
# total number of negative words: 245
# sentiment score: -0.24050632911392406
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 97 OSG
# text file length: 146466
# total number of positive words: 94
# total number of negative words: 324
# sentiment score: -0.5502392344497608
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 98 OSG
# text file length: 132823
# total number of positive words: 73
# total number of negative words: 309
# sentiment score: -0.6178010471204188
# sentiment classification: Negative
# --------------------------------------------------------------------------
# 99 OSG
# text file length: 113521
# total number of positive words: 109
# total number of negative words: 198
# sentiment score: -0.2899022801302932
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 100 OSG
# text file length: 84062
# total number of positive words: 87
# total number of negative words: 164
# sentiment score: -0.30677290836653387
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 101 OSG
# text file length: 48954
# total number of positive words: 54
# total number of negative words: 70
# sentiment score: -0.12903225806451613
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 102 OMI
# text file length: 34833
# total number of positive words: 28
# total number of negative words: 62
# sentiment score: -0.37777777777777777
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 103 OMI
# text file length: 37400
# total number of positive words: 31
# total number of negative words: 72
# sentiment score: -0.39805825242718446
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 104 PKD
# text file length: 67354
# total number of positive words: 71
# total number of negative words: 94
# sentiment score: -0.1393939393939394
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 105 PKD
# text file length: 66464
# total number of positive words: 61
# total number of negative words: 144
# sentiment score: -0.40487804878048783
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 106 TPC
# text file length: 77887
# total number of positive words: 75
# total number of negative words: 160
# sentiment score: -0.3617021276595745
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 107 TPC
# text file length: 98129
# total number of positive words: 67
# total number of negative words: 247
# sentiment score: -0.5732484076433121
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 108 TPC
# text file length: 92980
# total number of positive words: 74
# total number of negative words: 200
# sentiment score: -0.45985401459854014
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 109 TPC
# text file length: 101523
# total number of positive words: 69
# total number of negative words: 171
# sentiment score: -0.425
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 110 LUV
# text file length: 103921
# total number of positive words: 99
# total number of negative words: 133
# sentiment score: -0.14655172413793102
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 111 LUV
# text file length: 116967
# total number of positive words: 108
# total number of negative words: 146
# sentiment score: -0.14960629921259844
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 112 SUP
# text file length: 64321
# total number of positive words: 72
# total number of negative words: 149
# sentiment score: -0.34841628959276016
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 113 SUP
# text file length: 69148
# total number of positive words: 80
# total number of negative words: 113
# sentiment score: -0.17098445595854922
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 114 SUP
# text file length: 70606
# total number of positive words: 100
# total number of negative words: 109
# sentiment score: -0.0430622009569378
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 115 SUP
# text file length: 92268
# total number of positive words: 109
# total number of negative words: 153
# sentiment score: -0.16793893129770993
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 116 SUP
# text file length: 92000
# total number of positive words: 101
# total number of negative words: 158
# sentiment score: -0.22007722007722008
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 117 SUP
# text file length: 79232
# total number of positive words: 92
# total number of negative words: 127
# sentiment score: -0.1598173515981735
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 118 SUP
# text file length: 38223
# total number of positive words: 41
# total number of negative words: 59
# sentiment score: -0.18
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 119 TEX
# text file length: 86000
# total number of positive words: 119
# total number of negative words: 206
# sentiment score: -0.2676923076923077
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 120 TMO
# text file length: 68829
# total number of positive words: 97
# total number of negative words: 172
# sentiment score: -0.2788104089219331
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 121 TSN
# text file length: 61933
# total number of positive words: 108
# total number of negative words: 158
# sentiment score: -0.18796992481203006
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 122 TSN
# text file length: 59645
# total number of positive words: 94
# total number of negative words: 129
# sentiment score: -0.15695067264573992
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 123 UFI
# text file length: 83901
# total number of positive words: 127
# total number of negative words: 180
# sentiment score: -0.17263843648208468
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 124 UFI
# text file length: 66438
# total number of positive words: 85
# total number of negative words: 133
# sentiment score: -0.22018348623853212
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 125 UFI
# text file length: 81770
# total number of positive words: 110
# total number of negative words: 158
# sentiment score: -0.1791044776119403
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 126 MRO
# text file length: 86140
# total number of positive words: 74
# total number of negative words: 147
# sentiment score: -0.33031674208144796
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 127 MRO
# text file length: 81776
# total number of positive words: 66
# total number of negative words: 128
# sentiment score: -0.31958762886597936
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 128 S
# text file length: 105958
# total number of positive words: 118
# total number of negative words: 240
# sentiment score: -0.3407821229050279
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 129 S
# text file length: 172983
# total number of positive words: 128
# total number of negative words: 257
# sentiment score: -0.33506493506493507
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 130 S
# text file length: 169629
# total number of positive words: 137
# total number of negative words: 225
# sentiment score: -0.2430939226519337
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 131 S
# text file length: 129506
# total number of positive words: 111
# total number of negative words: 179
# sentiment score: -0.23448275862068965
# sentiment classification: Negative
# --------------------------------------------------------------------------
# 132 S
# text file length: 136183
# total number of positive words: 115
# total number of negative words: 200
# sentiment score: -0.2698412698412698
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 133 UVV
# text file length: 71170
# total number of positive words: 127
# total number of negative words: 114
# sentiment score: 0.05394190871369295
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 134 UVV
# text file length: 67516
# total number of positive words: 129
# total number of negative words: 105
# sentiment score: 0.10256410256410256
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 135 UVV
# text file length: 70088
# total number of positive words: 141
# total number of negative words: 116
# sentiment score: 0.09727626459143969
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 136 UVV
# text file length: 77895
# total number of positive words: 168
# total number of negative words: 108
# sentiment score: 0.21739130434782608
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 137 UVV
# text file length: 74401
# total number of positive words: 156
# total number of negative words: 108
# sentiment score: 0.18181818181818182
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 138 UVV
# text file length: 82655
# total number of positive words: 200
# total number of negative words: 94
# sentiment score: 0.36054421768707484
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 139 UVV
# text file length: 82724
# total number of positive words: 196
# total number of negative words: 94
# sentiment score: 0.35172413793103446
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 140 VSH
# text file length: 86297
# total number of positive words: 119
# total number of negative words: 134
# sentiment score: -0.05928853754940711
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 141 VSH
# text file length: 86040
# total number of positive words: 118
# total number of negative words: 129
# sentiment score: -0.044534412955465584
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 142 VSH
# text file length: 95761
# total number of positive words: 124
# total number of negative words: 111
# sentiment score: 0.05531914893617021
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 143 VSH
# text file length: 103276
# total number of positive words: 132
# total number of negative words: 215
# sentiment score: -0.23919308357348704
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 144 GHC
# text file length: 363
# total number of positive words: N/A
# total number of negative words: N/A
# sentiment score: N/A
# sentiment classification: N/A
#
#
# --------------------------------------------------------------------------
# 145 AVA
# text file length: 134893
# total number of positive words: 115
# total number of negative words: 160
# sentiment score: -0.16363636363636364
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 146 AVA
# text file length: 140530
# total number of positive words: 119
# total number of negative words: 162
# sentiment score: -0.15302491103202848
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 147 CDE
# text file length: 69765
# total number of positive words: 41
# total number of negative words: 113
# sentiment score: -0.4675324675324675
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 148 CDE
# text file length: 44744
# total number of positive words: 35
# total number of negative words: 66
# sentiment score: -0.3069306930693069
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 149 CDE
# text file length: 51218
# total number of positive words: 47
# total number of negative words: 66
# sentiment score: -0.168141592920354
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 150 CDE
# text file length: 68433
# total number of positive words: 67
# total number of negative words: 87
# sentiment score: -0.12987012987012986
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 151 HVT
# text file length: 35872
# total number of positive words: 72
# total number of negative words: 60
# sentiment score: 0.09090909090909091
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 152 PIR
# text file length: 52967
# total number of positive words: 55
# total number of negative words: 58
# sentiment score: -0.02654867256637168
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 153 KEG
# text file length: 72531
# total number of positive words: 80
# total number of negative words: 121
# sentiment score: -0.20398009950248755
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 154 AN
# text file length: 73760
# total number of positive words: 75
# total number of negative words: 184
# sentiment score: -0.42084942084942084
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 155 SBOW
# text file length: 30816
# total number of positive words: 28
# total number of negative words: 50
# sentiment score: -0.28205128205128205
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 156 SBOW
# text file length: 34544
# total number of positive words: 45
# total number of negative words: 34
# sentiment score: 0.13924050632911392
# sentiment classification: Positive
#
#
# --------------------------------------------------------------------------
# 157 MDR
# text file length: 141656
# total number of positive words: 189
# total number of negative words: 271
# sentiment score: -0.1782608695652174
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 158 PAR
# text file length: 48870
# total number of positive words: 52
# total number of negative words: 93
# sentiment score: -0.2827586206896552
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 159 PAR
# text file length: 40433
# total number of positive words: 35
# total number of negative words: 74
# sentiment score: -0.3577981651376147
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 160 PAR
# text file length: 39181
# total number of positive words: 35
# total number of negative words: 56
# sentiment score: -0.23076923076923078
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 161 ACCO
# text file length: 70119
# total number of positive words: 78
# total number of negative words: 103
# sentiment score: -0.13812154696132597
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 162 RGS
# text file length: 53394
# total number of positive words: 26
# total number of negative words: 156
# sentiment score: -0.7142857142857143
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 163 TRCO
# text file length: 143576
# total number of positive words: 148
# total number of negative words: 304
# sentiment score: -0.34513274336283184
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 164 ATGE
# text file length: 128694
# total number of positive words: 153
# total number of negative words: 308
# sentiment score: -0.3362255965292842
# sentiment classification: Negative
# --------------------------------------------------------------------------
# 165 ATGE
# text file length: 131128
# total number of positive words: 124
# total number of negative words: 308
# sentiment score: -0.42592592592592593
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 166 IVC
# text file length: 87673
# total number of positive words: 127
# total number of negative words: 218
# sentiment score: -0.263768115942029
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 167 REX
# text file length: 94937
# total number of positive words: 94
# total number of negative words: 200
# sentiment score: -0.36054421768707484
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 168 REX
# text file length: 52651
# total number of positive words: 59
# total number of negative words: 117
# sentiment score: -0.32954545454545453
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 169 REX
# text file length: 45973
# total number of positive words: 47
# total number of negative words: 101
# sentiment score: -0.36486486486486486
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 170 CLF
# text file length: 137416
# total number of positive words: 118
# total number of negative words: 320
# sentiment score: -0.4611872146118721
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 171 OSK
# text file length: 94196
# total number of positive words: 114
# total number of negative words: 206
# sentiment score: -0.2875
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 172 CRY
# text file length: 81784
# total number of positive words: 60
# total number of negative words: 128
# sentiment score: -0.3617021276595745
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 173 POR
# text file length: 81545
# total number of positive words: 52
# total number of negative words: 114
# sentiment score: -0.37349397590361444
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 174 POR
# text file length: 81113
# total number of positive words: 60
# total number of negative words: 91
# sentiment score: -0.2052980132450331
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 175 INT
# text file length: 56268
# total number of positive words: 66
# total number of negative words: 106
# sentiment score: -0.23255813953488372
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 176 INT
# text file length: 51686
# total number of positive words: 77
# total number of negative words: 101
# sentiment score: -0.1348314606741573
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 177 MGM
# text file length: 62465
# total number of positive words: 66
# total number of negative words: 79
# sentiment score: -0.0896551724137931
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 178 UNT
# text file length: 97619
# total number of positive words: 65
# total number of negative words: 142
# sentiment score: -0.3719806763285024
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 179 UNT
# text file length: 102008
# total number of positive words: 50
# total number of negative words: 160
# sentiment score: -0.5238095238095238
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 180 UNT
# text file length: 101435
# total number of positive words: 67
# total number of negative words: 141
# sentiment score: -0.3557692307692308
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 181 USM
# text file length: 284
# total number of positive words: N/A
# total number of negative words: N/A
# sentiment score: N/A
# sentiment classification: N/A
#
#
# --------------------------------------------------------------------------
# 182 USM
# text file length: 285
# total number of positive words: N/A
# total number of negative words: N/A
# sentiment score: N/A
# sentiment classification: N/A
#
#
# --------------------------------------------------------------------------
# 183 ELY
# text file length: 77304
# total number of positive words: 83
# total number of negative words: 175
# sentiment score: -0.35658914728682173
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 184 MHK
# text file length: 53290
# total number of positive words: 87
# total number of negative words: 127
# sentiment score: -0.18691588785046728
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 185 CGA
# text file length: 50118
# total number of positive words: 29
# total number of negative words: 52
# sentiment score: -0.2839506172839506
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 186 CGA
# text file length: 44832
# total number of positive words: 25
# total number of negative words: 49
# sentiment score: -0.32432432432432434
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 187 CGA
# text file length: 49096
# total number of positive words: 37
# total number of negative words: 37
# sentiment score: 0.0
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 188 CGA
# text file length: 40865
# total number of positive words: 19
# total number of negative words: 43
# sentiment score: -0.3870967741935484
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 189 CGA
# text file length: 42409
# total number of positive words: 17
# total number of negative words: 45
# sentiment score: -0.45161290322580644
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 190 CGA
# text file length: 43167
# total number of positive words: 16
# total number of negative words: 50
# sentiment score: -0.5151515151515151
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 191 AVX
# text file length: 63724
# ...
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 798 TRQ
# text file length: 207261
# total number of positive words: 166
# total number of negative words: 631
# sentiment score: -0.5834378920953576
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 799 TRQ
# text file length: 179561
# total number of positive words: 172
# total number of negative words: 480
# sentiment score: -0.4723926380368098
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 800 TRQ
# text file length: 158240
# total number of positive words: 121
# total number of negative words: 403
# sentiment score: -0.5381679389312977
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 801 TRQ
# text file length: 155630
# total number of positive words: 117
# total number of negative words: 398
# sentiment score: -0.545631067961165
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 802 TRQ
# text file length: 164871
# total number of positive words: 145
# total number of negative words: 463
# sentiment score: -0.5230263157894737
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 803 TRQ
# text file length: 167619
# total number of positive words: 144
# total number of negative words: 471
# sentiment score: -0.5317073170731708
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 804 AQN
# text file length: 230493
# total number of positive words: 120
# total number of negative words: 228
# sentiment score: -0.3103448275862069
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 805 AQN
# text file length: 231245
# total number of positive words: 148
# total number of negative words: 256
# sentiment score: -0.26732673267326734
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 806 AQN
# text file length: 215889
# total number of positive words: 202
# total number of negative words: 318
# sentiment score: -0.2230769230769231
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 807 AQN
# text file length: 228806
# total number of positive words: 207
# total number of negative words: 356
# sentiment score: -0.26465364120781526
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 808 IAG
# text file length: 134899
# total number of positive words: 141
# total number of negative words: 208
# sentiment score: -0.19197707736389685
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 809 IAG
# text file length: 141778
# total number of positive words: 132
# total number of negative words: 234
# sentiment score: -0.2786885245901639
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 810 IAG
# text file length: 145897
# total number of positive words: 155
# total number of negative words: 279
# sentiment score: -0.2857142857142857
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 811 IAG
# text file length: 159163
# total number of positive words: 155
# total number of negative words: 455
# sentiment score: -0.4918032786885246
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 812 IAG
# text file length: 191671
# total number of positive words: 173
# total number of negative words: 581
# sentiment score: -0.5411140583554377
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 813 IAG
# text file length: 223506
# total number of positive words: 223
# total number of negative words: 705
# sentiment score: -0.5193965517241379
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 814 IAG
# text file length: 151773
# total number of positive words: 142
# total number of negative words: 144
# sentiment score: -0.006993006993006993
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 815 AUY
# text file length: 186028
# total number of positive words: 150
# total number of negative words: 371
# sentiment score: -0.42418426103646834
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 816 AUY
# text file length: 254071
# total number of positive words: 265
# total number of negative words: 643
# sentiment score: -0.41629955947136565
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 817 AUY
# text file length: 191957
# total number of positive words: 186
# total number of negative words: 313
# sentiment score: -0.2545090180360721
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 818 AUY
# text file length: 256463
# total number of positive words: 283
# total number of negative words: 402
# sentiment score: -0.17372262773722627
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 819 AUY
# text file length: 165630
# total number of positive words: 181
# total number of negative words: 228
# sentiment score: -0.11491442542787286
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 820 AUY
# text file length: 161847
# total number of positive words: 195
# total number of negative words: 259
# sentiment score: -0.14096916299559473
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 821 EXK
# text file length: 160648
# total number of positive words: 138
# total number of negative words: 343
# sentiment score: -0.4261954261954262
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 822 AG
# text file length: 115558
# total number of positive words: 109
# total number of negative words: 202
# sentiment score: -0.2990353697749196
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 823 AG
# text file length: 118520
# total number of positive words: 74
# total number of negative words: 247
# sentiment score: -0.5389408099688473
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 824 HBM
# text file length: 125703
# total number of positive words: 102
# total number of negative words: 146
# sentiment score: -0.1774193548387097
# sentiment classification: Negative
# --------------------------------------------------------------------------
# 825 HBM
# text file length: 136805
# total number of positive words: 134
# total number of negative words: 253
# sentiment score: -0.30749354005167956
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 826 HBM
# text file length: 146176
# total number of positive words: 123
# total number of negative words: 278
# sentiment score: -0.3865336658354115
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 827 HBM
# text file length: 124452
# total number of positive words: 117
# total number of negative words: 211
# sentiment score: -0.2865853658536585
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 828 HBM
# text file length: 140626
# total number of positive words: 162
# total number of negative words: 250
# sentiment score: -0.21359223300970873
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 829 HBM
# text file length: 108512
# total number of positive words: 117
# total number of negative words: 164
# sentiment score: -0.16725978647686832
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 830 HBM
# text file length: 106451
# total number of positive words: 104
# total number of negative words: 137
# sentiment score: -0.13692946058091288
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 831 HBM
# text file length: 120049
# total number of positive words: 112
# total number of negative words: 125
# sentiment score: -0.05485232067510549
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 832 WPM
# text file length: 380330
# total number of positive words: 174
# total number of negative words: 741
# sentiment score: -0.6196721311475409
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 833 OBE
# text file length: 76345
# total number of positive words: 79
# total number of negative words: 138
# sentiment score: -0.271889400921659
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 834 OBE
# text file length: 66615
# total number of positive words: 73
# total number of negative words: 111
# sentiment score: -0.20652173913043478
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 835 OBE
# text file length: 69660
# total number of positive words: 80
# total number of negative words: 146
# sentiment score: -0.2920353982300885
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 836 OBE
# text file length: 74209
# total number of positive words: 86
# total number of negative words: 216
# sentiment score: -0.4304635761589404
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 837 OBE
# text file length: 76104
# total number of positive words: 86
# total number of negative words: 201
# sentiment score: -0.40069686411149824
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 838 OBE
# text file length: 69848
# total number of positive words: 83
# total number of negative words: 170
# sentiment score: -0.3438735177865613
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 839 OBE
# text file length: 64439
# total number of positive words: 76
# total number of negative words: 153
# sentiment score: -0.33624454148471616
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 840 OBE
# text file length: 66388
# total number of positive words: 57
# total number of negative words: 158
# sentiment score: -0.4697674418604651
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 841 FSM
# text file length: 101490
# total number of positive words: 53
# total number of negative words: 197
# sentiment score: -0.576
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 842 FSM
# text file length: 126796
# total number of positive words: 66
# total number of negative words: 275
# sentiment score: -0.6129032258064516
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 843 NOA
# text file length: 111277
# total number of positive words: 132
# total number of negative words: 247
# sentiment score: -0.3034300791556728
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 844 NOA
# text file length: 118388
# total number of positive words: 185
# total number of negative words: 226
# sentiment score: -0.09975669099756691
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 845 NOA
# text file length: 129059
# total number of positive words: 207
# total number of negative words: 259
# sentiment score: -0.11158798283261803
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 846 NOA
# text file length: 128613
# total number of positive words: 173
# total number of negative words: 227
# sentiment score: -0.135
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 847 CVE
# text file length: 314323
# total number of positive words: 333
# total number of negative words: 737
# sentiment score: -0.3775700934579439
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 848 CVE
# text file length: 267969
# total number of positive words: 332
# total number of negative words: 682
# sentiment score: -0.34516765285996054
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 849 CPG
# text file length: 78778
# total number of positive words: 90
# total number of negative words: 176
# sentiment score: -0.3233082706766917
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 850 CPG
# text file length: 83100
# total number of positive words: 103
# total number of negative words: 162
# sentiment score: -0.22264150943396227
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 851 CPG
# text file length: 83867
# total number of positive words: 105
# total number of negative words: 167
# sentiment score: -0.22794117647058823
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 852 CPG
# text file length: 82642
# total number of positive words: 103
# total number of negative words: 144
# sentiment score: -0.1659919028340081
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 853 CPG
# text file length: 86384
# total number of positive words: 95
# total number of negative words: 189
# sentiment score: -0.33098591549295775
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 854 OR
# text file length: 100833
# total number of positive words: 64
# total number of negative words: 143
# sentiment score: -0.38164251207729466
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 855 OR
# text file length: 142340
# total number of positive words: 84
# total number of negative words: 189
# sentiment score: -0.38461538461538464
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 856 OR
# text file length: 159244
# total number of positive words: 109
# total number of negative words: 232
# sentiment score: -0.36070381231671556
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 857 FTS
# text file length: 252717
# total number of positive words: 255
# total number of negative words: 511
# sentiment score: -0.3342036553524804
# sentiment classification: Negative
# --------------------------------------------------------------------------
# 858 FTS
# text file length: 231287
# total number of positive words: 227
# total number of negative words: 466
# sentiment score: -0.3448773448773449
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 859 FTS
# text file length: 190951
# total number of positive words: 227
# total number of negative words: 447
# sentiment score: -0.3264094955489614
# sentiment classification: Negative
#
#
# --------------------------------------------------------------------------
# 860 NTR
# text file length: 172212
# total number of positive words: 314
# total number of negative words: 294
# sentiment score: 0.03289473684210526
# sentiment classification: Positive

# %% [markdown]
# ## Portfolio Analysis and Feasibility Check

# %%
# note: a feasibility study is necessary to see whether this lexicon method of labeling the sentiment of
#       the text files differentiates good investments from bad ones
#       the returns of each stock will be analyzed using the stock_price_df_copy.csv file

# go back to prototype two notebooks folder
# note: change directory path to 'Filing Text Files Folder'
os.chdir('..')

# read stock_price_df_copy.csv into a pandas dataframe
stock_price_df = pd.read_csv('stock_price_df_copy.csv')

# find the number of positive negative text, N/A files
number_of_positive_files = master_filing_df.query('Sentiment_Class=="Positive"').shape[0]
number_of_negative_files = master_filing_df.query('Sentiment_Class=="Negative"').shape[0]
number_of_na_files = master_filing_df.query('Sentiment_Class=="N/A"').shape[0]

# %%
# create a new dataframe to store returns for stocks in master_filing_df
# note: this dataframe will not include 'N/A' observations
lexicon_returns_df = master_filing_df.query('Sentiment_Class!="N/A"').reset_index(drop=True)

# create a new column to store the F-SCORE 
lexicon_returns_df['F_SCORE'] = 0

# create a new column to store long holding period return
lexicon_returns_df['Long_Holding_Period_Return_(%)'] = 0
# create a new column to store short holding period return
lexicon_returns_df['Short_Holding_Period_Return_(%)'] = 0
# create a new column to store annualized long holding period return
lexicon_returns_df['Long_Annualized_Holding_Period_Return_(%)'] = 0
# create a new column to store annualized short holding period return
lexicon_returns_df['Short_Annualized_Holding_Period_Return_(%)'] = 0
# create a new column to store long excess reurns
lexicon_returns_df['Long_Excess_Returns_(%)'] = 0 
# create a new column to store short excess reurns
lexicon_returns_df['Short_Excess_Returns_(%)'] = 0 

# get returns from stock_price_df
for idx, row in lexicon_returns_df.iterrows():
    for idx_a, row_a in stock_price_df.iterrows():
        if row['Data_Date']==row_a['Data_Date'] and row['Ticker_Symbol']==row_a['Ticker_Symbol']:
            lexicon_returns_df.loc[idx, 'F_SCORE'] = row_a['F_SCORE']
            lexicon_returns_df.loc[idx, 'Long_Holding_Period_Return_(%)'] = row_a['Long_Holding_Period_Return_(%)']
            lexicon_returns_df.loc[idx, 'Short_Holding_Period_Return_(%)'] = row_a['Short_Holding_Period_Return_(%)']
            lexicon_returns_df.loc[idx, 'Long_Annualized_Holding_Period_Return_(%)'] = row_a['Long_Annualized_Holding_Period_Return_(%)']
            lexicon_returns_df.loc[idx, 'Short_Annualized_Holding_Period_Return_(%)'] = row_a['Short_Annualized_Holding_Period_Return_(%)']
            lexicon_returns_df.loc[idx, 'Long_Excess_Returns_(%)'] = row_a['Long_Excess_Returns_(%)']
            lexicon_returns_df.loc[idx, 'Short_Excess_Returns_(%)'] = row_a['Short_Excess_Returns_(%)']
        else:
            continue

# %%
# check if any return columns in lexicon_returns_df has nan values
# if there are any nan values, drop row from lexicon_returns_df

# check if there are any nan values
print('number of nan values in lexicon_returns_df:', lexicon_returns_df.isnull().sum().sum())
# drop rows containing nan values
lexicon_returns_df = lexicon_returns_df.dropna()
# Out:
# number of nan values in lexicon_returns_df: 6

# %%
# note: various portfolio formations will be analyzed to identify the best combination of stocks
# note: a function will be defined to calculate various statistics of the various portfolios

def portfolio_analysis_statistics(portfolio_df):
    # mean of returns
    average_long_hpr = portfolio_df['Long_Holding_Period_Return_(%)'].mean()
    average_short_hpr = portfolio_df['Short_Holding_Period_Return_(%)'].mean()
    average_long_annaulized_hpr = portfolio_df['Long_Annualized_Holding_Period_Return_(%)'].mean()
    average_short_annaulized_hpr = portfolio_df['Short_Annualized_Holding_Period_Return_(%)'].mean()
    average_long_excess_returns = portfolio_df['Long_Excess_Returns_(%)'].mean()
    average_short_excess_returns = portfolio_df['Short_Excess_Returns_(%)'].mean()
    # median returns
    median_long_hpr = portfolio_df['Long_Holding_Period_Return_(%)'].median()
    median_short_hpr = portfolio_df['Short_Holding_Period_Return_(%)'].median()
    median_long_annaulized_hpr = portfolio_df['Long_Annualized_Holding_Period_Return_(%)'].median()
    median_short_annaulized_hpr = portfolio_df['Short_Annualized_Holding_Period_Return_(%)'].median()
    median_long_excess_returns = portfolio_df['Long_Excess_Returns_(%)'].median()
    median_short_excess_returns = portfolio_df['Short_Excess_Returns_(%)'].median()
    # 10th percentile returns
    percentile_10_long_hpr = portfolio_df['Long_Holding_Period_Return_(%)'].quantile(0.1)
    percentile_10_short_hpr = portfolio_df['Short_Holding_Period_Return_(%)'].quantile(0.1)
    percentile_10_long_annaulized_hpr = portfolio_df['Long_Annualized_Holding_Period_Return_(%)'].quantile(0.1)
    percentile_10_short_annaulized_hpr = portfolio_df['Short_Annualized_Holding_Period_Return_(%)'].quantile(0.1)
    percentile_10_long_excess_returns = portfolio_df['Long_Excess_Returns_(%)'].quantile(0.1)
    percentile_10_short_excess_returns = portfolio_df['Short_Excess_Returns_(%)'].quantile(0.1)
    # 25th percentile returns 
    percentile_25_long_hpr = portfolio_df['Long_Holding_Period_Return_(%)'].quantile(0.25)
    percentile_25_short_hpr = portfolio_df['Short_Holding_Period_Return_(%)'].quantile(0.25)
    percentile_25_long_annaulized_hpr = portfolio_df['Long_Annualized_Holding_Period_Return_(%)'].quantile(0.25)
    percentile_25_short_annaulized_hpr = portfolio_df['Short_Annualized_Holding_Period_Return_(%)'].quantile(0.25)
    percentile_25_long_excess_returns = portfolio_df['Long_Excess_Returns_(%)'].quantile(0.25)
    percentile_25_short_excess_returns = portfolio_df['Short_Excess_Returns_(%)'].quantile(0.25)
    # 75th percentile returns
    percentile_75_long_hpr = portfolio_df['Long_Holding_Period_Return_(%)'].quantile(0.75)
    percentile_75_short_hpr = portfolio_df['Short_Holding_Period_Return_(%)'].quantile(0.75)
    percentile_75_long_annaulized_hpr = portfolio_df['Long_Annualized_Holding_Period_Return_(%)'].quantile(0.75)
    percentile_75_short_annaulized_hpr = portfolio_df['Short_Annualized_Holding_Period_Return_(%)'].quantile(0.75)
    percentile_75_long_excess_returns = portfolio_df['Long_Excess_Returns_(%)'].quantile(0.75)
    percentile_75_short_excess_returns = portfolio_df['Short_Excess_Returns_(%)'].quantile(0.75)
    # 90th percentile returns
    percentile_90_long_hpr = portfolio_df['Long_Holding_Period_Return_(%)'].quantile(0.9)
    percentile_90_short_hpr = portfolio_df['Short_Holding_Period_Return_(%)'].quantile(0.9)
    percentile_90_long_annaulized_hpr = portfolio_df['Long_Annualized_Holding_Period_Return_(%)'].quantile(0.9)
    percentile_90_short_annaulized_hpr = portfolio_df['Short_Annualized_Holding_Period_Return_(%)'].quantile(0.9)
    percentile_90_long_excess_returns = portfolio_df['Long_Excess_Returns_(%)'].quantile(0.9)
    percentile_90_short_excess_returns = portfolio_df['Short_Excess_Returns_(%)'].quantile(0.9)

    print('number of observations:', portfolio_df.shape[0])
    print('\n')
    print('--------------------------------------------------------------------------------')
    print('mean returns')
    print('--------------------------------------------------------------------------------')
    print('long holding period return:', round((average_long_hpr), 3))
    print('short holding period return:', round((average_short_hpr), 3))
    print('long annualized holding period return:', round((average_long_annaulized_hpr), 3))
    print('short annualized holding period return:', round((average_short_annaulized_hpr), 3))
    print('long excess return:', round((average_long_excess_returns), 3))
    print('short excess return:', round((average_short_excess_returns), 3))
    print('\n')
    print('--------------------------------------------------------------------------------')
    print('median returns')
    print('--------------------------------------------------------------------------------')
    print('long holding period return:', round((median_long_hpr), 3))
    print('short holding period return:', round((median_short_hpr), 3))
    print('long annualized holding period return:', round((median_long_annaulized_hpr), 3))
    print('short annualized holding period return:', round((median_short_annaulized_hpr), 3))
    print('long excess return:', round((median_long_excess_returns), 3))
    print('short excess return:', round((median_short_excess_returns), 3))
    print('\n')
    print('--------------------------------------------------------------------------------')
    print('10th percentile returns')
    print('--------------------------------------------------------------------------------')
    print('long holding period return:', round((percentile_10_long_hpr), 3))
    print('short holding period return:', round((percentile_10_short_hpr), 3))
    print('long annualized holding period return:', round((percentile_10_long_annaulized_hpr), 3))
    print('short annualized holding period return:', round((percentile_10_short_annaulized_hpr), 3))
    print('long excess return:', round((percentile_10_long_excess_returns), 3))
    print('short excess return:', round((percentile_10_short_excess_returns), 3))
    print('\n')
    print('--------------------------------------------------------------------------------')
    print('25th percentile returns')
    print('--------------------------------------------------------------------------------')
    print('long holding period return:', round((percentile_25_long_hpr), 3))
    print('short holding period return:', round((percentile_25_short_hpr), 3))
    print('long annualized holding period return:', round((percentile_25_long_annaulized_hpr), 3))
    print('short annualized holding period return:', round((percentile_25_short_annaulized_hpr), 3))
    print('long excess return:', round((percentile_25_long_excess_returns), 3))
    print('short excess return:', round((percentile_25_short_excess_returns), 3))
    print('\n')
    print('--------------------------------------------------------------------------------')
    print('75th percentile returns')
    print('--------------------------------------------------------------------------------')
    print('long holding period return:', round((percentile_75_long_hpr), 3))
    print('short holding period return:', round((percentile_75_short_hpr), 3))
    print('long annualized holding period return:', round((percentile_75_long_annaulized_hpr), 3))
    print('short annualized holding period return:', round((percentile_75_short_annaulized_hpr), 3))
    print('long excess return:', round((percentile_75_long_excess_returns), 3))
    print('short excess return:', round((percentile_75_short_excess_returns), 3))
    print('\n')
    print('--------------------------------------------------------------------------------')
    print('90th percentile returns')
    print('--------------------------------------------------------------------------------')
    print('long holding period return:', round((percentile_90_long_hpr), 3))
    print('short holding period return:', round((percentile_90_short_hpr), 3))
    print('long annualized holding period return:', round((percentile_90_long_annaulized_hpr), 3))
    print('short annualized holding period return:', round((percentile_90_short_annaulized_hpr), 3))
    print('long excess return:', round((percentile_90_long_excess_returns), 3))
    print('short excess return:', round((percentile_90_short_excess_returns), 3))
    print('\n')
    return None

# %%
# analysis of text files that have been labeled with positive sentiment
print('POSITIVE SENTIMENT PORTFOLIO')
print('\n')
portfolio_analysis_statistics(lexicon_returns_df.loc[lexicon_returns_df['Sentiment_Class']=="Positive"])
# Out:
# POSITIVE SENTIMENT PORTFOLIO
#
#
# number of observations: 38
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: -0.009
# short holding period return: 0.278
# long annualized holding period return: -0.041
# short annualized holding period return: 0.471
# long excess return: -0.14
# short excess return: 0.556
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: -0.017
# short holding period return: 0.017
# long annualized holding period return: -0.019
# short annualized holding period return: 0.019
# long excess return: -0.106
# short excess return: 0.097
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.573
# short holding period return: -0.358
# long annualized holding period return: -0.63
# short annualized holding period return: -0.358
# long excess return: -0.701
# short excess return: -0.223
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.202
# short holding period return: -0.184
# long annualized holding period return: -0.343
# short annualized holding period return: -0.184
# long excess return: -0.433
# short excess return: -0.045
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.225
# short holding period return: 0.254
# long annualized holding period return: 0.225
# short annualized holding period return: 0.522
# long excess return: 0.061
# short excess return: 0.614
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.558
# short holding period return: 1.344
# long annualized holding period return: 0.557
# short annualized holding period return: 1.703
# long excess return: 0.38
# short excess return: 1.757

# %%
# analysis of text files that have been labeled with negative sentiment
print('NEGATIVE SENTIMENT PORTFOLIO')
print('\n')
portfolio_analysis_statistics(lexicon_returns_df.loc[lexicon_returns_df['Sentiment_Class']=="Negative"])
# Out:
# NEGATIVE SENTIMENT PORTFOLIO
#
#
# number of observations: 817
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.196
# short holding period return: 0.387
# long annualized holding period return: 1802.726
# short annualized holding period return: 0.913
# long excess return: 1802.619
# short excess return: 1.004
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: 0.001
# short holding period return: -0.001
# long annualized holding period return: 0.001
# short annualized holding period return: -0.001
# long excess return: -0.106
# short excess return: 0.088
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.494
# short holding period return: -0.38
# long annualized holding period return: -0.609
# short annualized holding period return: -0.414
# long excess return: -0.685
# short excess return: -0.311
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.268
# short holding period return: -0.21
# long annualized holding period return: -0.31
# short annualized holding period return: -0.234
# long excess return: -0.399
# short excess return: -0.125
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.265
# short holding period return: 0.366
# long annualized holding period return: 0.305
# short annualized holding period return: 0.448
# long excess return: 0.169
# short excess return: 0.54
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.612
# short holding period return: 0.976
# long annualized holding period return: 0.708
# short annualized holding period return: 1.555
# long excess return: 0.6
# short excess return: 1.632

# %%
# analysis of text files that have been labeled with negative sentiment (without outlier)
print('NEGATIVE SENTIMENT PORTFOLIO')
print('\n')
portfolio_analysis_statistics(lexicon_returns_df.loc[lexicon_returns_df['Sentiment_Class']=="Negative"].drop(78))
# Out:
# NEGATIVE SENTIMENT PORTFOLIO
#
#
# number of observations: 816
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.196
# short holding period return: 0.388
# long annualized holding period return: 0.926
# short annualized holding period return: 0.915
# long excess return: 0.82
# short excess return: 1.006
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: 0.001
# short holding period return: -0.001
# long annualized holding period return: 0.001
# short annualized holding period return: -0.001
# long excess return: -0.106
# short excess return: 0.089
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.494
# short holding period return: -0.38
# long annualized holding period return: -0.609
# short annualized holding period return: -0.406
# long excess return: -0.686
# short excess return: -0.309
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.268
# short holding period return: -0.21
# long annualized holding period return: -0.31
# short annualized holding period return: -0.233
# long excess return: -0.399
# short excess return: -0.123
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.266
# short holding period return: 0.367
# long annualized holding period return: 0.303
# short annualized holding period return: 0.45
# long excess return: 0.169
# short excess return: 0.54
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.613
# short holding period return: 0.976
# long annualized holding period return: 0.685
# short annualized holding period return: 1.56
# long excess return: 0.598
# short excess return: 1.633

# %%
# analysis of all text files
print('COMPLETE PORTFOLIO')
print('\n')
portfolio_analysis_statistics(lexicon_returns_df)
# Out:
# COMPLETE PORTFOLIO
#
#
# number of observations: 855
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.187
# short holding period return: 0.382
# long annualized holding period return: 1722.603
# short annualized holding period return: 0.893
# long excess return: 1722.497
# short excess return: 0.984
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: 0.0
# short holding period return: 0.0
# long annualized holding period return: 0.0
# short annualized holding period return: 0.0
# long excess return: -0.106
# short excess return: 0.09
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.498
# short holding period return: -0.378
# long annualized holding period return: -0.616
# short annualized holding period return: -0.407
# long excess return: -0.686
# short excess return: -0.31
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.267
# short holding period return: -0.209
# long annualized holding period return: -0.313
# short annualized holding period return: -0.232
# long excess return: -0.399
# short excess return: -0.121
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.265
# short holding period return: 0.365
# long annualized holding period return: 0.303
# short annualized holding period return: 0.456
# long excess return: 0.168
# short excess return: 0.541
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.609
# short holding period return: 0.992
# long annualized holding period return: 0.687
# short annualized holding period return: 1.602
# long excess return: 0.598
# short excess return: 1.661

# %%
# analysis of all text files (excluding major outlier in index 78)
print('COMPLETE PORTFOLIO (EXCLUDING MAJOR OUTLIER)')
print('\n')
portfolio_analysis_statistics(lexicon_returns_df.drop(78))
# Out:
# COMPLETE PORTFOLIO (EXCLUDING MAJOR OUTLIER)
#
#
# number of observations: 854
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.187
# short holding period return: 0.383
# long annualized holding period return: 0.883
# short annualized holding period return: 0.896
# long excess return: 0.778
# short excess return: 0.986
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: 0.0
# short holding period return: 0.0
# long annualized holding period return: 0.0
# short annualized holding period return: 0.0
# long excess return: -0.106
# short excess return: 0.091
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.498
# short holding period return: -0.379
# long annualized holding period return: -0.616
# short annualized holding period return: -0.402
# long excess return: -0.686
# short excess return: -0.308
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.268
# short holding period return: -0.21
# long annualized holding period return: -0.313
# short annualized holding period return: -0.232
# long excess return: -0.4
# short excess return: -0.119
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.265
# short holding period return: 0.365
# long annualized holding period return: 0.302
# short annualized holding period return: 0.456
# long excess return: 0.168
# short excess return: 0.542
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.609
# short holding period return: 0.993
# long annualized holding period return: 0.672
# short annualized holding period return: 1.605
# long excess return: 0.597
# short excess return: 1.665

# %%
# analysis of text files that have been labeled with positive sentiment and high F-SCORE
print('POSITIVE SENTIMENT PORTFOLIO FOR HIGH F-SCORE OBSERVATIONS')
print('\n')
portfolio_analysis_statistics(lexicon_returns_df.loc[(lexicon_returns_df['Sentiment_Class']=="Positive") & 
                                                     ((lexicon_returns_df['F_SCORE']==8) | 
                                                      (lexicon_returns_df['F_SCORE']==9))])
# Out:
# POSITIVE SENTIMENT PORTFOLIO FOR HIGH F-SCORE OBSERVATIONS
#
#
# number of observations: 2
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.173
# short holding period return: -0.049
# long annualized holding period return: 0.174
# short annualized holding period return: -0.05
# long excess return: 0.105
# short excess return: 0.013
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: 0.173
# short holding period return: -0.049
# long annualized holding period return: 0.174
# short annualized holding period return: -0.05
# long excess return: 0.105
# short excess return: 0.013
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.129
# short holding period return: -0.294
# long annualized holding period return: -0.128
# short annualized holding period return: -0.294
# long excess return: -0.171
# short excess return: -0.208
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.016
# short holding period return: -0.202
# long annualized holding period return: -0.015
# short annualized holding period return: -0.203
# long excess return: -0.067
# short excess return: -0.125
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.363
# short holding period return: 0.105
# long annualized holding period return: 0.363
# short annualized holding period return: 0.103
# long excess return: 0.278
# short excess return: 0.152
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.476
# short holding period return: 0.197
# long annualized holding period return: 0.476
# short annualized holding period return: 0.195
# long excess return: 0.382
# short excess return: 0.235

# %%
# analysis of text files that have been labeled with positive sentiment and high F-SCORE (with 7 also)
print('POSITIVE SENTIMENT PORTFOLIO FOR HIGH F-SCORE OBSERVATIONS')
print('\n')
portfolio_analysis_statistics(lexicon_returns_df.loc[(lexicon_returns_df['Sentiment_Class']=="Positive") & 
                                                     ((lexicon_returns_df['F_SCORE']==8) | 
                                                      (lexicon_returns_df['F_SCORE']==9) |
                                                      (lexicon_returns_df['F_SCORE']==7))])
# Out:
# POSITIVE SENTIMENT PORTFOLIO FOR HIGH F-SCORE OBSERVATIONS
#
#
# number of observations: 6
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.016
# short holding period return: 0.153
# long annualized holding period return: -0.029
# short annualized holding period return: 0.545
# long excess return: -0.135
# short excess return: 0.635
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: 0.004
# short holding period return: -0.003
# long annualized holding period return: -0.021
# short annualized holding period return: 0.025
# long excess return: -0.11
# short excess return: 0.097
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.38
# short holding period return: -0.292
# long annualized holding period return: -0.492
# short annualized holding period return: -0.292
# long excess return: -0.552
# short excess return: -0.152
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.161
# short holding period return: -0.181
# long annualized holding period return: -0.172
# short annualized holding period return: -0.181
# long excess return: -0.221
# short excess return: -0.014
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.232
# short holding period return: 0.201
# long annualized holding period return: 0.232
# short annualized holding period return: 0.213
# long excess return: 0.034
# short excess return: 0.251
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.424
# short holding period return: 0.753
# long annualized holding period return: 0.424
# short annualized holding period return: 1.904
# long excess return: 0.258
# short excess return: 1.96

# %%
# analysis of text files that have been labeled with negative sentiment and low F-SCORE
print('NEGATIVE SENTIMENT PORTFOLIO FOR LOW F-SCORE OBSERVATIONS')
print('\n')
portfolio_analysis_statistics(lexicon_returns_df.loc[(lexicon_returns_df['Sentiment_Class']=="Negative") & 
                                                     ((lexicon_returns_df['F_SCORE']==0) |
                                                     (lexicon_returns_df['F_SCORE']==1))])
# Out:
# NEGATIVE SENTIMENT PORTFOLIO FOR LOW F-SCORE OBSERVATIONS
#
#
# number of observations: 10
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: -0.079
# short holding period return: 0.538
# long annualized holding period return: -0.115
# short annualized holding period return: 0.709
# long excess return: -0.164
# short excess return: 0.754
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: -0.026
# short holding period return: 0.027
# long annualized holding period return: -0.065
# short annualized holding period return: 0.074
# long excess return: -0.067
# short excess return: 0.077
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.461
# short holding period return: -0.053
# long annualized holding period return: -0.712
# short annualized holding period return: -0.053
# long excess return: -0.765
# short excess return: -0.044
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.331
# short holding period return: 0.0
# long annualized holding period return: -0.331
# short annualized holding period return: 0.0
# long excess return: -0.455
# short excess return: 0.0
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.0
# short holding period return: 0.497
# long annualized holding period return: 0.0
# short annualized holding period return: 0.497
# long excess return: 0.0
# short excess return: 0.606
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.113
# short holding period return: 1.077
# long annualized holding period return: 0.113
# short annualized holding period return: 2.532
# long excess return: 0.103
# short excess return: 2.582

# %%
# analysis of text files that have been labeled with negative sentiment and low F-SCORE (with 2 also)
print('NEGATIVE SENTIMENT PORTFOLIO FOR LOW F-SCORE OBSERVATIONS')
print('\n')
portfolio_analysis_statistics(lexicon_returns_df.loc[(lexicon_returns_df['Sentiment_Class']=="Negative") & 
                                                     ((lexicon_returns_df['F_SCORE']==0) |
                                                     (lexicon_returns_df['F_SCORE']==1) |
                                                     (lexicon_returns_df['F_SCORE']==2))])
# Out:
# NEGATIVE SENTIMENT PORTFOLIO FOR LOW F-SCORE OBSERVATIONS
#
#
# number of observations: 54
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.072
# short holding period return: 0.24
# long annualized holding period return: 0.541
# short annualized holding period return: 0.544
# long excess return: 0.459
# short excess return: 0.615
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: 0.0
# short holding period return: 0.0
# long annualized holding period return: 0.0
# short annualized holding period return: 0.0
# long excess return: -0.058
# short excess return: 0.052
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.534
# short holding period return: -0.365
# long annualized holding period return: -0.628
# short annualized holding period return: -0.429
# long excess return: -0.716
# short excess return: -0.365
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.29
# short holding period return: -0.187
# long annualized holding period return: -0.296
# short annualized holding period return: -0.202
# long excess return: -0.406
# short excess return: -0.163
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.23
# short holding period return: 0.408
# long annualized holding period return: 0.253
# short annualized holding period return: 0.421
# long excess return: 0.225
# short excess return: 0.515
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.576
# short holding period return: 1.153
# long annualized holding period return: 0.759
# short annualized holding period return: 1.695
# long excess return: 0.647
# short excess return: 1.772

# %%
# analysis of going long on text files with positive sentiment and going short on text files with negative sentiment
positive_negative_portfolio_df = lexicon_returns_df

# define variables to store returns
hpr = 0
annualized_hpr = 0
excess_return = 0

for idx, row in positive_negative_portfolio_df.iterrows():
    if row['Sentiment_Class']=='Negative':
        hpr = hpr + row['Short_Holding_Period_Return_(%)']
        annualized_hpr = annualized_hpr + row['Short_Annualized_Holding_Period_Return_(%)']
        excess_return = excess_return + row['Short_Excess_Returns_(%)']        
    else:
        hpr = hpr + row['Long_Holding_Period_Return_(%)']
        annualized_hpr = annualized_hpr + row['Long_Annualized_Holding_Period_Return_(%)']
        excess_return = excess_return + row['Long_Excess_Returns_(%)']    

# calculate averages of returns
average_hpr = hpr / positive_negative_portfolio_df.shape[0]
average_annualized_hpr = annualized_hpr / positive_negative_portfolio_df.shape[0]
average_excess_return = excess_return / positive_negative_portfolio_df.shape[0]

print('LONG POSITIVE SENTIMENT TEXT AND SHORT NEGATIVE SENTIMENT TEXT')
print('\n')
print('---------------------------------------------------------------------------------------')
print('average holding period return: ', round(average_hpr*100, 3), '%', sep='')
print('average annaulized holding period return: ', round(average_annualized_hpr*100, 3), '%', sep='')
print('average excess return: ', round(average_excess_return*100, 3), '%', sep='')
# Out:
# LONG POSITIVE SENTIMENT TEXT AND SHORT NEGATIVE SENTIMENT TEXT
#
#
# ---------------------------------------------------------------------------------------
# average holding period return: 36.92%
# average annaulized holding period return: 87.069%
# average excess return: 95.315%

# %% [markdown]
# ## Save lexicon_returns_df to CSV File

# %%
# save lexicon_returns_df to csv file
lexicon_returns_df.to_csv('lexicon_returns_df.csv', index=False)
