# %% [markdown]
# # SEC EDGAR - Filings' Data Extraction Part 3

# %% [markdown]
# ## Import Libraries

# %%
# import necessary libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
import time
import re
import os
import unicodedata

# note: the requests library and the BeautifulSoup library will be used for web scraping
# note: the numpy library will be used to replace 'nan' values in various dataframes
# note: the unicodedata library will be used to get the normal form of unicode strings

# %% [markdown]
# ## Read Datasets to Pandas Dataframe

# %%
# read filing_page.csv file into a pandas dataframe
filing_page_df = pd.read_csv('filing_page.csv')
# display filing_page_df
display(filing_page_df.head())
# replace 'nan' values with 'N/A'
filing_page_df = filing_page_df.replace(np.nan, 'N/A')
# Out:
#     CIK Ticker_Symbol Company_Name   Data_Date Filing_Date Filing_Type  \
# 0  1750           AIR     AAR CORP  2012-05-31  2012-07-19        10-K
# 1  1750           AIR     AAR CORP  2013-05-31  2013-07-26        10-K
# 2  1750           AIR     AAR CORP  2014-05-31  2014-07-17        10-K
# 3  1750           AIR     AAR CORP  2016-05-31  2016-07-13        10-K
# 4  1750           AIR     AAR CORP  2019-05-31  2019-07-18        10-K
#
#                                           Filing_Url MDA_Placement  \
# 0  https://www.sec.gov/Archives/edgar/data/1750/0...          10-K
# 1  https://www.sec.gov/Archives/edgar/data/1750/0...          10-K
# 2  https://www.sec.gov/Archives/edgar/data/1750/0...          10-K
# 3  https://www.sec.gov/Archives/edgar/data/1750/0...          10-K
# 4  https://www.sec.gov/Archives/edgar/data/1750/0...          10-K
#
#   Filing_Check                                  Filing_Report_Url
# 0         True  https://www.sec.gov/Archives/edgar/data/1750/0...
# 1         True  https://www.sec.gov/Archives/edgar/data/1750/0...
# 2         True  https://www.sec.gov/Archives/edgar/data/1750/0...
# 3         True  https://www.sec.gov/Archives/edgar/data/1750/0...
# 4         True  https://www.sec.gov/Archives/edgar/data/1750/0...

# %%
# read filing_10k_mda_df.csv file into a pandas dataframe
filing_10k_mda_df = pd.read_csv('filing_10k_mda_df.csv')
# display filing_10k_mda_df 
display(filing_10k_mda_df.head())
# replace 'nan' values with 'N/A'
filing_10k_mda_df = filing_10k_mda_df.replace(np.nan, 'N/A')
# Out:
#     CIK Ticker_Symbol Company_Name   Data_Date Filing_Date Filing_Type  \
# 0  1750           AIR     AAR CORP  2012-05-31  2012-07-19        10-K
# 1  1750           AIR     AAR CORP  2013-05-31  2013-07-26        10-K
# 2  1750           AIR     AAR CORP  2014-05-31  2014-07-17        10-K
# 3  1750           AIR     AAR CORP  2016-05-31  2016-07-13        10-K
# 4  1750           AIR     AAR CORP  2019-05-31  2019-07-18        10-K
#
#                                           Filing_Url MDA_Placement  \
# 0  https://www.sec.gov/Archives/edgar/data/1750/0...          10-K
# 1  https://www.sec.gov/Archives/edgar/data/1750/0...          10-K
# 2  https://www.sec.gov/Archives/edgar/data/1750/0...          10-K
# 3  https://www.sec.gov/Archives/edgar/data/1750/0...          10-K
# 4  https://www.sec.gov/Archives/edgar/data/1750/0...          10-K
#
#    Filing_Check                                  Filing_Report_Url  ...  \
# 0          True  https://www.sec.gov/Archives/edgar/data/1750/0...  ...
# 1          True  https://www.sec.gov/Archives/edgar/data/1750/0...  ...
# 2          True  https://www.sec.gov/Archives/edgar/data/1750/0...  ...
# 3          True  https://www.sec.gov/Archives/edgar/data/1750/0...  ...
# 4          True  https://www.sec.gov/Archives/edgar/data/1750/0...  ...
#
#    MDA_Page_Number_Start_Tag  MDA_Page_Number_Start_Prev_Tag  \
# 0   <font size="2">17</font>        <font size="2">16</font>
# 1   <font size="2">18</font>        <font size="2">17</font>
# 2   <font size="2">19</font>        <font size="2">18</font>
# 3   <font size="2">20</font>        <font size="2">19</font>
# 4   <font size="2">21</font>        <font size="2">20</font>
#
#     MDA_Page_Number_End_Tag  MDA_Page_Number_End_Prev_Tag  \
# 0  <font size="2">29</font>      <font size="2">28</font>
# 1  <font size="2">27</font>      <font size="2">26</font>
# 2  <font size="2">29</font>      <font size="2">28</font>
# 3  <font size="2">33</font>      <font size="2">32</font>
# 4  <font size="2">36</font>      <font size="2">35</font>
#
#    MDA_Page_Number_Start_Match MDA_Page_Number_Start_Prev_Match  \
# 0                         True                             True
# 1                         True                             True
# 2                         True                             True
# 3                         True                             True
# 4                         True                             True
#
#   MDA_Page_Number_End_Match MDA_Page_Number_End_Prev_Match MDA_Start_Position  \
# 0                      True                           True           176725.0
# 1                      True                           True           186736.0
# 2                      True                           True           229060.0
# 3                      True                           True           291382.0
# 4                      True                           True           226707.0
#
#    MDA_End_Position
# 0          275637.0
# 1          272962.0
# 2          405617.0
# 3          482986.0
# 4          426552.0
#
# [5 rows x 25 columns]

# %%
# read filing_20f_ofp_df.csv file into a pandas dataframe
filing_20f_ofp_df = pd.read_csv('filing_20f_ofp_df.csv')
# display filing_20f_ofp_df 
display(filing_20f_ofp_df.head())
# replace 'nan' values with 'N/A'
filing_20f_ofp_df = filing_20f_ofp_df.replace(np.nan, 'N/A')
# Out:
#       CIK Ticker_Symbol Company_Name   Data_Date Filing_Date Filing_Type  \
# 0  911971            TK  TEEKAY CORP  2011-12-31  2012-04-25        20-F
# 1  911971            TK  TEEKAY CORP  2012-12-31  2013-04-29        20-F
# 2  911971            TK  TEEKAY CORP  2013-12-31  2014-04-28        20-F
# 3  911971            TK  TEEKAY CORP  2014-12-31  2015-04-29        20-F
# 4  911971            TK  TEEKAY CORP  2015-12-31  2016-04-26        20-F
#
#                                           Filing_Url MDA_Placement  \
# 0  https://www.sec.gov/Archives/edgar/data/911971...          20-F
# 1  https://www.sec.gov/Archives/edgar/data/911971...          20-F
# 2  https://www.sec.gov/Archives/edgar/data/911971...          20-F
# 3  https://www.sec.gov/Archives/edgar/data/911971...          20-F
# 4  https://www.sec.gov/Archives/edgar/data/911971...          20-F
#
#    Filing_Check                                  Filing_Report_Url  ...  \
# 0          True  https://www.sec.gov/Archives/edgar/data/911971...  ...
# 1          True  https://www.sec.gov/Archives/edgar/data/911971...  ...
# 2          True  https://www.sec.gov/Archives/edgar/data/911971...  ...
# 3          True  https://www.sec.gov/Archives/edgar/data/911971...  ...
# 4          True  https://www.sec.gov/Archives/edgar/data/911971...  ...
#
#                            OFP_Page_Number_Start_Tag  \
# 0  <font size="2" style="font-family:Times New Ro...
# 1  <font size="2" style="font-family:Times New Ro...
# 2  <p align="center" style="margin-top:0pt; margi...
# 3  <p align="center" style="margin-top:0pt; margi...
# 4  <p align="center" style="margin-top:0pt; margi...
#
#                       OFP_Page_Number_Start_Prev_Tag  \
# 0  <font size="2" style="font-family:Times New Ro...
# 1  <font size="2" style="font-family:Times New Ro...
# 2  <p align="center" style="margin-top:0pt; margi...
# 3  <p align="center" style="margin-top:0pt; margi...
# 4  <p align="center" style="margin-top:0pt; margi...
#
#                              OFP_Page_Number_End_Tag  \
# 0  <font size="2" style="font-family:Times New Ro...
# 1  <font size="2" style="font-family:Times New Ro...
# 2  <p align="center" style="margin-top:0pt; margi...
# 3  <p align="center" style="margin-top:0pt; margi...
# 4  <p align="center" style="margin-top:0pt; margi...
#
#                         OFP_Page_Number_End_Prev_Tag  \
# 0  <font size="2" style="font-family:Times New Ro...
# 1  <font size="2" style="font-family:Times New Ro...
# 2  <p align="center" style="margin-top:0pt; margi...
# 3  <p align="center" style="margin-top:0pt; margi...
# 4  <p align="center" style="margin-top:0pt; margi...
#
#    OFP_Page_Number_Start_Match OFP_Page_Number_Start_Prev_Match  \
# 0                         True                             True
# 1                         True                             True
# 2                         True                             True
# 3                         True                             True
# 4                         True                             True
#
#   OFP_Page_Number_End_Match OFP_Page_Number_End_Prev_Match OFP_Start_Position  \
# 0                      True                           True           565576.0
# 1                      True                           True           568217.0
# 2                      True                           True           483881.0
# 3                      True                           True           497565.0
# 4                      True                           True           576580.0
#
#    OFP_End_Position
# 0         1154045.0
# 1         1177746.0
# 2          979510.0
# 3         1096371.0
# 4         1288894.0
#
# [5 rows x 25 columns]

# %%
# note: there is no need to read filing_40f_mda_df.csv into dataframe as observations are all 'N/A'

# %% [markdown]
# ## Define Master Dataframe to Store Details of Extracted Filings

# %%
# note: a master dataframe is needed to keep a track of which filings have been extracted 
# note: this dataframe will also store the text file name for each filing

# create master dataframe to store details of extracted filings
master_filing_df = pd.DataFrame(columns=['CIK', 'Ticker_Symbol', 'Company_Name', 'Data_Date', 'Filing_Date', 
                                         'Filing_Type', 'MDA_Placement', 'File_Name'])

# %% [markdown]
# ## Define Function to Complete Initial Preprocessing on HTML

# %%
# note: in order to save the text from html to a text file, the following preprocessing steps are required:
# - remove all tables as these are most likely less meaningful to the sentiment of the text
# - get textual data from html code
# - get the normal form of the unicode string (text) 
# - remove all non-ascii characters  
# - restore c1 control characters to windows-1252 encoding
# - replace new line encoding '\n' with space

# define function to complete preprocessing outlined above
def file_preprocessing(soup):
    # extract tables with numerical content > 10%
    for table in soup.find_all('table'):
        def table_digit_percentage(tablestring):
            if len(tablestring)>0.0:
                numbers = sum([char.isdigit() for char in tablestring])
                length = len(tablestring)
                return numbers/length
            else:
                return 1
        if table_digit_percentage(table.get_text())>0.1:
            table.extract()
        else:
            continue        
    # get soup text
    soup_text = soup.get_text()
    # get normal form of unicode string and remove all non-ascii characters
    soup_text = unicodedata.normalize('NFKD', soup_text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    # restore c1 control characters to windows-1252 encoding
    def restore_windows_1252_characters(restore_string):
        def to_windows_1252(match):
            try:
                return bytes([ord(match.group(0))]).decode('windows-1252')
            except UnicodeDecodeError:
                # No character at the corresponding code point: remove it.
                return ''    
        return re.sub(r'[\u0080-\u0099]', to_windows_1252, restore_string)
    soup_text = restore_windows_1252_characters(soup_text)
    # replace '\n' with space
    soup_text = soup_text.replace('\n', ' ')
    return soup_text

# %% [markdown]
# ## Create Directory for Filing Text Files

# %%
# note: a new directory will be created to store the filing text files
if os.path.exists('Filing Text Files'):
    print('folder already exists!')
else:
    os.mkdir('Filing Text Files')
    print('folder created')
# Out:
# folder already exists!

# %% [markdown]
# ## Change Working Directory to Filing Text Files Folder

# %%
# note: change directory path to 'Filing Text Files Folder'
try:
    os.chdir('Filing Text Files')
    print('directory changed')
except:
    print('already in directory!')
# Out:
# directory changed

# %% [markdown]
# ## Define Function to Write Filing Text to Text File

# %%
# note: define function to write filing text to text file in Filing Text Files directory
def write_text_file(file_name, text):
    file_n = open(file_name, 'w')
    file_n.write(text)
    file_n.close()

# %% [markdown]
# ## 10-K Filings - Retrieve MD&A Narrative and Save to Text File

# %%
# note: retrieve management's discussion and analysis narrative for observations in filing_10k_mda_df
# note: save narratives to text file

# start execution time
start_time = time.time()

# loop through observations in filing_10k_mda_df 
for idx, row in filing_10k_mda_df.iterrows():
    print('-------------------------------------------------------------------------')
    print(idx, row['Ticker_Symbol'])
    if row['MDA_Start_Position']!='N/A' and row['MDA_End_Position']!='N/A':
        filing_request = requests.get(url=row['Filing_Report_Url'])
        filing_soup = BeautifulSoup(filing_request.content, 'lxml')
        mda_start = int(row['MDA_Start_Position'])
        mda_end = int(row['MDA_End_Position'])
        filing_soup_mda_string = str(filing_soup)[mda_start:mda_end]
        filing_soup_mda = BeautifulSoup(filing_soup_mda_string)
        filing_mda_text = file_preprocessing(filing_soup_mda)
        file_name = row['Ticker_Symbol'] + '_' + row['Filing_Date'] + '.txt'
        data = [row['CIK'], row['Ticker_Symbol'], row['Company_Name'],
                                    row['Data_Date'], row['Filing_Date'], row['Filing_Type'],
                                    row['MDA_Placement'], file_name]
        observation = pd.DataFrame([data], columns=['CIK', 'Ticker_Symbol', 
                                                    'Company_Name', 'Data_Date', 'Filing_Date',
                                                    'Filing_Type', 'MDA_Placement', 'File_Name'])
        master_filing_df = master_filing_df.append(observation)
        if os.path.exists(file_name):
            print('file already exists!')
        else:
            write_text_file(file_name, filing_mda_text)
            print('md&a narrative written to text file')
    else:
        print('cannot retrieve md&a narrative')
    print('\n')
    # note: the SEC strictly states that developers should not exceed 10 requests per second 
    # delay next request to EDGAR by 1 second 
    time.sleep(1)
    
# reset index for master_filing_df
master_filing_df = master_filing_df.reset_index(drop=True)

# end execution time
end_time = time.time()

filing_10k_time = end_time - start_time

print('total time taken:', filing_10k_time)
# Out:
# -------------------------------------------------------------------------
# 0 AIR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1 AIR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 2 AIR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 3 AIR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 4 AIR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 5 HES
# file already exists!
#
#
# -------------------------------------------------------------------------
# 6 HES
# file already exists!
#
#
# -------------------------------------------------------------------------
# 7 HES
# file already exists!
#
#
# -------------------------------------------------------------------------
# 8 HES
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 9 HES
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 10 HES
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 11 HES
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 12 AP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 13 AP
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 14 AP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 15 AP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 16 AP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 17 AP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 18 AP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 19 APA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 20 APA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 21 APA
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 22 APA
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 23 APA
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 24 SSI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 25 SSI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 26 SSI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 27 SSI
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 28 SSI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 29 SSI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 30 TREC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 31 ADM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 32 ADM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 33 ADM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 34 ADM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 35 ADM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 36 SWN
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 37 SWN
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 38 ARW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 39 ARW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 40 ARW
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 41 ARW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 42 ESTE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 43 ESTE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 44 BGG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 45 CAL
# file already exists!
#
#
# -------------------------------------------------------------------------
# 46 CBT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 47 CBT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 48 CACI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 49 CACI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 50 CACI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 51 LUB
# file already exists!
#
#
# -------------------------------------------------------------------------
# 52 LUB
# file already exists!
#
#
# -------------------------------------------------------------------------
# 53 LUB
# file already exists!
#
#
# -------------------------------------------------------------------------
# 54 LUB
# file already exists!
#
#
# -------------------------------------------------------------------------
# 55 LUB
# file already exists!
#
#
# -------------------------------------------------------------------------
# 56 LUB
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 57 LUB
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 58 LUB
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 59 CATO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 60 CATO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 61 GCO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 62 GCO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 63 CTL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 64 CTL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 65 CTL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 66 CTL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 67 CTL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 68 CTL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 69 CSS
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 70 CSS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 71 CSS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 72 CSS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 73 CSS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 74 CSS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 75 CSS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 76 CSS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 77 CSS
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 78 CMC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 79 CMC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 80 TAP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 81 TAP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 82 TAP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 83 TAP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 84 GLW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 85 GLW
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 86 GLW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 87 GLW
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 88 CTS
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 89 CW
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 90 DAN
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 91 DAN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 92 DDS
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 93 DDS
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 94 DDS
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 95 DDS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 96 DDS
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 97 DCO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 98 DCO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 99 DCO
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 100 DCO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 101 KODK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 102 KODK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 103 EBF
# file already exists!
#
#
# -------------------------------------------------------------------------
# 104 EBF
# file already exists!
#
#
# -------------------------------------------------------------------------
# 105 EBF
# file already exists!
#
#
# -------------------------------------------------------------------------
# 106 EBF
# file already exists!
#
#
# -------------------------------------------------------------------------
# 107 EQT
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 108 EQT
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 109 EQT
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 110 FOE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 111 F
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 112 GLT
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 113 GLT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 114 GTN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 115 GTN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 116 GTN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 117 HHS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 118 HP
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 119 HPQ
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 120 HFC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 121 HFC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 122 HFC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 123 GFF
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 124 GFF
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 125 GFF
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 126 GFF
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 127 AXE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 128 JEC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 129 KFY
# file already exists!
#
#
# -------------------------------------------------------------------------
# 130 LCI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 131 LCI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 132 LCI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 133 VHI
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 134 VHI
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 135 LPX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 136 LXU
# file already exists!
#
#
# -------------------------------------------------------------------------
# 137 LXU
# file already exists!
#
#
# -------------------------------------------------------------------------
# 138 LXU
# file already exists!
#
#
# -------------------------------------------------------------------------
# 139 LXU
# file already exists!
#
#
# -------------------------------------------------------------------------
# 140 LDL
# file already exists!
#
#
# -------------------------------------------------------------------------
# 141 LDL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 142 MTW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 143 MCS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 144 MCS
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 145 MCS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 146 ETR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 147 ETR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 148 THC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 149 THC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 150 THC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 151 THC
# cannot retrieve md&a narrative
# -------------------------------------------------------------------------
# 152 GPX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 153 NR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 154 NR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 155 NL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 156 NL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 157 NBL
# file already exists!
#
#
# -------------------------------------------------------------------------
# 158 MOV
# file already exists!
#
#
# -------------------------------------------------------------------------
# 159 MOV
# file already exists!
#
#
# -------------------------------------------------------------------------
# 160 OII
# file already exists!
#
#
# -------------------------------------------------------------------------
# 161 OLN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 162 OLN
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 163 OSG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 164 OSG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 165 OSG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 166 OSG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 167 OSG
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 168 OSG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 169 OMI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 170 OMI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 171 PKD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 172 PKD
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 173 PKD
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 174 PKD
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 175 PKD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 176 PKD
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 177 TPC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 178 TPC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 179 TPC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 180 TPC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 181 TPC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 182 TPC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 183 TPC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 184 TPC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 185 RAD
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 186 R
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 187 LUV
# file already exists!
#
#
# -------------------------------------------------------------------------
# 188 LUV
# file already exists!
#
#
# -------------------------------------------------------------------------
# 189 CVX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 190 SCX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 191 SCX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 192 SCX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 193 SCX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 194 SCX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 195 SCX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 196 SCX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 197 SCX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 198 SCX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 199 SUP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 200 SUP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 201 SUP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 202 SUP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 203 SUP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 204 SUP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 205 SUP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 206 TEX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 207 TEX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 208 TMO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 209 TDW
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 210 TDW
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 211 TDW
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 212 TDW
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 213 TDW
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 214 TDW
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 215 TDW
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 216 TDW
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 217 TSN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 218 TSN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 219 UFI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 220 UFI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 221 UFI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 222 MRO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 223 MRO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 224 MRO
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 225 MRO
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 226 MRO
# cannot retrieve md&a narrative
# -------------------------------------------------------------------------
# 227 MRO
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 228 S
# file already exists!
#
#
# -------------------------------------------------------------------------
# 229 S
# file already exists!
#
#
# -------------------------------------------------------------------------
# 230 S
# file already exists!
#
#
# -------------------------------------------------------------------------
# 231 S
# file already exists!
#
#
# -------------------------------------------------------------------------
# 232 S
# file already exists!
#
#
# -------------------------------------------------------------------------
# 233 UVV
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 234 UVV
# file already exists!
#
#
# -------------------------------------------------------------------------
# 235 UVV
# file already exists!
#
#
# -------------------------------------------------------------------------
# 236 UVV
# file already exists!
#
#
# -------------------------------------------------------------------------
# 237 UVV
# file already exists!
#
#
# -------------------------------------------------------------------------
# 238 UVV
# file already exists!
#
#
# -------------------------------------------------------------------------
# 239 UVV
# file already exists!
#
#
# -------------------------------------------------------------------------
# 240 UVV
# file already exists!
#
#
# -------------------------------------------------------------------------
# 241 VSH
# file already exists!
#
#
# -------------------------------------------------------------------------
# 242 VSH
# file already exists!
#
#
# -------------------------------------------------------------------------
# 243 VSH
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 244 VSH
# file already exists!
#
#
# -------------------------------------------------------------------------
# 245 VSH
# file already exists!
#
#
# -------------------------------------------------------------------------
# 246 GHC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 247 GHC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 248 GHC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 249 GHC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 250 GHC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 251 GHC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 252 AVA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 253 AVA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 254 WMK
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 255 WHR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 256 WMB
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 257 CDE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 258 CDE
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 259 CDE
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 260 CDE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 261 CDE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 262 CDE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 263 HVT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 264 PIR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 265 MUX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 266 MUX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 267 MUX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 268 VAL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 269 VAL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 270 VAL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 271 VAL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 272 VAL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 273 VAL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 274 VAL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 275 VAL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 276 RRC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 277 RRC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 278 ENZ
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 279 TISI
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 280 TISI
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 281 KEG
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 282 KEG
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 283 KEG
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 284 KEG
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 285 KEG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 286 AN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 287 SBOW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 288 SBOW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 289 SBOW
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 290 SBOW
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 291 MDR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 292 MDR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 293 MDR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 294 MDR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 295 MDR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 296 PAR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 297 PAR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 298 PAR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 299 ACCO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 300 RGS
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 301 RGS
# cannot retrieve md&a narrative
# -------------------------------------------------------------------------
# 302 RGS
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 303 RGS
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 304 RGS
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 305 RGS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 306 MUR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 307 MUR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 308 MUR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 309 MUR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 310 MUR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 311 HL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 312 HL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 313 HL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 314 HL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 315 HL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 316 TRCO
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 317 TRCO
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 318 TRCO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 319 TRCO
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 320 ATGE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 321 ATGE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 322 T
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 323 IVC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 324 IVC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 325 IVC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 326 IVC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 327 IVC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 328 IVC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 329 IVC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 330 REX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 331 REX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 332 REX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 333 REX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 334 REX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 335 REX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 336 REX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 337 CLF
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 338 CLF
# file already exists!
#
#
# -------------------------------------------------------------------------
# 339 OSK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 340 CRY
# file already exists!
#
#
# -------------------------------------------------------------------------
# 341 POR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 342 POR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 343 INT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 344 INT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 345 MGM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 346 MGM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 347 MGM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 348 NC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 349 NC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 350 NC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 351 UNT
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 352 UNT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 353 UNT
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 354 UNT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 355 UNT
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 356 UNT
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 357 UNT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 358 UNT
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 359 BPL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 360 CCL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 361 CCL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 362 USM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 363 USM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 364 USM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 365 USM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 366 USM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 367 USM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 368 USM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 369 USM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 370 EIX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 371 FCX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 372 FCX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 373 FCX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 374 SIG
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 375 SIG
# cannot retrieve md&a narrative
# -------------------------------------------------------------------------
# 376 ELY
# file already exists!
#
#
# -------------------------------------------------------------------------
# 377 TTI
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 378 TTI
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 379 TTI
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 380 TTI
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 381 MHK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 382 MHK
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 383 CGA
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 384 CGA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 385 CGA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 386 CGA
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 387 CGA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 388 CGA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 389 CGA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 390 CGA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 391 AVX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 392 AVX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 393 AVX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 394 AVX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 395 AVX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 396 CKH
# file already exists!
#
#
# -------------------------------------------------------------------------
# 397 CKH
# file already exists!
#
#
# -------------------------------------------------------------------------
# 398 CKH
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 399 CKH
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 400 CKH
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 401 CKH
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 402 CKH
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 403 GVA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 404 RS
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 405 RS
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 406 RS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 407 RS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 408 BHE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 409 BHE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 410 BHE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 411 BHE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 412 BHE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 413 BHE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 414 BHE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 415 BHE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 416 IO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 417 ESE
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 418 HLX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 419 HLX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 420 HLX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 421 HLX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 422 HLX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 423 ACM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 424 ACM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 425 ACM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 426 ACM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 427 MAN
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 428 AES
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 429 AES
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 430 AES
# file already exists!
#
#
# -------------------------------------------------------------------------
# 431 AES
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 432 AGCO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 433 CNR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 434 CNR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 435 VVI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 436 UGI
# file already exists!
#
#
# ...
#
#
# -------------------------------------------------------------------------
# 953 SLCA
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 954 ERA
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 955 ERA
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 956 ERA
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 957 ERA
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 958 LPI
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 959 LPI
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 960 GNE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 961 RH
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 962 TROX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 963 TROX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 964 TROX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 965 TROX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 966 POST
# file already exists!
#
#
# -------------------------------------------------------------------------
# 967 AMPY
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 968 AMPY
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 969 AMPY
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 970 AMPY
# file already exists!
#
#
# -------------------------------------------------------------------------
# 971 AMPY
# file already exists!
#
#
# -------------------------------------------------------------------------
# 972 PBF
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 973 PBF
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 974 ICD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 975 ICD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 976 ICD
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 977 FELP
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 978 FELP
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 979 EQM
# cannot retrieve md&a narrative
# -------------------------------------------------------------------------
# 980 ALEX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 981 NGVC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 982 HCR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 983 HCR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 984 SMLP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 985 SMLP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 986 MPLX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 987 SUN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 988 SUN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 989 CWEN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 990 CWEN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 991 CWEN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 992 CWEN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 993 MNK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 994 MNK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 995 FI
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 996 AGN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 997 AGN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 998 AGN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 999 VNCE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1000 NEWM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1001 NEWM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1002 PAGP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1003 PAGP
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1004 PAGP
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1005 PAGP
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1006 PRGO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1007 KN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1008 KN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1009 CVEO
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1010 CVEO
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1011 CVEO
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1012 ESI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1013 ESI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1014 ENBL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1015 ENBL
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1016 ENBL
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1017 ENLC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1018 ENLC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1019 ENLC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1020 PRTY
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1021 PE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1022 RUBI
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1023 RUBI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1024 LPG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1025 LPG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1026 LPG
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1027 RYAM
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1028 TMST
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1029 TMST
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1030 TMST
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1031 VRTV
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1032 VRTV
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1033 DNOW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1034 DNOW
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1035 GMS
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1036 MR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1037 MR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1038 VEC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1039 NEP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1040 NEP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1041 NEP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1042 WLKP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1043 WLKP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1044 WLKP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1045 AAC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1046 AAC
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1047 VSLR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1048 VSLR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1049 VSLR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1050 CJ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1051 CJ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1052 CJ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1053 VSTO
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1054 VSTO
# cannot retrieve md&a narrative
# -------------------------------------------------------------------------
# 1055 VSTO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1056 JAX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1057 QSR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1058 SUM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1059 EVH
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1060 TGE
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1061 BNED
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1062 BNED
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1063 AGR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1064 AGR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1065 GCI
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1066 EXTN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1067 HPE
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1068 NBLX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1069 AFI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1070 ASH
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1071 AA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1072 CNDT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1073 INSW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1074 DK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1075 DK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1076 HPR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1077 HPR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1078 HPR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1079 HPR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1080 HPR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1081 HPR
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1082 BH
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1083 BH
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1084 BH
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1085 BH
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1086 BH
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1087 BH
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1088 BH
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1089 BH
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1090 WRK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1091 WRK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1092 WRK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1093 XRX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1094 XRX
# cannot retrieve md&a narrative
#
#
# -------------------------------------------------------------------------
# 1095 XRX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1096 XRX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1097 XRX
# cannot retrieve md&a narrative
#
#
# total time taken: 2390.497316122055

# %% [markdown]
# ## 20-F Filings - Retrieve OFP Narrative and Save to Text File

# %%
# note: retrieve operating and financial review and prospects narrative for observations in filing_20f_ofp_df
# note: save narratives to text file

# start execution time
start_time = time.time()

# loop through observations in filing_20f_ofp_df
for idx, row in filing_20f_ofp_df.iterrows():
    print('-------------------------------------------------------------------------')
    print(idx, row['Ticker_Symbol'])
    if row['OFP_Start_Position']!='N/A' and row['OFP_End_Position']!='N/A':
        filing_request = requests.get(url=row['Filing_Report_Url'])
        filing_soup = BeautifulSoup(filing_request.content, 'lxml')
        ofp_start = int(row['OFP_Start_Position'])
        ofp_end = int(row['OFP_End_Position'])
        filing_soup_ofp_string = str(filing_soup)[ofp_start:ofp_end]
        filing_soup_ofp = BeautifulSoup(filing_soup_ofp_string)
        filing_ofp_text = file_preprocessing(filing_soup_ofp)
        file_name = row['Ticker_Symbol'] + '_' + row['Filing_Date'] + '.txt'
        data = [row['CIK'], row['Ticker_Symbol'], row['Company_Name'],
                                    row['Data_Date'], row['Filing_Date'], row['Filing_Type'],
                                    row['MDA_Placement'], file_name]
        observation = pd.DataFrame([data], columns=['CIK', 'Ticker_Symbol', 
                                                    'Company_Name', 'Data_Date', 'Filing_Date',
                                                    'Filing_Type', 'MDA_Placement', 'File_Name'])
        master_filing_df = master_filing_df.append(observation)
        if os.path.exists(file_name):
            print('file already exists!')
        else:
            write_text_file(file_name, filing_ofp_text)
            print('ofp narrative written to text file')
    else:
        print('cannot retrieve ofp narrative')
    print('\n')
    # note: the SEC strictly states that developers should not exceed 10 requests per second 
    # delay next request to EDGAR by 1 second 
    time.sleep(1)
    
# reset index for master_filing_df
master_filing_df = master_filing_df.reset_index(drop=True)

# end execution time
end_time = time.time()

filing_20f_time = end_time - start_time

print('total time taken:', filing_20f_time)
# Out:
# -------------------------------------------------------------------------
# 0 TK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1 TK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 2 TK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 3 TK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 4 TK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 5 TK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 6 TK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 7 TK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 8 FRO
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 9 FRO
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 10 CYD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 11 CYD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 12 CYD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 13 CYD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 14 CYD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 15 CYD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 16 CYD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 17 CYD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 18 NAT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 19 NAT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 20 NAT
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 21 NAT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 22 NAT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 23 NAT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 24 NAT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 25 CEA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 26 CEA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 27 CEA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 28 CEA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 29 CLS
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 30 CLS
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 31 CLS
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 32 CLS
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 33 TNP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 34 TNP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 35 TNP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 36 TNP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 37 TNP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 38 TNP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 39 TNP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 40 TNP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 41 SFL
# file already exists!
#
#
# -------------------------------------------------------------------------
# 42 TGP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 43 TGP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 44 TGP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 45 TGP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 46 DSX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 47 DSX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 48 DSX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 49 DSX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 50 DSX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 51 DSX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 52 DSX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 53 DSX
# file already exists!
#
#
# -------------------------------------------------------------------------
# 54 DHT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 55 DHT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 56 DHT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 57 DHT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 58 DHT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 59 DHT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 60 DHT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 61 DHT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 62 SSW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 63 SSW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 64 SSW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 65 SSW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 66 SSW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 67 SSW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 68 SSW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 69 SSW
# file already exists!
#
#
# -------------------------------------------------------------------------
# 70 NM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 71 NM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 72 NM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 73 NM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 74 NM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 75 NM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 76 NM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 77 NM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 78 DAC
# cannot retrieve ofp narrative
# -------------------------------------------------------------------------
# 79 DAC
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 80 DAC
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 81 DAC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 82 DAC
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 83 DAC
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 84 DAC
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 85 DAC
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 86 TOO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 87 TOO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 88 TOO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 89 TOO
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 90 CZZ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 91 CZZ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 92 CZZ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 93 CZZ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 94 CZZ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 95 CZZ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 96 CZZ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 97 CZZ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 98 CZZ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 99 BIP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 100 BIP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 101 BIP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 102 BIP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 103 BIP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 104 BIP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 105 BIP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 106 BIP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 107 TGH
# file already exists!
#
#
# -------------------------------------------------------------------------
# 108 TGH
# file already exists!
#
#
# -------------------------------------------------------------------------
# 109 TGH
# file already exists!
#
#
# -------------------------------------------------------------------------
# 110 TGH
# file already exists!
#
#
# -------------------------------------------------------------------------
# 111 NMM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 112 NMM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 113 NMM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 114 NMM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 115 NMM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 116 NMM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 117 TNK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 118 TNK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 119 TNK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 120 TNK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 121 TNK
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 122 TNK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 123 TNK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 124 GSL
# file already exists!
#
#
# -------------------------------------------------------------------------
# 125 GSL
# file already exists!
#
#
# -------------------------------------------------------------------------
# 126 GSL
# file already exists!
#
#
# -------------------------------------------------------------------------
# 127 GSL
# file already exists!
#
#
# -------------------------------------------------------------------------
# 128 GSL
# file already exists!
#
#
# -------------------------------------------------------------------------
# 129 GSL
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 130 GSL
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 131 GSL
# file already exists!
#
#
# -------------------------------------------------------------------------
# 132 SB
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 133 SB
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 134 SB
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 135 SB
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 136 SB
# file already exists!
#
#
# -------------------------------------------------------------------------
# 137 SB
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 138 NNA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 139 NNA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 140 NNA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 141 NNA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 142 NNA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 143 NNA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 144 NNA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 145 GPRK
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 146 STNG
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 147 STNG
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 148 STNG
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 149 STNG
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 150 STNG
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 151 AGRO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 152 AGRO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 153 CMRE
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 154 CMRE
# cannot retrieve ofp narrative
# -------------------------------------------------------------------------
# 155 CMRE
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 156 CMRE
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 157 PACD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 158 PACD
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 159 PACD
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 160 PACD
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 161 PACD
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 162 PACD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 163 EROS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 164 EROS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 165 EROS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 166 EROS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 167 BEP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 168 BEP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 169 BEP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 170 BEP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 171 BEP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 172 BEP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 173 GLOG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 174 GLOG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 175 GLOG
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 176 GLOG
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 177 ANFI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 178 ANFI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 179 ANFI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 180 ANFI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 181 KNOP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 182 KNOP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 183 KNOP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 184 ASC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 185 ASC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 186 ASC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 187 ASC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 188 DLNG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 189 DLNG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 190 DLNG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 191 DLNG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 192 NVGS
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 193 NVGS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 194 NVGS
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 195 NVGS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 196 SALT
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 197 SALT
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 198 SALT
# file already exists!
#
#
# -------------------------------------------------------------------------
# 199 SALT
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 200 PSV
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 201 PSV
# file already exists!
#
#
# -------------------------------------------------------------------------
# 202 PSV
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 203 GLOP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 204 GLOP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 205 GLOP
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 206 HMLP
# file already exists!
#
#
# -------------------------------------------------------------------------
# 207 EURN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 208 EURN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 209 EURN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 210 EURN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 211 FCAU
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 212 ATTO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 213 KEN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 214 KEN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 215 IGT
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 216 BBU
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 217 SDRL
# file already exists!
#
#
# -------------------------------------------------------------------------
# 218 SDRL
# file already exists!
#
#
# -------------------------------------------------------------------------
# 219 SDRL
# cannot retrieve ofp narrative
#
#
# -------------------------------------------------------------------------
# 220 SDRL
# file already exists!
#
#
# -------------------------------------------------------------------------
# 221 SDRL
# file already exists!
#
#
# total time taken: 627.7819557189941

# %% [markdown]
# ## Other Filings - Retrieve MD&A Narrative and Save to Text File

# %%
# note: retrieve filings for which the management's discussion and analysis narrative is stored in separate exhbits
# note: save narratives to text file 

# store filings for which the management's discussion and analysis narrative is stored in separate exhbits
filing_other_mda_df = filing_page_df.query('MDA_Placement!="N/A" & MDA_Placement!="10-K" & MDA_Placement!="10-KT" & MDA_Placement!="20-F" & MDA_Placement!="40-F"')

# start execution time
start_time = time.time()

# loop through observations in filing_other_mda_df
for idx, row in filing_other_mda_df.iterrows():
    print('-------------------------------------------------------------------------')
    print(idx, row['Ticker_Symbol'])
    filing_request = requests.get(url=row['Filing_Report_Url'])
    filing_soup_mda = BeautifulSoup(filing_request.content, 'lxml')
    filing_mda_text = file_preprocessing(filing_soup_mda)
    file_name = row['Ticker_Symbol'] + '_' + row['Filing_Date'] + '.txt'
    data = [row['CIK'], row['Ticker_Symbol'], row['Company_Name'],
            row['Data_Date'], row['Filing_Date'], row['Filing_Type'],
            row['MDA_Placement'], file_name]
    observation = pd.DataFrame([data], columns=['CIK', 'Ticker_Symbol', 
                                                'Company_Name', 'Data_Date', 'Filing_Date',
                                                'Filing_Type', 'MDA_Placement', 'File_Name'])
    master_filing_df = master_filing_df.append(observation)
    if os.path.exists(file_name):
        print('file already exists!')
    else:
        write_text_file(file_name, filing_mda_text)
        print('md&a narrative written to text file')
    print('\n')
    # note: the SEC strictly states that developers should not exceed 10 requests per second 
    # delay next request to EDGAR by 1 second 
    time.sleep(1)
    
# reset index for master_filing_df
master_filing_df = master_filing_df.reset_index(drop=True)

# end execution time
end_time = time.time()

filing_other_time = end_time - start_time

print('total time taken:', filing_other_time)
# Out:
# -------------------------------------------------------------------------
# 265 SU
# file already exists!
#
#
# -------------------------------------------------------------------------
# 292 KGC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 293 KGC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 294 KGC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 295 KGC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 296 KGC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 297 KGC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 298 KGC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 299 KGC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 347 GOLD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 348 GOLD
# file already exists!
#
#
# -------------------------------------------------------------------------
# 463 TECK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 464 TECK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 465 TECK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 466 TECK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 467 TECK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 468 TECK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 469 TECK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 470 TECK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 509 EGO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 510 EGO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 511 EGO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 512 EGO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 513 EGO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 514 EGO
# file already exists!
#
#
# -------------------------------------------------------------------------
# 589 CCJ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 590 CCJ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 591 CCJ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 599 PDS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 600 PDS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 601 PDS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 602 PDS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 603 PDS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 604 PDS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 605 PDS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 698 BB
# file already exists!
#
#
# -------------------------------------------------------------------------
# 699 BB
# file already exists!
#
#
# -------------------------------------------------------------------------
# 706 AUQ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 707 AUQ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 708 AUQ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 709 AUQ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 710 AGI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 711 AGI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 712 AGI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 713 AGI
# file already exists!
#
#
# -------------------------------------------------------------------------
# 755 ERF
# file already exists!
#
#
# -------------------------------------------------------------------------
# 756 ERF
# file already exists!
#
#
# -------------------------------------------------------------------------
# 757 ERF
# file already exists!
#
#
# -------------------------------------------------------------------------
# 778 TAC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 779 TAC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 780 TAC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 781 TAC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 782 TAC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 783 TAC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 784 TAC
# file already exists!
#
#
# -------------------------------------------------------------------------
# 795 TRQ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 796 TRQ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 797 TRQ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 798 TRQ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 799 TRQ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 800 TRQ
# file already exists!
#
#
# -------------------------------------------------------------------------
# 832 AQN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 833 AQN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 834 AQN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 835 AQN
# file already exists!
#
#
# -------------------------------------------------------------------------
# 839 IAG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 840 IAG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 841 IAG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 842 IAG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 843 IAG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 844 IAG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 845 IAG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 856 AUY
# file already exists!
#
#
# -------------------------------------------------------------------------
# 857 AUY
# file already exists!
#
#
# -------------------------------------------------------------------------
# 858 AUY
# file already exists!
#
#
# -------------------------------------------------------------------------
# 859 AUY
# file already exists!
#
#
# -------------------------------------------------------------------------
# 860 AUY
# file already exists!
#
#
# -------------------------------------------------------------------------
# 861 AUY
# file already exists!
# -------------------------------------------------------------------------
# 868 EXK
# file already exists!
#
#
# -------------------------------------------------------------------------
# 895 AG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 896 AG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 909 HBM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 910 HBM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 911 HBM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 912 HBM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 913 HBM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 914 HBM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 915 HBM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 916 HBM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 917 WPM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 963 OBE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 964 OBE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 965 OBE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 966 OBE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 967 OBE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 968 OBE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 969 OBE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 970 OBE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 976 FSM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 977 FSM
# file already exists!
#
#
# -------------------------------------------------------------------------
# 991 NOA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 992 NOA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 994 NOA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 995 NOA
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1168 CVE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1169 CVE
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1275 CPG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1276 CPG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1277 CPG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1278 CPG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1279 CPG
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1399 OR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1400 OR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1401 OR
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1418 FTS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1419 FTS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1420 FTS
# file already exists!
#
#
# -------------------------------------------------------------------------
# 1437 NTR
# file already exists!
#
#
# total time taken: 231.74184107780457

# %% [markdown]
# ## Save master_filing_df to CSV File

# %%
# change directory back to 'Prototype Two Notebooks'
os.chdir('..')

# save master_filing_df to csv file
master_filing_df.to_csv('master_filing_df.csv', index=False)
