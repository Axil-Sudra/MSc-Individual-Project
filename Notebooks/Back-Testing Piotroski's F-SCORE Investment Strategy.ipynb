# %% [markdown]
# # Back-Testing Piotroski's F-SCORE Strategy

# %% [markdown]
# ## Import Libraries

# %%
# import necessary libraries
import wrds
import pandas as pd
import datetime as dt
import numpy as np
from datetime import datetime
from datetime import timedelta
from calendar import isleap
from workalendar.usa import UnitedStates
from pandas_datareader import data

# note: wrds provides an api to wharton research data services which provides access to various databases
# note: compustat can be accessed through wrds
# note: the calender library will be used to identify leap years
# note: the workalendar.usa library will be used to identify days that are public holidays in the US

# connect to wrds
db = wrds.Connection(wrds_username='acka662')

# set US calender
cal = UnitedStates()
# Out:
# Loading library list...
# Done

# %% [markdown]
# ## Read Dataset to Pandas Dataframe

# %%
# read fundamentals_fscore.csv file into a pandas dataframe
funda_df = pd.read_csv('fundamentals_fscore.csv')
# display funda_df
display(funda_df.head())
# Out:
#     CIK Ticker_Symbol Company_Name         Sector   Data_Date  \
# 0  1750           AIR     AAR CORP  Capital Goods  2011-05-31
# 1  1750           AIR     AAR CORP  Capital Goods  2012-05-31
# 2  1750           AIR     AAR CORP  Capital Goods  2013-05-31
# 3  1750           AIR     AAR CORP  Capital Goods  2014-05-31
# 4  1750           AIR     AAR CORP  Capital Goods  2015-05-31
#
#    Market_Capitalization  Total_Assets  Total_Assets_PY1  Total_Assets_PY2  \
# 0              1049.8206      1703.727          1501.042          1377.511
# 1               485.2897      2195.653          1703.727          1501.042
# 2               790.0029      2136.900          2195.653          1703.727
# 3               961.3080      2199.500          2136.900          2195.653
# 4              1046.3954      1515.000          2199.500          2136.900
#
#    Total_Liabilities  ...  F_CLEVER   CLIQUID  F_CLIQUID  EQ_OFFER  \
# 0            868.438  ...         1 -0.455190          0     0.297
# 1           1329.631  ...         0  0.049832          1     0.492
# 2           1217.400  ...         1  0.410468          1    -0.891
# 3           1198.800  ...         1  0.120341          1     0.178
# 4            669.900  ...         1 -0.461891          0    -4.137
#
#    F_EQ_OFFER   CMARGIN  F_CMARGIN     CTURN  F_CTURN  F_SCORE
# 0           0 -0.004629          0  0.201443        1        6
# 1           0 -0.008424          0  0.034591        1        5
# 2           1  0.010205          1 -0.230628        0        7
# 3           0  0.014049          1 -0.034682        0        7
# 4           1 -0.065087          0 -0.227468        0        3
#
# [5 rows x 46 columns]

# %%
# note: the cik of each company is usuallly 10 digits in length
# note: the leading 0's from some ciks have been removed
# note: therefore, these leading 0's have to be added again to ensure all ciks are of length 10

# add leading 0's to ciks that have a length less than 10
funda_df['CIK'] = funda_df['CIK'].apply(lambda x: '{0:0>10}'.format(x))

# convert values in the Data_Date column of funda_df to datetime 
funda_df['Data_Date'] = pd.to_datetime(funda_df['Data_Date'])

# %% [markdown]
# ## COMPUSTAT - Stock Price Data Extraction

# %%
pd.options.mode.chained_assignment = None

# note: in order to back-test portfolio performance, stock price data is required
# note: pricing data for each observation in funda_df will be obtained
# note: each observation will have pricing data that corresponds to the date on which the financial
#       statement data is avaliable to the public (this is the final date variable in the funda table on compustat)
# note: the sell date of each observation will be one year from the final date described in the note above
# note: the pricing data for more recent observations (which the fiscal year has not concluded) will not be
#       available for a year - these observations will be sold on 02/09/2019

# define a dataframe that will store the pricing data for each observation in funda_df
# note: this dataframe will also store the observations corresponding F-SCORE
stock_price_df = funda_df[['Ticker_Symbol', 'Company_Name', 'Data_Date', 'BM_Quintile', 'F_SCORE']]
# filter very high b/m companies from stock_price_df
stock_price_df = stock_price_df.loc[stock_price_df['BM_Quintile']=='Very High'].reset_index(drop=True)

# create column in stock_price_df to store purchase date
# note: purchase date will be equal to the final date variable in the funda table in the compustat database
stock_price_df['Purchase_Date'] = 0
# retrieve final data from funda table
for idx, row in stock_price_df.iterrows():
    purchase_date = db.raw_sql("""SELECT DISTINCT fdate
                                  FROM compa.funda WHERE tic=%s
                                  AND datadate=%s""", params=(row['Ticker_Symbol'], row['Data_Date']))
    # provide user feedback
    print('-----------------------------------------------------------------------------')
    print(idx, row['Ticker_Symbol'])
    if purchase_date.shape[0]==0:
        stock_price_df.loc[idx, 'Purchase_Date'] = 'N/A'
    else:
        stock_price_df.loc[idx, 'Purchase_Date'] = purchase_date['fdate'][0]
    print('data available to public on:', stock_price_df.loc[idx, 'Purchase_Date'])
    print('\n')
# Out:
# -----------------------------------------------------------------------------
# 0 AIR
# data available to public on: 2012-07-23
#
#
# -----------------------------------------------------------------------------
# 1 AIR
# data available to public on: 2013-08-01
#
#
# -----------------------------------------------------------------------------
# 2 AIR
# data available to public on: 2014-07-20
#
#
# -----------------------------------------------------------------------------
# 3 AIR
# data available to public on: 2016-07-18
#
#
# -----------------------------------------------------------------------------
# 4 AIR
# data available to public on: N/A
#
#
# -----------------------------------------------------------------------------
# 5 HES
# data available to public on: 2012-02-28
#
#
# -----------------------------------------------------------------------------
# 6 HES
# data available to public on: 2013-03-03
#
#
# -----------------------------------------------------------------------------
# 7 HES
# data available to public on: 2014-03-04
#
#
# -----------------------------------------------------------------------------
# 8 HES
# data available to public on: 2015-03-02
#
#
# -----------------------------------------------------------------------------
# 9 HES
# data available to public on: 2016-02-27
#
#
# -----------------------------------------------------------------------------
# 10 HES
# data available to public on: 2018-02-24
#
#
# -----------------------------------------------------------------------------
# 11 HES
# data available to public on: 2019-02-25
#
#
# -----------------------------------------------------------------------------
# 12 AP
# data available to public on: 2012-03-23
#
#
# -----------------------------------------------------------------------------
# 13 AP
# data available to public on: 2013-03-22
#
#
# -----------------------------------------------------------------------------
# 14 AP
# data available to public on: 2014-03-20
#
#
# -----------------------------------------------------------------------------
# 15 AP
# data available to public on: 2015-03-24
#
#
# -----------------------------------------------------------------------------
# 16 AP
# data available to public on: 2016-04-04
#
#
# -----------------------------------------------------------------------------
# 17 AP
# data available to public on: 2018-04-07
#
#
# -----------------------------------------------------------------------------
# 18 AP
# data available to public on: 2019-04-10
#
#
# -----------------------------------------------------------------------------
# 19 APA
# data available to public on: 2012-03-02
#
#
# -----------------------------------------------------------------------------
# 20 APA
# data available to public on: 2013-03-03
#
#
# -----------------------------------------------------------------------------
# 21 APA
# data available to public on: 2014-03-01
#
#
# -----------------------------------------------------------------------------
# 22 APA
# data available to public on: 2015-03-03
#
#
# -----------------------------------------------------------------------------
# 23 APA
# data available to public on: 2019-03-10
#
#
# -----------------------------------------------------------------------------
# 24 SSI
# data available to public on: 2011-04-07
#
#
# -----------------------------------------------------------------------------
# 25 SSI
# data available to public on: 2012-04-07
#
#
# -----------------------------------------------------------------------------
# 26 SSI
# data available to public on: 2016-04-19
#
#
# -----------------------------------------------------------------------------
# 27 SSI
# data available to public on: 2017-04-13
#
#
# -----------------------------------------------------------------------------
# 28 SSI
# data available to public on: 2018-05-29
#
#
# -----------------------------------------------------------------------------
# 29 SSI
# data available to public on: 2019-05-06
#
#
# -----------------------------------------------------------------------------
# 30 TREC
# data available to public on: 2019-04-11
#
#
# -----------------------------------------------------------------------------
# 31 ADM
# data available to public on: 2011-08-26
#
#
# -----------------------------------------------------------------------------
# 32 ADM
# data available to public on: 2012-08-29
#
#
# -----------------------------------------------------------------------------
# 33 ADM
# data available to public on: 2016-02-22
#
#
# -----------------------------------------------------------------------------
# 34 ADM
# data available to public on: 2018-02-17
#
#
# -----------------------------------------------------------------------------
# 35 ADM
# data available to public on: 2019-02-21
#
#
# -----------------------------------------------------------------------------
# 36 SWN
# data available to public on: 2016-02-26
#
#
# -----------------------------------------------------------------------------
# 37 SWN
# data available to public on: 2019-03-14
#
#
# -----------------------------------------------------------------------------
# 38 ARW
# data available to public on: 2012-02-03
#
#
# -----------------------------------------------------------------------------
# 39 ARW
# data available to public on: 2013-02-08
#
#
# -----------------------------------------------------------------------------
# 40 ARW
# data available to public on: 2016-02-10
#
#
# -----------------------------------------------------------------------------
# 41 ARW
# data available to public on: 2019-02-11
#
#
# -----------------------------------------------------------------------------
# 42 ESTE
# data available to public on: 2018-04-14
#
#
# -----------------------------------------------------------------------------
# 43 ESTE
# data available to public on: 2019-04-06
#
#
# -----------------------------------------------------------------------------
# 44 BGG
# data available to public on: N/A
#
#
# -----------------------------------------------------------------------------
# 45 CAL
# data available to public on: 2012-04-04
#
#
# -----------------------------------------------------------------------------
# 46 CBT
# data available to public on: 2011-12-08
#
#
# -----------------------------------------------------------------------------
# 47 CBT
# data available to public on: 2012-12-03
#
#
# -----------------------------------------------------------------------------
# 48 CACI
# data available to public on: 2012-09-06
#
#
# -----------------------------------------------------------------------------
# 49 CACI
# data available to public on: 2013-09-04
#
#
# -----------------------------------------------------------------------------
# 50 CACI
# data available to public on: 2014-09-15
#
#
# -----------------------------------------------------------------------------
# 51 LUB
# data available to public on: 2011-11-16
#
#
# -----------------------------------------------------------------------------
# 52 LUB
# data available to public on: 2012-11-16
#
#
# -----------------------------------------------------------------------------
# 53 LUB
# data available to public on: 2013-11-15
#
#
# -----------------------------------------------------------------------------
# 54 LUB
# data available to public on: 2014-11-21
#
#
# -----------------------------------------------------------------------------
# 55 LUB
# data available to public on: 2015-11-30
#
#
# -----------------------------------------------------------------------------
# 56 LUB
# data available to public on: 2016-12-06
#
#
# -----------------------------------------------------------------------------
# 57 LUB
# data available to public on: 2017-12-07
#
#
# -----------------------------------------------------------------------------
# 58 LUB
# data available to public on: 2018-12-12
#
#
# -----------------------------------------------------------------------------
# 59 CATO
# data available to public on: 2018-03-30
#
#
# -----------------------------------------------------------------------------
# 60 CATO
# data available to public on: 2019-04-08
#
#
# -----------------------------------------------------------------------------
# 61 GCO
# data available to public on: 2018-04-13
#
#
# -----------------------------------------------------------------------------
# 62 GCO
# data available to public on: 2019-04-15
#
#
# -----------------------------------------------------------------------------
# 63 CTL
# data available to public on: 2012-02-29
#
#
# -----------------------------------------------------------------------------
# 64 CTL
# data available to public on: 2014-03-03
#
#
# -----------------------------------------------------------------------------
# 65 CTL
# data available to public on: 2016-02-29
#
#
# -----------------------------------------------------------------------------
# 66 CTL
# data available to public on: 2017-02-28
# -----------------------------------------------------------------------------
# 67 CTL
# data available to public on: 2018-03-06
#
#
# -----------------------------------------------------------------------------
# 68 CTL
# data available to public on: 2019-03-13
#
#
# -----------------------------------------------------------------------------
# 69 CSS
# data available to public on: 2011-06-08
#
#
# -----------------------------------------------------------------------------
# 70 CSS
# data available to public on: 2012-06-08
#
#
# -----------------------------------------------------------------------------
# 71 CSS
# data available to public on: 2013-06-06
#
#
# -----------------------------------------------------------------------------
# 72 CSS
# data available to public on: 2014-06-04
#
#
# -----------------------------------------------------------------------------
# 73 CSS
# data available to public on: 2015-06-09
#
#
# -----------------------------------------------------------------------------
# 74 CSS
# data available to public on: 2016-05-25
#
#
# -----------------------------------------------------------------------------
# 75 CSS
# data available to public on: 2017-06-21
#
#
# -----------------------------------------------------------------------------
# 76 CSS
# data available to public on: 2018-07-02
#
#
# -----------------------------------------------------------------------------
# 77 CSS
# data available to public on: 2019-06-27
#
#
# -----------------------------------------------------------------------------
# 78 CMC
# data available to public on: 2011-11-07
#
#
# -----------------------------------------------------------------------------
# 79 CMC
# data available to public on: 2012-11-05
#
#
# -----------------------------------------------------------------------------
# 80 TAP
# data available to public on: 2012-02-28
#
#
# -----------------------------------------------------------------------------
# 81 TAP
# data available to public on: 2013-02-23
#
#
# -----------------------------------------------------------------------------
# 82 TAP
# data available to public on: 2014-02-18
#
#
# -----------------------------------------------------------------------------
# 83 TAP
# data available to public on: 2019-02-12
#
#
# -----------------------------------------------------------------------------
# 84 GLW
# data available to public on: 2012-02-15
#
#
# -----------------------------------------------------------------------------
# 85 GLW
# data available to public on: 2013-02-18
#
#
# -----------------------------------------------------------------------------
# 86 GLW
# data available to public on: 2014-02-11
#
#
# -----------------------------------------------------------------------------
# 87 GLW
# data available to public on: 2016-02-13
#
#
# -----------------------------------------------------------------------------
# 88 CTS
# data available to public on: 2012-03-08
#
#
# -----------------------------------------------------------------------------
# 89 CW
# data available to public on: 2013-02-27
#
#
# -----------------------------------------------------------------------------
# 90 DAN
# data available to public on: 2012-03-07
#
#
# -----------------------------------------------------------------------------
# 91 DAN
# data available to public on: 2013-02-26
#
#
# -----------------------------------------------------------------------------
# 92 DDS
# data available to public on: 2011-04-01
#
#
# -----------------------------------------------------------------------------
# 93 DDS
# data available to public on: 2012-04-03
#
#
# -----------------------------------------------------------------------------
# 94 DDS
# data available to public on: 2017-03-31
#
#
# -----------------------------------------------------------------------------
# 95 DDS
# data available to public on: 2018-04-10
#
#
# -----------------------------------------------------------------------------
# 96 DDS
# data available to public on: 2019-04-08
#
#
# -----------------------------------------------------------------------------
# 97 DCO
# data available to public on: 2012-03-15
#
#
# -----------------------------------------------------------------------------
# 98 DCO
# data available to public on: 2013-03-22
#
#
# -----------------------------------------------------------------------------
# 99 DCO
# data available to public on: 2015-04-16
#
#
# -----------------------------------------------------------------------------
# 100 DCO
# data available to public on: 2016-03-24
#
#
# -----------------------------------------------------------------------------
# 101 KODK
# data available to public on: 2018-04-09
#
#
# -----------------------------------------------------------------------------
# 102 KODK
# data available to public on: 2019-04-16
#
#
# -----------------------------------------------------------------------------
# 103 EBF
# data available to public on: 2011-05-11
#
#
# -----------------------------------------------------------------------------
# 104 EBF
# data available to public on: 2012-05-16
#
#
# -----------------------------------------------------------------------------
# 105 EBF
# data available to public on: 2013-05-14
#
#
# -----------------------------------------------------------------------------
# 106 EBF
# data available to public on: 2014-05-15
#
#
# -----------------------------------------------------------------------------
# 107 EQT
# data available to public on: 2016-02-15
#
#
# -----------------------------------------------------------------------------
# 108 EQT
# data available to public on: 2018-02-19
#
#
# -----------------------------------------------------------------------------
# 109 EQT
# data available to public on: 2019-02-16
#
#
# -----------------------------------------------------------------------------
# 110 FOE
# data available to public on: 2012-03-22
#
#
# -----------------------------------------------------------------------------
# 111 F
# data available to public on: 2019-02-26
#
#
# -----------------------------------------------------------------------------
# 112 GLT
# data available to public on: 2016-03-21
#
#
# -----------------------------------------------------------------------------
# 113 GLT
# data available to public on: 2019-03-13
#
#
# -----------------------------------------------------------------------------
# 114 GTN
# data available to public on: 2012-03-27
#
#
# -----------------------------------------------------------------------------
# 115 GTN
# data available to public on: 2013-04-02
#
#
# -----------------------------------------------------------------------------
# 116 GTN
# data available to public on: 2019-03-12
#
#
# -----------------------------------------------------------------------------
# 117 HHS
# data available to public on: 2013-03-26
#
#
# -----------------------------------------------------------------------------
# 118 HP
# data available to public on: 2015-11-25
#
#
# -----------------------------------------------------------------------------
# 119 HPQ
# data available to public on: 2012-12-31
#
#
# -----------------------------------------------------------------------------
# 120 HFC
# data available to public on: 2012-03-16
#
#
# -----------------------------------------------------------------------------
# 121 HFC
# data available to public on: 2015-03-06
#
#
# -----------------------------------------------------------------------------
# 122 HFC
# data available to public on: 2017-03-08
#
#
# -----------------------------------------------------------------------------
# 123 GFF
# data available to public on: 2011-11-29
#
#
# -----------------------------------------------------------------------------
# 124 GFF
# data available to public on: 2012-11-28
#
#
# -----------------------------------------------------------------------------
# 125 GFF
# data available to public on: 2013-12-03
#
#
# -----------------------------------------------------------------------------
# 126 GFF
# data available to public on: 2014-11-24
#
#
# -----------------------------------------------------------------------------
# 127 AXE
# data available to public on: 2019-03-10
#
#
# -----------------------------------------------------------------------------
# 128 JEC
# data available to public on: 2015-11-24
#
#
# -----------------------------------------------------------------------------
# 129 KFY
# data available to public on: 2013-07-02
#
#
# -----------------------------------------------------------------------------
# 130 LCI
# data available to public on: 2012-09-20
#
#
# -----------------------------------------------------------------------------
# 131 LCI
# data available to public on: 2018-08-30
#
#
# -----------------------------------------------------------------------------
# 132 LCI
# data available to public on: N/A
# -----------------------------------------------------------------------------
# 133 VHI
# data available to public on: 2016-03-24
#
#
# -----------------------------------------------------------------------------
# 134 VHI
# data available to public on: 2019-03-28
#
#
# -----------------------------------------------------------------------------
# 135 LPX
# data available to public on: 2012-03-18
#
#
# -----------------------------------------------------------------------------
# 136 LXU
# data available to public on: 2016-03-22
#
#
# -----------------------------------------------------------------------------
# 137 LXU
# data available to public on: 2017-03-15
#
#
# -----------------------------------------------------------------------------
# 138 LXU
# data available to public on: 2018-03-20
#
#
# -----------------------------------------------------------------------------
# 139 LXU
# data available to public on: 2019-03-18
#
#
# -----------------------------------------------------------------------------
# 140 LDL
# data available to public on: 2012-03-21
#
#
# -----------------------------------------------------------------------------
# 141 LDL
# data available to public on: 2019-03-18
#
#
# -----------------------------------------------------------------------------
# 142 MTW
# data available to public on: 2019-02-21
#
#
# -----------------------------------------------------------------------------
# 143 MCS
# data available to public on: 2011-08-22
#
#
# -----------------------------------------------------------------------------
# 144 MCS
# data available to public on: 2012-08-16
#
#
# -----------------------------------------------------------------------------
# 145 MCS
# data available to public on: 2013-08-20
#
#
# -----------------------------------------------------------------------------
# 146 ETR
# data available to public on: 2013-02-28
#
#
# -----------------------------------------------------------------------------
# 147 ETR
# data available to public on: 2014-03-02
#
#
# -----------------------------------------------------------------------------
# 148 THC
# data available to public on: 2016-02-24
#
#
# -----------------------------------------------------------------------------
# 149 THC
# data available to public on: 2017-03-16
#
#
# -----------------------------------------------------------------------------
# 150 THC
# data available to public on: 2018-03-13
#
#
# -----------------------------------------------------------------------------
# 151 THC
# data available to public on: 2019-03-14
#
#
# -----------------------------------------------------------------------------
# 152 GPX
# data available to public on: 2019-04-18
#
#
# -----------------------------------------------------------------------------
# 153 NR
# data available to public on: 2016-03-21
#
#
# -----------------------------------------------------------------------------
# 154 NR
# data available to public on: 2019-03-11
#
#
# -----------------------------------------------------------------------------
# 155 NL
# data available to public on: 2016-03-23
#
#
# -----------------------------------------------------------------------------
# 156 NL
# data available to public on: 2019-04-01
#
#
# -----------------------------------------------------------------------------
# 157 NBL
# data available to public on: 2019-02-20
#
#
# -----------------------------------------------------------------------------
# 158 MOV
# data available to public on: 2011-04-14
#
#
# -----------------------------------------------------------------------------
# 159 MOV
# data available to public on: 2012-04-10
#
#
# -----------------------------------------------------------------------------
# 160 OII
# data available to public on: 2019-03-19
#
#
# -----------------------------------------------------------------------------
# 161 OLN
# data available to public on: 2016-03-16
#
#
# -----------------------------------------------------------------------------
# 162 OLN
# data available to public on: 2019-03-19
#
#
# -----------------------------------------------------------------------------
# 163 OSG
# data available to public on: 2012-03-20
#
#
# -----------------------------------------------------------------------------
# 164 OSG
# data available to public on: 2013-09-06
#
#
# -----------------------------------------------------------------------------
# 165 OSG
# data available to public on: 2016-03-18
#
#
# -----------------------------------------------------------------------------
# 166 OSG
# data available to public on: 2017-04-11
#
#
# -----------------------------------------------------------------------------
# 167 OSG
# data available to public on: 2018-04-16
#
#
# -----------------------------------------------------------------------------
# 168 OSG
# data available to public on: 2019-04-12
#
#
# -----------------------------------------------------------------------------
# 169 OMI
# data available to public on: 2018-03-12
#
#
# -----------------------------------------------------------------------------
# 170 OMI
# data available to public on: 2019-03-19
#
#
# -----------------------------------------------------------------------------
# 171 PKD
# data available to public on: 2013-03-23
#
#
# -----------------------------------------------------------------------------
# 172 PKD
# data available to public on: 2015-03-19
#
#
# -----------------------------------------------------------------------------
# 173 PKD
# data available to public on: 2016-03-22
#
#
# -----------------------------------------------------------------------------
# 174 PKD
# data available to public on: 2017-03-17
#
#
# -----------------------------------------------------------------------------
# 175 PKD
# data available to public on: 2018-04-08
#
#
# -----------------------------------------------------------------------------
# 176 PKD
# data available to public on: 2019-06-07
#
#
# -----------------------------------------------------------------------------
# 177 TPC
# data available to public on: 2012-03-26
#
#
# -----------------------------------------------------------------------------
# 178 TPC
# data available to public on: 2013-03-20
#
#
# -----------------------------------------------------------------------------
# 179 TPC
# data available to public on: 2014-03-10
#
#
# -----------------------------------------------------------------------------
# 180 TPC
# data available to public on: 2015-03-14
#
#
# -----------------------------------------------------------------------------
# 181 TPC
# data available to public on: 2016-03-15
#
#
# -----------------------------------------------------------------------------
# 182 TPC
# data available to public on: 2017-03-09
#
#
# -----------------------------------------------------------------------------
# 183 TPC
# data available to public on: 2018-03-31
#
#
# -----------------------------------------------------------------------------
# 184 TPC
# data available to public on: 2019-03-01
#
#
# -----------------------------------------------------------------------------
# 185 RAD
# data available to public on: 2019-05-19
#
#
# -----------------------------------------------------------------------------
# 186 R
# data available to public on: 2019-03-08
#
#
# -----------------------------------------------------------------------------
# 187 LUV
# data available to public on: 2012-02-10
#
#
# -----------------------------------------------------------------------------
# 188 LUV
# data available to public on: 2013-02-08
#
#
# -----------------------------------------------------------------------------
# 189 CVX
# data available to public on: 2016-02-28
#
#
# -----------------------------------------------------------------------------
# 190 SCX
# data available to public on: 2011-09-19
#
#
# -----------------------------------------------------------------------------
# 191 SCX
# data available to public on: 2012-09-17
#
#
# -----------------------------------------------------------------------------
# 192 SCX
# data available to public on: 2013-09-18
#
#
# -----------------------------------------------------------------------------
# 193 SCX
# data available to public on: 2014-09-17
#
#
# -----------------------------------------------------------------------------
# 194 SCX
# data available to public on: 2015-09-04
#
#
# -----------------------------------------------------------------------------
# 195 SCX
# data available to public on: 2016-09-07
#
#
# -----------------------------------------------------------------------------
# 196 SCX
# data available to public on: 2017-09-05
# -----------------------------------------------------------------------------
# 197 SCX
# data available to public on: 2018-09-14
#
#
# -----------------------------------------------------------------------------
# 198 SCX
# data available to public on: N/A
#
#
# -----------------------------------------------------------------------------
# 199 SUP
# data available to public on: 2012-03-20
#
#
# -----------------------------------------------------------------------------
# 200 SUP
# data available to public on: 2013-03-27
#
#
# -----------------------------------------------------------------------------
# 201 SUP
# data available to public on: 2014-03-27
#
#
# -----------------------------------------------------------------------------
# 202 SUP
# data available to public on: 2015-03-27
#
#
# -----------------------------------------------------------------------------
# 203 SUP
# data available to public on: 2016-04-01
#
#
# -----------------------------------------------------------------------------
# 204 SUP
# data available to public on: 2018-03-30
#
#
# -----------------------------------------------------------------------------
# 205 SUP
# data available to public on: 2019-03-21
#
#
# -----------------------------------------------------------------------------
# 206 TEX
# data available to public on: 2012-03-19
#
#
# -----------------------------------------------------------------------------
# 207 TEX
# data available to public on: 2016-02-24
#
#
# -----------------------------------------------------------------------------
# 208 TMO
# data available to public on: 2012-03-02
#
#
# -----------------------------------------------------------------------------
# 209 TDW
# data available to public on: 2012-05-24
#
#
# -----------------------------------------------------------------------------
# 210 TDW
# data available to public on: 2013-05-29
#
#
# -----------------------------------------------------------------------------
# 211 TDW
# data available to public on: 2014-06-03
#
#
# -----------------------------------------------------------------------------
# 212 TDW
# data available to public on: 2015-06-09
#
#
# -----------------------------------------------------------------------------
# 213 TDW
# data available to public on: 2016-06-08
#
#
# -----------------------------------------------------------------------------
# 214 TDW
# data available to public on: 2017-06-23
#
#
# -----------------------------------------------------------------------------
# 215 TDW
# data available to public on: 2018-05-04
#
#
# -----------------------------------------------------------------------------
# 216 TDW
# data available to public on: 2019-03-06
#
#
# -----------------------------------------------------------------------------
# 217 TSN
# data available to public on: 2011-11-23
#
#
# -----------------------------------------------------------------------------
# 218 TSN
# data available to public on: 2012-11-19
#
#
# -----------------------------------------------------------------------------
# 219 UFI
# data available to public on: 2011-09-15
#
#
# -----------------------------------------------------------------------------
# 220 UFI
# data available to public on: 2012-09-09
#
#
# -----------------------------------------------------------------------------
# 221 UFI
# data available to public on: N/A
#
#
# -----------------------------------------------------------------------------
# 222 MRO
# data available to public on: 2012-03-03
#
#
# -----------------------------------------------------------------------------
# 223 MRO
# data available to public on: 2013-02-22
#
#
# -----------------------------------------------------------------------------
# 224 MRO
# data available to public on: 2015-03-03
#
#
# -----------------------------------------------------------------------------
# 225 MRO
# data available to public on: 2016-02-26
#
#
# -----------------------------------------------------------------------------
# 226 MRO
# data available to public on: 2017-02-25
#
#
# -----------------------------------------------------------------------------
# 227 MRO
# data available to public on: 2019-02-27
#
#
# -----------------------------------------------------------------------------
# 228 S
# data available to public on: 2012-02-27
#
#
# -----------------------------------------------------------------------------
# 229 S
# data available to public on: 2015-06-09
#
#
# -----------------------------------------------------------------------------
# 230 S
# data available to public on: 2016-05-25
#
#
# -----------------------------------------------------------------------------
# 231 S
# data available to public on: 2018-06-08
#
#
# -----------------------------------------------------------------------------
# 232 S
# data available to public on: 2019-06-05
#
#
# -----------------------------------------------------------------------------
# 233 UVV
# data available to public on: 2011-06-05
#
#
# -----------------------------------------------------------------------------
# 234 UVV
# data available to public on: 2012-06-06
#
#
# -----------------------------------------------------------------------------
# 235 UVV
# data available to public on: 2013-06-04
#
#
# -----------------------------------------------------------------------------
# 236 UVV
# data available to public on: 2014-06-03
#
#
# -----------------------------------------------------------------------------
# 237 UVV
# data available to public on: 2015-06-07
#
#
# -----------------------------------------------------------------------------
# 238 UVV
# data available to public on: 2016-06-07
#
#
# -----------------------------------------------------------------------------
# 239 UVV
# data available to public on: 2018-06-05
#
#
# -----------------------------------------------------------------------------
# 240 UVV
# data available to public on: 2019-05-28
#
#
# -----------------------------------------------------------------------------
# 241 VSH
# data available to public on: 2012-03-06
#
#
# -----------------------------------------------------------------------------
# 242 VSH
# data available to public on: 2013-02-25
#
#
# -----------------------------------------------------------------------------
# 243 VSH
# data available to public on: 2014-02-23
#
#
# -----------------------------------------------------------------------------
# 244 VSH
# data available to public on: 2015-02-23
#
#
# -----------------------------------------------------------------------------
# 245 VSH
# data available to public on: 2016-02-17
#
#
# -----------------------------------------------------------------------------
# 246 GHC
# data available to public on: 2012-03-01
#
#
# -----------------------------------------------------------------------------
# 247 GHC
# data available to public on: 2013-03-01
#
#
# -----------------------------------------------------------------------------
# 248 GHC
# data available to public on: 2016-03-10
#
#
# -----------------------------------------------------------------------------
# 249 GHC
# data available to public on: 2017-03-13
#
#
# -----------------------------------------------------------------------------
# 250 GHC
# data available to public on: 2018-02-27
#
#
# -----------------------------------------------------------------------------
# 251 GHC
# data available to public on: 2019-03-08
#
#
# -----------------------------------------------------------------------------
# 252 AVA
# data available to public on: 2012-03-08
#
#
# -----------------------------------------------------------------------------
# 253 AVA
# data available to public on: 2013-03-04
#
#
# -----------------------------------------------------------------------------
# 254 WMK
# data available to public on: 2018-03-21
#
#
# -----------------------------------------------------------------------------
# 255 WHR
# data available to public on: 2012-02-22
#
#
# -----------------------------------------------------------------------------
# 256 WMB
# data available to public on: 2016-03-01
#
#
# -----------------------------------------------------------------------------
# 257 CDE
# data available to public on: 2012-03-04
#
#
# -----------------------------------------------------------------------------
# 258 CDE
# data available to public on: 2013-03-04
#
#
# -----------------------------------------------------------------------------
# 259 CDE
# data available to public on: 2014-03-15
#
#
# -----------------------------------------------------------------------------
# 260 CDE
# data available to public on: 2015-03-16
#
#
# -----------------------------------------------------------------------------
# 261 CDE
# data available to public on: 2016-02-16
#
#
# -----------------------------------------------------------------------------
# 262 CDE
# data available to public on: 2019-03-23
# -----------------------------------------------------------------------------
# 263 HVT
# data available to public on: 2012-03-22
#
#
# -----------------------------------------------------------------------------
# 264 PIR
# data available to public on: 2018-05-25
#
#
# -----------------------------------------------------------------------------
# 265 SU
# data available to public on: 2012-03-19
#
#
# -----------------------------------------------------------------------------
# 266 MUX
# data available to public on: 2014-04-10
#
#
# -----------------------------------------------------------------------------
# 267 MUX
# data available to public on: 2015-04-09
#
#
# -----------------------------------------------------------------------------
# 268 MUX
# data available to public on: 2016-04-05
#
#
# -----------------------------------------------------------------------------
# 269 VAL
# data available to public on: N/A
#
#
# -----------------------------------------------------------------------------
# 270 VAL
# data available to public on: N/A
#
#
# -----------------------------------------------------------------------------
# 271 VAL
# data available to public on: N/A
#
#
# -----------------------------------------------------------------------------
# 272 VAL
# data available to public on: N/A
#
#
# -----------------------------------------------------------------------------
# 273 VAL
# data available to public on: N/A
#
#
# -----------------------------------------------------------------------------
# 274 VAL
# data available to public on: N/A
#
#
# -----------------------------------------------------------------------------
# 275 VAL
# data available to public on: N/A
#
#
# -----------------------------------------------------------------------------
# 276 VAL
# data available to public on: N/A
#
#
# -----------------------------------------------------------------------------
# 277 RRC
# data available to public on: 2018-02-28
#
#
# -----------------------------------------------------------------------------
# 278 RRC
# data available to public on: 2019-03-13
#
#
# -----------------------------------------------------------------------------
# 279 ENZ
# data available to public on: 2012-10-17
#
#
# -----------------------------------------------------------------------------
# 280 TISI
# data available to public on: 2018-03-22
#
#
# -----------------------------------------------------------------------------
# 281 TISI
# data available to public on: 2019-04-02
#
#
# -----------------------------------------------------------------------------
# 282 KEG
# data available to public on: 2013-03-08
#
#
# -----------------------------------------------------------------------------
# 283 KEG
# data available to public on: 2014-03-10
#
#
# -----------------------------------------------------------------------------
# 284 KEG
# data available to public on: 2015-02-26
#
#
# -----------------------------------------------------------------------------
# 285 KEG
# data available to public on: 2016-03-30
#
#
# -----------------------------------------------------------------------------
# 286 KEG
# data available to public on: 2019-03-16
#
#
# -----------------------------------------------------------------------------
# 287 AN
# data available to public on: 2019-03-11
#
#
# -----------------------------------------------------------------------------
# 288 SBOW
# data available to public on: 2013-03-06
#
#
# -----------------------------------------------------------------------------
# 289 SBOW
# data available to public on: 2014-03-22
#
#
# -----------------------------------------------------------------------------
# 290 SBOW
# data available to public on: 2015-03-24
#
#
# -----------------------------------------------------------------------------
# 291 SBOW
# data available to public on: 2019-04-03
#
#
# -----------------------------------------------------------------------------
# 292 KGC
# data available to public on: 2012-02-18
#
#
# -----------------------------------------------------------------------------
# 293 KGC
# data available to public on: 2013-02-15
#
#
# -----------------------------------------------------------------------------
# 294 KGC
# data available to public on: 2014-02-14
#
#
# -----------------------------------------------------------------------------
# 295 KGC
# data available to public on: 2015-02-12
#
#
# -----------------------------------------------------------------------------
# 296 KGC
# data available to public on: 2016-02-10
#
#
# -----------------------------------------------------------------------------
# 297 KGC
# data available to public on: 2017-02-16
#
#
# -----------------------------------------------------------------------------
# 298 KGC
# data available to public on: 2018-03-13
#
#
# -----------------------------------------------------------------------------
# 299 KGC
# data available to public on: 2019-02-17
#
#
# -----------------------------------------------------------------------------
# 300 MDR
# data available to public on: 2015-03-17
#
#
# -----------------------------------------------------------------------------
# 301 MDR
# data available to public on: 2016-02-29
#
#
# -----------------------------------------------------------------------------
# 302 MDR
# data available to public on: 2017-02-23
#
#
# -----------------------------------------------------------------------------
# 303 MDR
# data available to public on: 2018-03-09
#
#
# -----------------------------------------------------------------------------
# 304 MDR
# data available to public on: 2019-03-11
#
#
# -----------------------------------------------------------------------------
# 305 PAR
# data available to public on: 2012-04-29
#
#
# -----------------------------------------------------------------------------
# 306 PAR
# data available to public on: 2013-04-11
#
#
# -----------------------------------------------------------------------------
# 307 PAR
# data available to public on: 2014-04-14
#
#
# -----------------------------------------------------------------------------
# 308 ACCO
# data available to public on: 2019-04-04
#
#
# -----------------------------------------------------------------------------
# 309 RGS
# data available to public on: 2011-09-07
#
#
# -----------------------------------------------------------------------------
# 310 RGS
# data available to public on: 2012-09-06
#
#
# -----------------------------------------------------------------------------
# 311 RGS
# data available to public on: 2013-09-04
#
#
# -----------------------------------------------------------------------------
# 312 RGS
# data available to public on: 2014-09-03
#
#
# -----------------------------------------------------------------------------
# 313 RGS
# data available to public on: 2016-08-31
#
#
# -----------------------------------------------------------------------------
# 314 RGS
# data available to public on: 2017-09-04
#
#
# -----------------------------------------------------------------------------
# 315 MUR
# data available to public on: 2015-03-02
#
#
# -----------------------------------------------------------------------------
# 316 MUR
# data available to public on: 2016-02-28
#
#
# -----------------------------------------------------------------------------
# 317 MUR
# data available to public on: 2017-02-27
#
#
# -----------------------------------------------------------------------------
# 318 MUR
# data available to public on: 2018-03-13
#
#
# -----------------------------------------------------------------------------
# 319 MUR
# data available to public on: 2019-03-13
#
#
# -----------------------------------------------------------------------------
# 320 HL
# data available to public on: 2014-02-24
#
#
# -----------------------------------------------------------------------------
# 321 HL
# data available to public on: 2015-02-22
#
#
# -----------------------------------------------------------------------------
# 322 HL
# data available to public on: 2016-03-02
#
#
# -----------------------------------------------------------------------------
# 323 HL
# data available to public on: 2018-03-28
#
#
# -----------------------------------------------------------------------------
# 324 HL
# data available to public on: 2019-03-24
#
#
# -----------------------------------------------------------------------------
# 325 TRCO
# data available to public on: 2016-03-07
#
#
# -----------------------------------------------------------------------------
# 326 TRCO
# data available to public on: 2017-03-28
#
#
# -----------------------------------------------------------------------------
# 327 TRCO
# data available to public on: 2018-03-20
# -----------------------------------------------------------------------------
# 328 TRCO
# data available to public on: 2019-03-13
#
#
# -----------------------------------------------------------------------------
# 329 ATGE
# data available to public on: 2015-08-31
#
#
# -----------------------------------------------------------------------------
# 330 ATGE
# data available to public on: 2016-09-02
#
#
# -----------------------------------------------------------------------------
# 331 T
# data available to public on: 2019-02-25
#
#
# -----------------------------------------------------------------------------
# 332 IVC
# data available to public on: 2012-03-16
#
#
# -----------------------------------------------------------------------------
# 333 IVC
# data available to public on: 2013-04-01
#
#
# -----------------------------------------------------------------------------
# 334 IVC
# data available to public on: 2014-03-21
#
#
# -----------------------------------------------------------------------------
# 335 IVC
# data available to public on: 2015-03-18
#
#
# -----------------------------------------------------------------------------
# 336 IVC
# data available to public on: 2016-03-28
#
#
# -----------------------------------------------------------------------------
# 337 IVC
# data available to public on: 2017-03-23
#
#
# -----------------------------------------------------------------------------
# 338 IVC
# data available to public on: 2019-03-21
#
#
# -----------------------------------------------------------------------------
# 339 REX
# data available to public on: 2011-04-19
#
#
# -----------------------------------------------------------------------------
# 340 REX
# data available to public on: 2012-04-10
#
#
# -----------------------------------------------------------------------------
# 341 REX
# data available to public on: 2013-04-17
#
#
# -----------------------------------------------------------------------------
# 342 REX
# data available to public on: 2014-05-02
#
#
# -----------------------------------------------------------------------------
# 343 REX
# data available to public on: 2015-05-19
#
#
# -----------------------------------------------------------------------------
# 344 REX
# data available to public on: 2016-04-08
#
#
# -----------------------------------------------------------------------------
# 345 REX
# data available to public on: 2019-04-08
#
#
# -----------------------------------------------------------------------------
# 346 MGA
# data available to public on: 2012-03-26
#
#
# -----------------------------------------------------------------------------
# 347 GOLD
# data available to public on: 2015-02-24
#
#
# -----------------------------------------------------------------------------
# 348 GOLD
# data available to public on: 2016-02-23
#
#
# -----------------------------------------------------------------------------
# 349 CLF
# data available to public on: 2013-02-13
#
#
# -----------------------------------------------------------------------------
# 350 CLF
# data available to public on: 2014-02-16
#
#
# -----------------------------------------------------------------------------
# 351 OSK
# data available to public on: 2011-11-21
#
#
# -----------------------------------------------------------------------------
# 352 CRY
# data available to public on: 2012-02-22
#
#
# -----------------------------------------------------------------------------
# 353 POR
# data available to public on: 2012-03-07
#
#
# -----------------------------------------------------------------------------
# 354 POR
# data available to public on: 2013-02-25
#
#
# -----------------------------------------------------------------------------
# 355 INT
# data available to public on: 2018-03-13
#
#
# -----------------------------------------------------------------------------
# 356 INT
# data available to public on: 2019-03-18
#
#
# -----------------------------------------------------------------------------
# 357 MGM
# data available to public on: 2012-03-19
#
#
# -----------------------------------------------------------------------------
# 358 MGM
# data available to public on: 2013-03-15
#
#
# -----------------------------------------------------------------------------
# 359 MGM
# data available to public on: 2019-03-12
#
#
# -----------------------------------------------------------------------------
# 360 NC
# data available to public on: 2016-03-21
#
#
# -----------------------------------------------------------------------------
# 361 NC
# data available to public on: 2018-03-23
#
#
# -----------------------------------------------------------------------------
# 362 NC
# data available to public on: 2019-03-11
#
#
# -----------------------------------------------------------------------------
# 363 UNT
# data available to public on: 2012-03-06
#
#
# -----------------------------------------------------------------------------
# 364 UNT
# data available to public on: 2013-03-11
#
#
# -----------------------------------------------------------------------------
# 365 UNT
# data available to public on: 2014-03-07
#
#
# -----------------------------------------------------------------------------
# 366 UNT
# data available to public on: 2015-03-04
#
#
# -----------------------------------------------------------------------------
# 367 UNT
# data available to public on: 2016-03-16
#
#
# -----------------------------------------------------------------------------
# 368 UNT
# data available to public on: 2017-03-15
#
#
# -----------------------------------------------------------------------------
# 369 UNT
# data available to public on: 2018-03-19
#
#
# -----------------------------------------------------------------------------
# 370 UNT
# data available to public on: 2019-03-18
#
#
# -----------------------------------------------------------------------------
# 371 BPL
# data available to public on: 2019-03-26
#
#
# -----------------------------------------------------------------------------
# 372 CCL
# data available to public on: 2012-02-01
#
#
# -----------------------------------------------------------------------------
# 373 CCL
# data available to public on: 2014-01-31
#
#
# -----------------------------------------------------------------------------
# 374 USM
# data available to public on: 2012-03-15
#
#
# -----------------------------------------------------------------------------
# 375 USM
# data available to public on: 2013-03-12
#
#
# -----------------------------------------------------------------------------
# 376 USM
# ...
# 1333 ESI
# data available to public on: 2017-03-31
#
#
# -----------------------------------------------------------------------------
# 1334 ESI
# data available to public on: 2018-04-04
#
#
# -----------------------------------------------------------------------------
# 1335 ENBL
# data available to public on: 2017-03-02
#
#
# -----------------------------------------------------------------------------
# 1336 ENBL
# data available to public on: 2018-02-23
#
#
# -----------------------------------------------------------------------------
# 1337 ENBL
# data available to public on: 2019-03-02
#
#
# -----------------------------------------------------------------------------
# 1338 ENLC
# data available to public on: 2017-02-16
#
#
# -----------------------------------------------------------------------------
# 1339 ENLC
# data available to public on: 2018-03-06
#
#
# -----------------------------------------------------------------------------
# 1340 ENLC
# data available to public on: 2019-03-05
#
#
# -----------------------------------------------------------------------------
# 1341 PRTY
# data available to public on: 2019-03-31
#
#
# -----------------------------------------------------------------------------
# 1342 PE
# data available to public on: 2019-03-26
#
#
# -----------------------------------------------------------------------------
# 1343 RUBI
# data available to public on: 2017-04-10
#
#
# -----------------------------------------------------------------------------
# 1344 RUBI
# data available to public on: 2018-04-15
#
#
# -----------------------------------------------------------------------------
# 1345 LPG
# data available to public on: 2017-06-23
#
#
# -----------------------------------------------------------------------------
# 1346 LPG
# data available to public on: 2018-07-25
#
#
# -----------------------------------------------------------------------------
# 1347 LPG
# data available to public on: 2019-06-18
#
#
# -----------------------------------------------------------------------------
# 1348 PSV
# data available to public on: 2017-05-03
#
#
# -----------------------------------------------------------------------------
# 1349 PSV
# data available to public on: 2018-05-17
#
#
# -----------------------------------------------------------------------------
# 1350 PSV
# data available to public on: 2019-06-12
#
#
# -----------------------------------------------------------------------------
# 1351 RYAM
# data available to public on: 2019-03-17
#
#
# -----------------------------------------------------------------------------
# 1352 TMST
# data available to public on: 2017-03-28
#
#
# -----------------------------------------------------------------------------
# 1353 TMST
# data available to public on: 2018-03-11
#
#
# -----------------------------------------------------------------------------
# 1354 TMST
# data available to public on: 2019-03-02
#
#
# -----------------------------------------------------------------------------
# 1355 GLOP
# data available to public on: 2017-03-07
#
#
# -----------------------------------------------------------------------------
# 1356 GLOP
# data available to public on: 2018-04-18
#
#
# -----------------------------------------------------------------------------
# 1357 GLOP
# data available to public on: 2019-03-29
#
#
# -----------------------------------------------------------------------------
# 1358 VRTV
# data available to public on: 2018-03-20
#
#
# -----------------------------------------------------------------------------
# 1359 VRTV
# data available to public on: 2019-03-20
#
#
# -----------------------------------------------------------------------------
# 1360 DNOW
# data available to public on: 2018-02-19
#
#
# -----------------------------------------------------------------------------
# 1361 DNOW
# data available to public on: 2019-02-19
#
#
# -----------------------------------------------------------------------------
# 1362 GMS
# data available to public on: None
#
#
# -----------------------------------------------------------------------------
# 1363 MR
# data available to public on: 2018-04-12
#
#
# -----------------------------------------------------------------------------
# 1364 MR
# data available to public on: 2019-04-09
#
#
# -----------------------------------------------------------------------------
# 1365 VEC
# data available to public on: 2019-02-28
#
#
# -----------------------------------------------------------------------------
# 1366 HMLP
# data available to public on: 2019-05-22
#
#
# -----------------------------------------------------------------------------
# 1367 NEP
# data available to public on: 2017-03-10
#
#
# -----------------------------------------------------------------------------
# 1368 NEP
# data available to public on: 2018-03-06
#
#
# -----------------------------------------------------------------------------
# 1369 NEP
# data available to public on: 2019-03-04
#
#
# -----------------------------------------------------------------------------
# 1370 EURN
# data available to public on: 2016-04-19
#
#
# -----------------------------------------------------------------------------
# 1371 EURN
# data available to public on: 2017-04-13
# -----------------------------------------------------------------------------
# 1372 EURN
# data available to public on: 2018-05-23
#
#
# -----------------------------------------------------------------------------
# 1373 EURN
# data available to public on: 2019-04-30
#
#
# -----------------------------------------------------------------------------
# 1374 WLKP
# data available to public on: 2017-04-13
#
#
# -----------------------------------------------------------------------------
# 1375 WLKP
# data available to public on: 2018-04-24
#
#
# -----------------------------------------------------------------------------
# 1376 WLKP
# data available to public on: 2019-04-19
#
#
# -----------------------------------------------------------------------------
# 1377 FCAU
# data available to public on: 2019-03-30
#
#
# -----------------------------------------------------------------------------
# 1378 ATTO
# data available to public on: 2019-04-16
#
#
# -----------------------------------------------------------------------------
# 1379 VSLR
# data available to public on: 2017-04-10
#
#
# -----------------------------------------------------------------------------
# 1380 VSLR
# data available to public on: 2018-04-10
#
#
# -----------------------------------------------------------------------------
# 1381 VSLR
# data available to public on: 2019-03-24
#
#
# -----------------------------------------------------------------------------
# 1382 KEN
# data available to public on: 2018-06-16
#
#
# -----------------------------------------------------------------------------
# 1383 KEN
# data available to public on: 2019-05-04
#
#
# -----------------------------------------------------------------------------
# 1384 CJ
# data available to public on: 2015-03-10
#
#
# -----------------------------------------------------------------------------
# 1385 CJ
# data available to public on: 2016-03-25
#
#
# -----------------------------------------------------------------------------
# 1386 CJ
# data available to public on: 2019-03-15
#
#
# -----------------------------------------------------------------------------
# 1387 VSTO
# data available to public on: 2017-06-02
#
#
# -----------------------------------------------------------------------------
# 1388 VSTO
# data available to public on: 2018-06-01
#
#
# -----------------------------------------------------------------------------
# 1389 VSTO
# data available to public on: 2019-06-03
#
#
# -----------------------------------------------------------------------------
# 1390 JAX
# data available to public on: 2012-04-25
#
#
# -----------------------------------------------------------------------------
# 1391 JAX
# data available to public on: 2019-04-10
#
#
# -----------------------------------------------------------------------------
# 1392 QSR
# data available to public on: 2015-03-18
#
#
# -----------------------------------------------------------------------------
# 1393 IGT
# data available to public on: 2019-03-11
#
#
# -----------------------------------------------------------------------------
# 1394 SUM
# data available to public on: 2019-02-11
#
#
# -----------------------------------------------------------------------------
# 1395 BKI
# data available to public on: 2016-03-15
#
#
# -----------------------------------------------------------------------------
# 1396 OR
# data available to public on: 2014-04-01
#
#
# -----------------------------------------------------------------------------
# 1397 OR
# data available to public on: 2017-03-30
#
#
# -----------------------------------------------------------------------------
# 1398 OR
# data available to public on: 2018-03-22
#
#
# -----------------------------------------------------------------------------
# 1399 OR
# data available to public on: 2019-03-23
#
#
# -----------------------------------------------------------------------------
# 1400 EVH
# data available to public on: 2018-04-02
#
#
# -----------------------------------------------------------------------------
# 1401 TGE
# data available to public on: 2018-02-28
#
#
# -----------------------------------------------------------------------------
# 1402 BNED
# data available to public on: 2018-07-02
#
#
# -----------------------------------------------------------------------------
# 1403 BNED
# data available to public on: None
#
#
# -----------------------------------------------------------------------------
# 1404 AGR
# data available to public on: 2018-04-02
#
#
# -----------------------------------------------------------------------------
# 1405 AGR
# data available to public on: 2019-03-21
#
#
# -----------------------------------------------------------------------------
# 1406 GCI
# data available to public on: 2019-03-19
#
#
# -----------------------------------------------------------------------------
# 1407 EXTN
# data available to public on: 2019-03-20
#
#
# -----------------------------------------------------------------------------
# 1408 HPE
# data available to public on: 2018-12-13
#
#
# -----------------------------------------------------------------------------
# 1409 NBLX
# data available to public on: 2019-04-12
#
#
# -----------------------------------------------------------------------------
# 1410 BBU
# data available to public on: 2019-04-09
#
#
# -----------------------------------------------------------------------------
# 1411 AFI
# data available to public on: 2019-03-15
#
#
# -----------------------------------------------------------------------------
# 1412 FTS
# data available to public on: 2013-04-02
#
#
# -----------------------------------------------------------------------------
# 1413 FTS
# data available to public on: 2014-04-01
#
#
# -----------------------------------------------------------------------------
# 1414 FTS
# data available to public on: 2015-02-25
#
#
# -----------------------------------------------------------------------------
# 1415 FTS
# data available to public on: 2016-02-23
#
#
# -----------------------------------------------------------------------------
# 1416 FTS
# data available to public on: 2017-02-22
#
#
# -----------------------------------------------------------------------------
# 1417 FTS
# data available to public on: 2018-02-25
#
#
# -----------------------------------------------------------------------------
# 1418 FTS
# data available to public on: 2019-03-15
#
#
# -----------------------------------------------------------------------------
# 1419 ASH
# data available to public on: 2011-12-08
#
#
# -----------------------------------------------------------------------------
# 1420 ASH
# data available to public on: 2017-11-29
#
#
# -----------------------------------------------------------------------------
# 1421 AA
# data available to public on: 2019-03-26
#
#
# -----------------------------------------------------------------------------
# 1422 CNDT
# data available to public on: 2019-03-31
#
#
# -----------------------------------------------------------------------------
# 1423 INSW
# data available to public on: 2019-04-07
#
#
# -----------------------------------------------------------------------------
# 1424 DXC
# data available to public on: 2011-06-15
#
#
# -----------------------------------------------------------------------------
# 1425 DK
# data available to public on: 2012-04-02
#
#
# -----------------------------------------------------------------------------
# 1426 DK
# data available to public on: 2016-03-24
#
#
# -----------------------------------------------------------------------------
# 1427 KL
# data available to public on: 2013-07-18
#
#
# -----------------------------------------------------------------------------
# 1428 KL
# data available to public on: 2014-07-11
#
#
# -----------------------------------------------------------------------------
# 1429 HPR
# data available to public on: 2013-03-11
#
#
# -----------------------------------------------------------------------------
# 1430 HPR
# data available to public on: 2015-03-21
#
#
# -----------------------------------------------------------------------------
# 1431 HPR
# data available to public on: 2016-03-24
#
#
# -----------------------------------------------------------------------------
# 1432 HPR
# data available to public on: 2017-03-16
#
#
# -----------------------------------------------------------------------------
# 1433 HPR
# data available to public on: 2018-03-19
#
#
# -----------------------------------------------------------------------------
# 1434 HPR
# data available to public on: 2019-03-14
#
#
# -----------------------------------------------------------------------------
# 1435 NTR
# data available to public on: 2019-03-26
# -----------------------------------------------------------------------------
# 1436 BH
# data available to public on: 2011-12-14
#
#
# -----------------------------------------------------------------------------
# 1437 BH
# data available to public on: 2012-12-11
#
#
# -----------------------------------------------------------------------------
# 1438 BH
# data available to public on: 2013-12-11
#
#
# -----------------------------------------------------------------------------
# 1439 BH
# data available to public on: 2014-12-02
#
#
# -----------------------------------------------------------------------------
# 1440 BH
# data available to public on: 2016-03-02
#
#
# -----------------------------------------------------------------------------
# 1441 BH
# data available to public on: 2017-03-13
#
#
# -----------------------------------------------------------------------------
# 1442 BH
# data available to public on: 2018-03-19
#
#
# -----------------------------------------------------------------------------
# 1443 BH
# data available to public on: 2019-03-08
#
#
# -----------------------------------------------------------------------------
# 1444 WRK
# data available to public on: 2011-12-06
#
#
# -----------------------------------------------------------------------------
# 1445 WRK
# data available to public on: 2015-11-30
#
#
# -----------------------------------------------------------------------------
# 1446 WRK
# data available to public on: 2018-11-19
#
#
# -----------------------------------------------------------------------------
# 1447 SDRL
# data available to public on: 2015-05-08
#
#
# -----------------------------------------------------------------------------
# 1448 SDRL
# data available to public on: 2016-05-18
#
#
# -----------------------------------------------------------------------------
# 1449 SDRL
# data available to public on: 2017-05-18
#
#
# -----------------------------------------------------------------------------
# 1450 SDRL
# data available to public on: 2018-06-19
#
#
# -----------------------------------------------------------------------------
# 1451 SDRL
# data available to public on: 2019-04-26
#
#
# -----------------------------------------------------------------------------
# 1452 XRX
# data available to public on: 2012-02-27
#
#
# -----------------------------------------------------------------------------
# 1453 XRX
# data available to public on: 2013-02-24
#
#
# -----------------------------------------------------------------------------
# 1454 XRX
# data available to public on: 2014-02-23
#
#
# -----------------------------------------------------------------------------
# 1455 XRX
# data available to public on: 2016-02-22
#
#
# -----------------------------------------------------------------------------
# 1456 XRX
# data available to public on: 2019-03-06

# %%
# investigate 'N/A' purchase date observations in stock_price_df
stock_price_df.query('Purchase_Date=="N/A"')
# Out:
#      Ticker_Symbol                 Company_Name  Data_Date BM_Quintile  \
# 4              AIR                     AAR CORP 2019-05-31   Very High
# 44             BGG            BRIGGS & STRATTON 2019-06-30   Very High
# 132            LCI               LANNETT CO INC 2019-06-30   Very High
# 198            SCX    STARRETT (L.S.) CO  -CL A 2019-06-30   Very High
# 221            UFI                    UNIFI INC 2019-06-30   Very High
# 269            VAL                  VALARIS PLC 2011-12-31   Very High
# 270            VAL                  VALARIS PLC 2012-12-31   Very High
# 271            VAL                  VALARIS PLC 2013-12-31   Very High
# 272            VAL                  VALARIS PLC 2014-12-31   Very High
# 273            VAL                  VALARIS PLC 2015-12-31   Very High
# 274            VAL                  VALARIS PLC 2016-12-31   Very High
# 275            VAL                  VALARIS PLC 2017-12-31   Very High
# 276            VAL                  VALARIS PLC 2018-12-31   Very High
# 403            CGA  CHINA GREEN AGRICULTURE INC 2019-06-30   Very High
# 623           UNFI     UNITED NATURAL FOODS INC 2019-07-31   Very High
# 1249          EROS       EROS INTERNATIONAL PLC 2019-03-31   Very High
#
#       F_SCORE Purchase_Date
# 4           5           N/A
# 44          3           N/A
# 132         4           N/A
# 198         7           N/A
# 221         5           N/A
# 269         5           N/A
# 270         6           N/A
# 271         6           N/A
# 272         4           N/A
# 273         5           N/A
# 274         6           N/A
# 275         3           N/A
# 276         2           N/A
# 403         5           N/A
# 623         3           N/A
# 1249        3           N/A

# %%
# investigate None purchase date observations in stock_price_df
stock_price_df.loc[stock_price_df['Purchase_Date'].isnull()]
# Out:
#      Ticker_Symbol                  Company_Name  Data_Date BM_Quintile  \
# 1362           GMS                       GMS INC 2019-04-30   Very High
# 1403          BNED  BARNES & NOBLE EDUCATION INC 2019-04-30   Very High
#
#       F_SCORE Purchase_Date
# 1362        4          None
# 1403        6          None

# %%
# note: the purchase date for the 'N/A' observations can be obtained as the SEC filing date
#       for the observations corresponding annual filing
# note: these are investigated and corrected (if possible) below

# observation at index 4 in stock_price_df
stock_price_df.loc[4, 'Purchase_Date'] = '2019-07-18'
# observation at index 44 in stock_price_df
stock_price_df.loc[44, 'Purchase_Date'] = '2019-08-27'
# observation at index 132 in stock_price_df
stock_price_df.loc[132, 'Purchase_Date'] = '2019-08-28'
# observation at index 198 in stock_price_df
stock_price_df.loc[198, 'Purchase_Date'] = '2019-08-26'
# observation at index 221 in stock_price_df
stock_price_df.loc[221, 'Purchase_Date'] = '2019-08-29'
# observation at index 269 in stock_price_df
stock_price_df.loc[269, 'Purchase_Date'] = '2012-02-24'
# observation at index 270 in stock_price_df
stock_price_df.loc[270, 'Purchase_Date'] = '2013-02-22'
# observation at index 271 in stock_price_df
stock_price_df.loc[271, 'Purchase_Date'] = '2014-02-26'
# observation at index 272 in stock_price_df
stock_price_df.loc[272, 'Purchase_Date'] = '2015-03-02'
# observation at index 273 in stock_price_df
stock_price_df.loc[273, 'Purchase_Date'] = '2016-02-25'
# observation at index 274 in stock_price_df
stock_price_df.loc[274, 'Purchase_Date'] = '2017-02-28'
# observation at index 275 in stock_price_df
stock_price_df.loc[275, 'Purchase_Date'] = '2018-02-27'
# observation at index 276 in stock_price_df
stock_price_df.loc[276, 'Purchase_Date'] = '2019-02-28'
# observation at index 1249 in stock_price_df
stock_price_df.loc[1249, 'Purchase_Date'] = '2019-08-14'
# observation at index 1362 in stock_price_df
stock_price_df.loc[1362, 'Purchase_Date'] = '2019-06-27'
# observation at index 1403 in stock_price_df
stock_price_df.loc[1403, 'Purchase_Date'] = '2019-06-25'

# %%
# filter out 'N/A' observations
stock_price_df = stock_price_df.query('Purchase_Date!="N/A"')

# %%
# check if purchase day is a working day
# if Purchase_Date is not working day, add 1 working day

stock_price_df['Purchase_Date'] = pd.to_datetime(stock_price_df['Purchase_Date'])

for idx, row in stock_price_df.iterrows():
    if cal.is_working_day(row['Purchase_Date'])==True:
        continue
    else:
        stock_price_df.loc[idx, 'Purchase_Date'] = cal.add_working_days(row['Purchase_Date'], 1)

# %%
# create column in stock_price_df to store sell date
stock_price_df['Sell_Date'] = 0

# note: sell date will be equal to the Purchase_Date variable plus 1 year
# note: similar to purchase date, if sell date correponds to a holiday, then set sell date
#       to closest date corresponding to business day
for idx, row in stock_price_df.iterrows():
    if datetime.strptime(row['Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') >= datetime(2018, 9, 1):
        stock_price_df.loc[idx, 'Sell_Date'] = datetime(2019, 9, 2).strftime('%Y-%m-%d')
    else:
        if isleap((datetime.strptime(row['Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') + timedelta(days=365)).year)==True:
            stock_price_df.loc[idx, 'Sell_Date'] = \
            (datetime.strptime(row['Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') + 
                                                    timedelta(days=366)).strftime('%Y-%m-%d')
        else:
            stock_price_df.loc[idx, 'Sell_Date'] = \
            (datetime.strptime(row['Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') + 
                                                    timedelta(days=365)).strftime('%Y-%m-%d')

# %%
# check if Sell_Date in stock_price_df is business day; if not change to closest future business day
for idx, row in stock_price_df.iterrows():
    if cal.is_working_day(datetime.strptime(row['Sell_Date'], '%Y-%m-%d'))==False:
        stock_price_df.loc[idx, 'Sell_Date'] = \
        cal.add_working_days(datetime.strptime(row['Sell_Date'], '%Y-%m-%d'), 1).strftime('%Y-%m-%d')
    else:
        continue

# %%
# create column in stock_price_df to store stock purchase price
stock_price_df['Stock_Purchase_Price'] = 0
# create column in stock_price_df to store stock sell price
stock_price_df['Stock_Sell_Price'] = 0

# retrieve Stock_Purchase_Price and Stock_Sell_Price from compustat database
# note: the stock prices are retrieved from the secutiy daily dataset
for idx, row in stock_price_df.iterrows():
    ticker_symbol = row['Ticker_Symbol']
    
    # Stock_Purchase_Price Da
    purchase_date = datetime.strptime(row['Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d').strftime('%m/%d/%Y')
    purchase_price = db.raw_sql("""SELECT DISTINCT prccd
                                   FROM comp.secd WHERE tic=%s
                                   AND datadate=%s""", params=(ticker_symbol, purchase_date))
    # check if purchase_price dataframe is empty
    if purchase_price.empty==True:
        try:
            # if purchase price returns empty dataframe, retrieve data from yahoo finance
            stock_price_df.loc[idx, 'Stock_Purchase_Price'] = \
            data.DataReader(ticker_symbol, 'yahoo', purchase_date, purchase_date)['Close'][0]
        except:
            # if data cannot be obtained, set Stock_Purchase_Price to 'N/A'
            stock_price_df.loc[idx, 'Stock_Purchase_Price'] = 'N/A'
    else:
        stock_price_df.loc[idx, 'Stock_Purchase_Price'] = purchase_price['prccd'][0]
    
    # provide user feedback
    print('-----------------------------------------------------------------------')
    print(idx, ticker_symbol)
    print('stock purchase price: $', stock_price_df.loc[idx, 'Stock_Purchase_Price'], sep='')
    
    # Stock_Sell_Price
    sell_date = datetime.strptime(row['Sell_Date'], '%Y-%m-%d').strftime('%m/%d/%Y')
    sell_price = db.raw_sql("""SELECT DISTINCT prccd
                               FROM comp.secd WHERE tic=%s
                               AND datadate=%s""", params=(ticker_symbol, sell_date))
    # check if sell_price dataframe is empty
    if sell_price.empty==True:
        # check if Stock_Purchase_Price was obtained; if it was obtained proceed to obtain Stock_Sell_Price
        try:
            # if sell price returns empty dataframe, retrieve data from yahoo finance
            stock_price_df.loc[idx, 'Stock_Sell_Price'] = \
            data.DataReader(ticker_symbol, 'yahoo', sell_date, sell_date)['Close'][0]
        except:
            # if data cannot be obtained, set Stock_Sell_Price to 'N/A'
            stock_price_df.loc[idx, 'Stock_Sell_Price'] = 'N/A' 
    else:
        stock_price_df.loc[idx, 'Stock_Sell_Price'] = sell_price['prccd'][0]
    
    print('stock sell price: $', stock_price_df.loc[idx, 'Stock_Sell_Price'], sep='')
# Out:
# -----------------------------------------------------------------------
# 0 AIR
# stock purchase price: $13.63
# stock sell price: $25.22
# -----------------------------------------------------------------------
# 1 AIR
# stock purchase price: $24.67
# stock sell price: $26.85
# -----------------------------------------------------------------------
# 2 AIR
# stock purchase price: $27.99
# stock sell price: $29.32
# -----------------------------------------------------------------------
# 3 AIR
# stock purchase price: $24.26
# stock sell price: $36.31
# -----------------------------------------------------------------------
# 4 AIR
# stock purchase price: $41.87
# stock sell price: $43.13
# -----------------------------------------------------------------------
# 5 HES
# stock purchase price: $65.86
# stock sell price: $65.68
# -----------------------------------------------------------------------
# 6 HES
# stock purchase price: $68.84
# stock sell price: $80.35
# -----------------------------------------------------------------------
# 7 HES
# stock purchase price: $80.35
# stock sell price: $74.84
# -----------------------------------------------------------------------
# 8 HES
# stock purchase price: $74.11
# stock sell price: $46.92
# -----------------------------------------------------------------------
# 9 HES
# stock purchase price: $43.6
# stock sell price: $51.44
# -----------------------------------------------------------------------
# 10 HES
# stock purchase price: $47.78
# stock sell price: $57.69
# -----------------------------------------------------------------------
# 11 HES
# stock purchase price: $57.54
# stock sell price: $63.28
# -----------------------------------------------------------------------
# 12 AP
# stock purchase price: $20.19
# stock sell price: $19.08
# -----------------------------------------------------------------------
# 13 AP
# stock purchase price: $18.62
# stock sell price: $19.13
# -----------------------------------------------------------------------
# 14 AP
# stock purchase price: $18.86
# stock sell price: $17.05
# -----------------------------------------------------------------------
# 15 AP
# stock purchase price: $17.65
# stock sell price: $13.61
# -----------------------------------------------------------------------
# 16 AP
# stock purchase price: $13.93
# stock sell price: $13.45
# -----------------------------------------------------------------------
# 17 AP
# stock purchase price: $10.85
# stock sell price: $3.22
# -----------------------------------------------------------------------
# 18 AP
# stock purchase price: $3.15
# stock sell price: $3.45
# -----------------------------------------------------------------------
# 19 APA
# stock purchase price: $106.45
# stock sell price: $72.73
# -----------------------------------------------------------------------
# 20 APA
# stock purchase price: $72.73
# stock sell price: $80.48
# -----------------------------------------------------------------------
# 21 APA
# stock purchase price: $79.86
# stock sell price: $66.72
# -----------------------------------------------------------------------
# 22 APA
# stock purchase price: $66.72
# stock sell price: $45.09
# -----------------------------------------------------------------------
# 23 APA
# stock purchase price: $32.75
# stock sell price: $21.41
# -----------------------------------------------------------------------
# 24 SSI
# stock purchase price: $19.6
# stock sell price: $15.58
# -----------------------------------------------------------------------
# 25 SSI
# stock purchase price: $15.58
# stock sell price: $27.39
# -----------------------------------------------------------------------
# 26 SSI
# stock purchase price: $7.62
# stock sell price: $2.71
# -----------------------------------------------------------------------
# 27 SSI
# stock purchase price: $2.5
# stock sell price: $2.96
# -----------------------------------------------------------------------
# 28 SSI
# stock purchase price: $2.71
# stock sell price: $1.02
# -----------------------------------------------------------------------
# 29 SSI
# stock purchase price: $1.07
# stock sell price: $0.7799
# -----------------------------------------------------------------------
# 30 TREC
# stock purchase price: $9.1
# stock sell price: $8.9
# -----------------------------------------------------------------------
# 31 ADM
# stock purchase price: $27.8
# stock sell price: $26.42
# -----------------------------------------------------------------------
# 32 ADM
# stock purchase price: $26.58
# stock sell price: $34.81
# -----------------------------------------------------------------------
# 33 ADM
# stock purchase price: $33.79
# stock sell price: $44.81
# -----------------------------------------------------------------------
# 34 ADM
# stock purchase price: $42.57
# stock sell price: $41.97
# -----------------------------------------------------------------------
# 35 ADM
# stock purchase price: $42.57
# stock sell price: $37.99
# -----------------------------------------------------------------------
# 36 SWN
# stock purchase price: $6.38
# stock sell price: $7.61
# -----------------------------------------------------------------------
# 37 SWN
# stock purchase price: $4.46
# stock sell price: $1.64
# -----------------------------------------------------------------------
# 38 ARW
# stock purchase price: $42.29
# stock sell price: $39.3
# -----------------------------------------------------------------------
# 39 ARW
# stock purchase price: $40.46
# stock sell price: $53.29
# -----------------------------------------------------------------------
# 40 ARW
# stock purchase price: $54.33
# stock sell price: $72.89
# -----------------------------------------------------------------------
# 41 ARW
# stock purchase price: $79.51
# stock sell price: $68.09
# -----------------------------------------------------------------------
# 42 ESTE
# stock purchase price: $10.37
# stock sell price: $7.06
# -----------------------------------------------------------------------
# 43 ESTE
# stock purchase price: $7.42
# stock sell price: $3.24
# -----------------------------------------------------------------------
# 44 BGG
# stock purchase price: $4.03
# stock sell price: $4.44
# -----------------------------------------------------------------------
# 45 CAL
# stock purchase price: $9.08
# stock sell price: $15.68
# -----------------------------------------------------------------------
# 46 CBT
# stock purchase price: $32.65
# stock sell price: $38.88
# -----------------------------------------------------------------------
# 47 CBT
# stock purchase price: $37.12
# stock sell price: $48.27
# -----------------------------------------------------------------------
# 48 CACI
# stock purchase price: $53.8
# stock sell price: $67.32
# -----------------------------------------------------------------------
# 49 CACI
# stock purchase price: $67.95
# stock sell price: $72.35
# -----------------------------------------------------------------------
# 50 CACI
# stock purchase price: $72.4
# stock sell price: $77.59
# -----------------------------------------------------------------------
# 51 LUB
# stock purchase price: $4.33
# stock sell price: $5.82
# -----------------------------------------------------------------------
# 52 LUB
# stock purchase price: $5.82
# stock sell price: $7.4
# -----------------------------------------------------------------------
# 53 LUB
# stock purchase price: $7.47
# stock sell price: $4.77
# -----------------------------------------------------------------------
# 54 LUB
# stock purchase price: $4.95
# stock sell price: $4.95
# -----------------------------------------------------------------------
# 55 LUB
# stock purchase price: $4.78
# stock sell price: $4.26
# -----------------------------------------------------------------------
# 56 LUB
# stock purchase price: $4.28
# stock sell price: $2.77
# -----------------------------------------------------------------------
# 57 LUB
# stock purchase price: $2.78
# stock sell price: $1.56
# -----------------------------------------------------------------------
# 58 LUB
# stock purchase price: $1.52
# stock sell price: $1.49
# -----------------------------------------------------------------------
# 59 CATO
# stock purchase price: $N/A
# stock sell price: $15.28
# -----------------------------------------------------------------------
# 60 CATO
# stock purchase price: $14.71
# stock sell price: $16.91
# -----------------------------------------------------------------------
# 61 GCO
# stock purchase price: $42.55
# stock sell price: $43.23
# -----------------------------------------------------------------------
# 62 GCO
# stock purchase price: $43.23
# stock sell price: $34.84
# -----------------------------------------------------------------------
# 63 CTL
# stock purchase price: $40.25
# stock sell price: $34.67
# -----------------------------------------------------------------------
# 64 CTL
# stock purchase price: $31.11
# stock sell price: $37.68
# -----------------------------------------------------------------------
# 65 CTL
# stock purchase price: $30.59
# stock sell price: $24.26
# -----------------------------------------------------------------------
# 66 CTL
# stock purchase price: $24.26
# stock sell price: $17.67
# -----------------------------------------------------------------------
# 67 CTL
# stock purchase price: $18.06
# stock sell price: $11.56
# -----------------------------------------------------------------------
# 68 CTL
# stock purchase price: $12.1
# stock sell price: $11.52
# -----------------------------------------------------------------------
# 69 CSS
# stock purchase price: $18.32
# stock sell price: $20.15
# -----------------------------------------------------------------------
# 70 CSS
# stock purchase price: $20.15
# stock sell price: $27.0
# -----------------------------------------------------------------------
# 71 CSS
# stock purchase price: $27.49
# stock sell price: $25.22
# -----------------------------------------------------------------------
# 72 CSS
# stock purchase price: $23.35
# stock sell price: $27.55
# -----------------------------------------------------------------------
# 73 CSS
# stock purchase price: $27.68
# stock sell price: $26.38
# -----------------------------------------------------------------------
# 74 CSS
# stock purchase price: $28.11
# stock sell price: $25.98
# -----------------------------------------------------------------------
# 75 CSS
# stock purchase price: $26.0
# stock sell price: $16.74
# -----------------------------------------------------------------------
# 76 CSS
# stock purchase price: $17.55
# stock sell price: $4.9
# -----------------------------------------------------------------------
# 77 CSS
# stock purchase price: $5.17
# stock sell price: $3.82
# -----------------------------------------------------------------------
# 78 CMC
# stock purchase price: $13.37
# stock sell price: $13.82
# -----------------------------------------------------------------------
# 79 CMC
# stock purchase price: $14.4
# stock sell price: $18.56
# -----------------------------------------------------------------------
# 80 TAP
# stock purchase price: $44.0
# stock sell price: $44.79
# -----------------------------------------------------------------------
# 81 TAP
# stock purchase price: $46.08
# stock sell price: $57.25
# -----------------------------------------------------------------------
# 82 TAP
# stock purchase price: $55.73
# stock sell price: $76.26
# -----------------------------------------------------------------------
# 83 TAP
# stock purchase price: $59.19
# stock sell price: $52.39
# -----------------------------------------------------------------------
# 84 GLW
# stock purchase price: $13.52
# stock sell price: $12.95
# -----------------------------------------------------------------------
# 85 GLW
# stock purchase price: $12.9
# stock sell price: $18.92
# -----------------------------------------------------------------------
# 86 GLW
# stock purchase price: $18.8
# stock sell price: $24.55
# -----------------------------------------------------------------------
# 87 GLW
# stock purchase price: $18.64
# stock sell price: $27.36
# -----------------------------------------------------------------------
# 88 CTS
# stock purchase price: $9.5
# stock sell price: $10.15
# -----------------------------------------------------------------------
# 89 CW
# stock purchase price: $34.78
# stock sell price: $68.91
# -----------------------------------------------------------------------
# 90 DAN
# stock purchase price: $15.26
# stock sell price: $17.52
# -----------------------------------------------------------------------
# 91 DAN
# stock purchase price: $16.43
# stock sell price: $21.31
# -----------------------------------------------------------------------
# 92 DDS
# stock purchase price: $40.47
# stock sell price: $63.63
# -----------------------------------------------------------------------
# 93 DDS
# stock purchase price: $63.89
# stock sell price: $78.85
# -----------------------------------------------------------------------
# 94 DDS
# stock purchase price: $52.24
# stock sell price: $76.68
# -----------------------------------------------------------------------
# 95 DDS
# stock purchase price: $81.52
# stock sell price: $75.38
# -----------------------------------------------------------------------
# 96 DDS
# stock purchase price: $75.67
# stock sell price: $58.77
# -----------------------------------------------------------------------
# 97 DCO
# stock purchase price: $13.98
# stock sell price: $17.34
# -----------------------------------------------------------------------
# 98 DCO
# stock purchase price: $18.92
# stock sell price: $23.7
# -----------------------------------------------------------------------
# 99 DCO
# stock purchase price: $31.92
# stock sell price: $15.3
# -----------------------------------------------------------------------
# 100 DCO
# stock purchase price: $15.37
# stock sell price: $27.9
# -----------------------------------------------------------------------
# 101 KODK
# stock purchase price: $5.0
# stock sell price: $2.92
# -----------------------------------------------------------------------
# 102 KODK
# stock purchase price: $2.51
# stock sell price: $2.38
# -----------------------------------------------------------------------
# 103 EBF
# stock purchase price: $19.02
# stock sell price: $14.37
# -----------------------------------------------------------------------
# 104 EBF
# stock purchase price: $14.23
# stock sell price: $15.89
# -----------------------------------------------------------------------
# 105 EBF
# stock purchase price: $15.48
# stock sell price: $15.1
# -----------------------------------------------------------------------
# 106 EBF
# stock purchase price: $15.15
# stock sell price: $16.61
# -----------------------------------------------------------------------
# 107 EQT
# stock purchase price: $60.32
# stock sell price: $64.03
# -----------------------------------------------------------------------
# 108 EQT
# stock purchase price: $51.4
# stock sell price: $19.35
# -----------------------------------------------------------------------
# 109 EQT
# stock purchase price: $18.97
# stock sell price: $10.02
# -----------------------------------------------------------------------
# 110 FOE
# stock purchase price: $5.95
# stock sell price: $6.72
# -----------------------------------------------------------------------
# 111 F
# stock purchase price: $8.88
# stock sell price: $9.1
# -----------------------------------------------------------------------
# 112 GLT
# stock purchase price: $19.38
# stock sell price: $21.52
# -----------------------------------------------------------------------
# 113 GLT
# stock purchase price: $13.21
# stock sell price: $14.09
# -----------------------------------------------------------------------
# 114 GTN
# stock purchase price: $1.94
# stock sell price: $4.38
# -----------------------------------------------------------------------
# 115 GTN
# stock purchase price: $4.86
# stock sell price: $10.8
# -----------------------------------------------------------------------
# 116 GTN
# stock purchase price: $23.18
# stock sell price: $14.62
# -----------------------------------------------------------------------
# 117 HHS
# stock purchase price: $7.83
# stock sell price: $8.26
# -----------------------------------------------------------------------
# 118 HP
# stock purchase price: $58.49
# stock sell price: $69.6
# -----------------------------------------------------------------------
# 119 HPQ
# stock purchase price: $14.25
# stock sell price: $27.98
# -----------------------------------------------------------------------
# 120 HFC
# stock purchase price: $35.93
# stock sell price: $53.11
# -----------------------------------------------------------------------
# 121 HFC
# stock purchase price: $39.75
# stock sell price: $35.83
# -----------------------------------------------------------------------
# 122 HFC
# stock purchase price: $27.27
# stock sell price: $45.29
# -----------------------------------------------------------------------
# 123 GFF
# stock purchase price: $8.38
# stock sell price: $10.03
# -----------------------------------------------------------------------
# 124 GFF
# stock purchase price: $9.8
# stock sell price: $12.86
# -----------------------------------------------------------------------
# 125 GFF
# stock purchase price: $12.98
# stock sell price: $12.62
# -----------------------------------------------------------------------
# 126 GFF
# stock purchase price: $12.67
# stock sell price: $17.71
# -----------------------------------------------------------------------
# 127 AXE
# stock purchase price: $56.36
# stock sell price: $58.63
# -----------------------------------------------------------------------
# 128 JEC
# stock purchase price: $43.97
# stock sell price: $62.17
# -----------------------------------------------------------------------
# 129 KFY
# stock purchase price: $18.71
# stock sell price: $30.21
# -----------------------------------------------------------------------
# 130 LCI
# stock purchase price: $4.81
# stock sell price: $18.09
# -----------------------------------------------------------------------
# 131 LCI
# stock purchase price: $5.35
# stock sell price: $10.3
# -----------------------------------------------------------------------
# 132 LCI
# stock purchase price: $8.1
# stock sell price: $10.23
# -----------------------------------------------------------------------
# 133 VHI
# stock purchase price: $1.24
# stock sell price: $3.34
# -----------------------------------------------------------------------
# 134 VHI
# stock purchase price: $2.34
# stock sell price: $1.96
# -----------------------------------------------------------------------
# 135 LPX
# stock purchase price: $10.12
# stock sell price: $21.54
# -----------------------------------------------------------------------
# 136 LXU
# stock purchase price: $13.29
# stock sell price: $8.43
# -----------------------------------------------------------------------
# 137 LXU
# stock purchase price: $9.83
# stock sell price: $6.97
# -----------------------------------------------------------------------
# 138 LXU
# stock purchase price: $6.75
# stock sell price: $7.19
# -----------------------------------------------------------------------
# 139 LXU
# stock purchase price: $7.08
# stock sell price: $4.43
# -----------------------------------------------------------------------
# 140 LDL
# stock purchase price: $9.95
# stock sell price: $15.44
# -----------------------------------------------------------------------
# 141 LDL
# stock purchase price: $24.57
# stock sell price: $19.59
# -----------------------------------------------------------------------
# 142 MTW
# stock purchase price: $18.59
# stock sell price: $11.68
# -----------------------------------------------------------------------
# 143 MCS
# stock purchase price: $8.23
# stock sell price: $12.94
# -----------------------------------------------------------------------
# 144 MCS
# stock purchase price: $13.37
# stock sell price: $12.37
# -----------------------------------------------------------------------
# 145 MCS
# stock purchase price: $12.58
# stock sell price: $18.37
# -----------------------------------------------------------------------
# 146 ETR
# stock purchase price: $62.26
# stock sell price: $63.82
# -----------------------------------------------------------------------
# 147 ETR
# stock purchase price: $63.28
# stock sell price: $77.48
# -----------------------------------------------------------------------
# 148 THC
# stock purchase price: $24.79
# stock sell price: $20.79
# -----------------------------------------------------------------------
# 149 THC
# stock purchase price: $18.0
# stock sell price: $24.62
# -----------------------------------------------------------------------
# 150 THC
# stock purchase price: $24.16
# stock sell price: $29.76
# -----------------------------------------------------------------------
# 151 THC
# stock purchase price: $30.18
# stock sell price: $20.89
# -----------------------------------------------------------------------
# 152 GPX
# stock purchase price: $12.64
# stock sell price: $12.9
# -----------------------------------------------------------------------
# 153 NR
# stock purchase price: $4.6
# stock sell price: $7.3
# -----------------------------------------------------------------------
# 154 NR
# stock purchase price: $8.15
# stock sell price: $6.5
# -----------------------------------------------------------------------
# 155 NL
# stock purchase price: $2.21
# stock sell price: $6.45
# -----------------------------------------------------------------------
# 156 NL
# stock purchase price: $3.85
# stock sell price: $3.61
# -----------------------------------------------------------------------
# 157 NBL
# stock purchase price: $24.05
# stock sell price: $22.31
# -----------------------------------------------------------------------
# 158 MOV
# stock purchase price: $16.95
# stock sell price: $25.25
# -----------------------------------------------------------------------
# 159 MOV
# stock purchase price: $24.42
# stock sell price: $32.61
# -----------------------------------------------------------------------
# 160 OII
# stock purchase price: $16.49
# stock sell price: $12.39
# -----------------------------------------------------------------------
# 161 OLN
# stock purchase price: $15.89
# stock sell price: $33.07
# -----------------------------------------------------------------------
# 162 OLN
# stock purchase price: $23.22
# stock sell price: $16.65
# -----------------------------------------------------------------------
# 163 OSG
# stock purchase price: $N/A
# stock sell price: $N/A
# -----------------------------------------------------------------------
# 164 OSG
# stock purchase price: $N/A
# stock sell price: $N/A
# -----------------------------------------------------------------------
# 165 OSG
# stock purchase price: $2.02
# stock sell price: $4.33
# -----------------------------------------------------------------------
# 166 OSG
# stock purchase price: $3.66
# stock sell price: $3.21
# -----------------------------------------------------------------------
# 167 OSG
# stock purchase price: $3.59
# stock sell price: $2.1
# -----------------------------------------------------------------------
# 168 OSG
# stock purchase price: $2.17
# stock sell price: $1.78
# -----------------------------------------------------------------------
# 169 OMI
# stock purchase price: $17.35
# stock sell price: $4.72
# -----------------------------------------------------------------------
# 170 OMI
# stock purchase price: $4.54
# stock sell price: $5.53
# -----------------------------------------------------------------------
# 171 PKD
# stock purchase price: $N/A
# stock sell price: $N/A
# -----------------------------------------------------------------------
# 172 PKD
# stock purchase price: $N/A
# stock sell price: $N/A
# -----------------------------------------------------------------------
# 173 PKD
# stock purchase price: $N/A
# stock sell price: $N/A
# -----------------------------------------------------------------------
# 174 PKD
# stock purchase price: $N/A
# stock sell price: $N/A
# -----------------------------------------------------------------------
# 175 PKD
# stock purchase price: $N/A
# stock sell price: $17.64
# -----------------------------------------------------------------------
# 176 PKD
# stock purchase price: $19.28
# stock sell price: $17.1
# -----------------------------------------------------------------------
# 177 TPC
# stock purchase price: $15.77
# stock sell price: $19.08
# -----------------------------------------------------------------------
# 178 TPC
# stock purchase price: $18.92
# stock sell price: $29.7
# -----------------------------------------------------------------------
# 179 TPC
# stock purchase price: $28.62
# stock sell price: $20.54
# -----------------------------------------------------------------------
# 180 TPC
# stock purchase price: $21.8
# stock sell price: $15.21
# -----------------------------------------------------------------------
# 181 TPC
# stock purchase price: $14.84
# stock sell price: $31.5
# -----------------------------------------------------------------------
# 182 TPC
# stock purchase price: $29.55
# stock sell price: $23.1
# -----------------------------------------------------------------------
# 183 TPC
# stock purchase price: $21.75
# stock sell price: $17.76
# -----------------------------------------------------------------------
# 184 TPC
# stock purchase price: $19.24
# stock sell price: $9.27
# -----------------------------------------------------------------------
# 185 RAD
# stock purchase price: $9.02
# stock sell price: $6.4
# -----------------------------------------------------------------------
# 186 R
# stock purchase price: $59.04
# stock sell price: $47.4
# -----------------------------------------------------------------------
# 187 LUV
# stock purchase price: $9.62
# stock sell price: $11.65
# -----------------------------------------------------------------------
# 188 LUV
# stock purchase price: $11.64
# stock sell price: $21.02
# -----------------------------------------------------------------------
# 189 CVX
# stock purchase price: $83.44
# stock sell price: $112.5
# -----------------------------------------------------------------------
# 190 SCX
# stock purchase price: $10.44
# stock sell price: $12.59
# -----------------------------------------------------------------------
# 191 SCX
# stock purchase price: $12.7
# stock sell price: $11.0
# -----------------------------------------------------------------------
# 192 SCX
# stock purchase price: $10.96
# stock sell price: $15.99
# -----------------------------------------------------------------------
# 193 SCX
# stock purchase price: $15.19
# stock sell price: $13.0
# -----------------------------------------------------------------------
# 194 SCX
# stock purchase price: $15.02
# stock sell price: $10.86
# -----------------------------------------------------------------------
# 195 SCX
# stock purchase price: $10.86
# stock sell price: $7.3
# -----------------------------------------------------------------------
# 196 SCX
# stock purchase price: $7.3
# stock sell price: $6.342
# -----------------------------------------------------------------------
# 197 SCX
# stock purchase price: $6.2
# stock sell price: $5.45
# -----------------------------------------------------------------------
# 198 SCX
# stock purchase price: $5.84
# stock sell price: $5.45
# -----------------------------------------------------------------------
# 199 SUP
# stock purchase price: $19.29
# stock sell price: $19.27
# -----------------------------------------------------------------------
# 200 SUP
# stock purchase price: $18.95
# stock sell price: $19.96
# -----------------------------------------------------------------------
# 201 SUP
# stock purchase price: $19.96
# stock sell price: $19.16
# -----------------------------------------------------------------------
# 202 SUP
# stock purchase price: $19.16
# stock sell price: $22.14
# -----------------------------------------------------------------------
# 203 SUP
# stock purchase price: $21.94
# stock sell price: $24.3
# -----------------------------------------------------------------------
# 204 SUP
# stock purchase price: $N/A
# stock sell price: $5.51
# -----------------------------------------------------------------------
# 205 SUP
# stock purchase price: $5.17
# stock sell price: $2.6
# -----------------------------------------------------------------------
# 206 TEX
# stock purchase price: $25.53
# stock sell price: $35.21
# -----------------------------------------------------------------------
# 207 TEX
# stock purchase price: $22.33
# stock sell price: $29.91
# -----------------------------------------------------------------------
# 208 TMO
# stock purchase price: $57.25
# stock sell price: $75.33
# -----------------------------------------------------------------------
# 209 TDW
# stock purchase price: $1487.4193115234375
# stock sell price: $1827.4193115234375
# -----------------------------------------------------------------------
# 210 TDW
# stock purchase price: $1812.5806884765625
# stock sell price: $1693.8709716796875
# -----------------------------------------------------------------------
# 211 TDW
# stock purchase price: $1671.6129150390625
# stock sell price: $760.3225708007812
# -----------------------------------------------------------------------
# 212 TDW
# stock purchase price: $758.7096557617188
# stock sell price: $179.03225708007812
# -----------------------------------------------------------------------
# 213 TDW
# stock purchase price: $181.2903289794922
# stock sell price: $25.483871459960938
# -----------------------------------------------------------------------
# 214 TDW
# stock purchase price: $26.129032135009766
# stock sell price: $28.31
# -----------------------------------------------------------------------
# 215 TDW
# stock purchase price: $33.58
# stock sell price: $22.12
# -----------------------------------------------------------------------
# 216 TDW
# stock purchase price: $22.73
# stock sell price: $15.2
# -----------------------------------------------------------------------
# 217 TSN
# stock purchase price: $19.17
# stock sell price: $19.25
# -----------------------------------------------------------------------
# 218 TSN
# stock purchase price: $18.72
# stock sell price: $30.78
# -----------------------------------------------------------------------
# 219 UFI
# stock purchase price: $10.13
# stock sell price: $12.13
# -----------------------------------------------------------------------
# 220 UFI
# stock purchase price: $11.22
# stock sell price: $23.45
# -----------------------------------------------------------------------
# 221 UFI
# stock purchase price: $19.26
# stock sell price: $19.16
# -----------------------------------------------------------------------
# 222 MRO
# stock purchase price: $33.46
# stock sell price: $32.54
# -----------------------------------------------------------------------
# 223 MRO
# stock purchase price: $34.71
# stock sell price: $33.89
# -----------------------------------------------------------------------
# 224 MRO
# stock purchase price: $27.74
# stock sell price: $9.97
# -----------------------------------------------------------------------
# 225 MRO
# stock purchase price: $8.03
# stock sell price: $15.85
# -----------------------------------------------------------------------
# 226 MRO
# stock purchase price: $15.85
# stock sell price: $15.0
# -----------------------------------------------------------------------
# 227 MRO
# stock purchase price: $16.79
# stock sell price: $11.77
# -----------------------------------------------------------------------
# 228 S
# stock purchase price: $2.549999952316284
# stock sell price: $5.78000020980835
# -----------------------------------------------------------------------
# 229 S
# stock purchase price: $4.53
# stock sell price: $3.81
# -----------------------------------------------------------------------
# 230 S
# stock purchase price: $3.53
# stock sell price: $8.33
# -----------------------------------------------------------------------
# 231 S
# stock purchase price: $5.17
# stock sell price: $6.99
# -----------------------------------------------------------------------
# 232 S
# stock purchase price: $7.07
# stock sell price: $6.7
# -----------------------------------------------------------------------
# 233 UVV
# stock purchase price: $38.56
# stock sell price: $44.59
# -----------------------------------------------------------------------
# 234 UVV
# stock purchase price: $44.59
# stock sell price: $59.25
# -----------------------------------------------------------------------
# 235 UVV
# stock purchase price: $58.25
# stock sell price: $53.23
# -----------------------------------------------------------------------
# 236 UVV
# stock purchase price: $52.68
# stock sell price: $52.48
# -----------------------------------------------------------------------
# 237 UVV
# stock purchase price: $52.79
# stock sell price: $55.77
# -----------------------------------------------------------------------
# 238 UVV
# stock purchase price: $55.24
# stock sell price: $67.35
# -----------------------------------------------------------------------
# 239 UVV
# stock purchase price: $65.25
# stock sell price: $59.33
# -----------------------------------------------------------------------
# 240 UVV
# stock purchase price: $56.4
# stock sell price: $50.58
# -----------------------------------------------------------------------
# 241 VSH
# stock purchase price: $11.31
# stock sell price: $13.12
# -----------------------------------------------------------------------
# 242 VSH
# stock purchase price: $13.13
# stock sell price: $14.1
# -----------------------------------------------------------------------
# 243 VSH
# stock purchase price: $13.86
# stock sell price: $14.58
# -----------------------------------------------------------------------
# 244 VSH
# stock purchase price: $14.39
# stock sell price: $11.59
# -----------------------------------------------------------------------
# 245 VSH
# stock purchase price: $11.71
# stock sell price: $16.25
# -----------------------------------------------------------------------
# 246 GHC
# stock purchase price: $398.5
# stock sell price: $395.83
# -----------------------------------------------------------------------
# 247 GHC
# stock purchase price: $395.83
# stock sell price: $701.49
# -----------------------------------------------------------------------
# 248 GHC
# stock purchase price: $499.27
# stock sell price: $568.25
# -----------------------------------------------------------------------
# 249 GHC
# stock purchase price: $571.15
# stock sell price: $589.1
# -----------------------------------------------------------------------
# 250 GHC
# stock purchase price: $584.85
# stock sell price: $674.34
# -----------------------------------------------------------------------
# 251 GHC
# stock purchase price: $678.19
# stock sell price: $701.15
# -----------------------------------------------------------------------
# 252 AVA
# stock purchase price: $25.25
# stock sell price: $26.46
# -----------------------------------------------------------------------
# 253 AVA
# stock purchase price: $26.17
# stock sell price: $30.0
# -----------------------------------------------------------------------
# 254 WMK
# stock purchase price: $38.31
# stock sell price: $41.2
# -----------------------------------------------------------------------
# 255 WHR
# stock purchase price: $70.08
# stock sell price: $107.11
# -----------------------------------------------------------------------
# 256 WMB
# stock purchase price: $16.55
# stock sell price: $28.79
# -----------------------------------------------------------------------
# 257 CDE
# stock purchase price: $26.85
# stock sell price: $18.15
# -----------------------------------------------------------------------
# 258 CDE
# stock purchase price: $18.03
# stock sell price: $11.19
# -----------------------------------------------------------------------
# 259 CDE
# stock purchase price: $10.59
# stock sell price: $4.77
# -----------------------------------------------------------------------
# 260 CDE
# stock purchase price: $5.05
# stock sell price: $5.3
# -----------------------------------------------------------------------
# 261 CDE
# stock purchase price: $3.2
# stock sell price: $9.15
# -----------------------------------------------------------------------
# 262 CDE
# stock purchase price: $4.64
# stock sell price: $5.58
# -----------------------------------------------------------------------
# 263 HVT
# stock purchase price: $11.71
# stock sell price: $20.32
# -----------------------------------------------------------------------
# 264 PIR
# stock purchase price: $2.38
# stock sell price: $0.6387
# -----------------------------------------------------------------------
# 265 SU
# stock purchase price: $33.93
# stock sell price: $30.2
# -----------------------------------------------------------------------
# 266 MUX
# stock purchase price: $2.47
# stock sell price: $0.97
# -----------------------------------------------------------------------
# 267 MUX
# stock purchase price: $0.95
# stock sell price: $2.45
# -----------------------------------------------------------------------
# 268 MUX
# stock purchase price: $1.97
# stock sell price: $3.2
# -----------------------------------------------------------------------
# 269 VAL
# stock purchase price: $59.4
# stock sell price: $58.35
# -----------------------------------------------------------------------
# 270 VAL
# stock purchase price: $61.49
# stock sell price: $53.29
# -----------------------------------------------------------------------
# 271 VAL
# stock purchase price: $52.81
# stock sell price: $24.41
# -----------------------------------------------------------------------
# 272 VAL
# stock purchase price: $23.77
# stock sell price: $9.58
# -----------------------------------------------------------------------
# 273 VAL
# stock purchase price: $7.88
# stock sell price: $10.17
# -----------------------------------------------------------------------
# 274 VAL
# stock purchase price: $9.74
# stock sell price: $4.44
# -----------------------------------------------------------------------
# 275 VAL
# stock purchase price: $4.89
# stock sell price: $4.12
# -----------------------------------------------------------------------
# 276 VAL
# stock purchase price: $4.1
# stock sell price: $4.6
# -----------------------------------------------------------------------
# 277 RRC
# stock purchase price: $13.29
# stock sell price: $10.7
# -----------------------------------------------------------------------
# 278 RRC
# stock purchase price: $10.81
# stock sell price: $3.69
# -----------------------------------------------------------------------
# 279 ENZ
# stock purchase price: $1.85
# stock sell price: $2.43
# -----------------------------------------------------------------------
# 280 TISI
# stock purchase price: $14.0
# stock sell price: $17.5
# -----------------------------------------------------------------------
# 281 TISI
# stock purchase price: $17.57
# stock sell price: $16.48
# -----------------------------------------------------------------------
# 282 KEG
# stock purchase price: $1656
# stock sell price: $1690
# -----------------------------------------------------------------------
# 283 KEG
# stock purchase price: $1690
# stock sell price: $314
# -----------------------------------------------------------------------
# 284 KEG
# stock purchase price: $408
# stock sell price: $46
# -----------------------------------------------------------------------
# 285 KEG
# stock purchase price: $76
# stock sell price: $23.09
# -----------------------------------------------------------------------
# 286 KEG
# stock purchase price: $5.78
# stock sell price: $1.01
# -----------------------------------------------------------------------
# 287 AN
# stock purchase price: $34.43
# stock sell price: $47.34
# -----------------------------------------------------------------------
# 288 SBOW
# stock purchase price: $N/A
# stock sell price: $N/A
# -----------------------------------------------------------------------
# 289 SBOW
# stock purchase price: $N/A
# stock sell price: $N/A
# -----------------------------------------------------------------------
# 290 SBOW
# stock purchase price: $N/A
# stock sell price: $N/A
# -----------------------------------------------------------------------
# 291 SBOW
# stock purchase price: $21.67
# stock sell price: $8.48
# -----------------------------------------------------------------------
# 292 KGC
# stock purchase price: $11.36
# stock sell price: $7.46
# -----------------------------------------------------------------------
# 293 KGC
# stock purchase price: $7.99
# stock sell price: $5.17
# -----------------------------------------------------------------------
# 294 KGC
# stock purchase price: $5.22
# stock sell price: $2.72
# -----------------------------------------------------------------------
# 295 KGC
# stock purchase price: $2.98
# stock sell price: $2.72
# -----------------------------------------------------------------------
# 296 KGC
# stock purchase price: $2.57
# stock sell price: $4.1
# -----------------------------------------------------------------------
# 297 KGC
# stock purchase price: $3.93
# stock sell price: $3.94
# -----------------------------------------------------------------------
# 298 KGC
# stock purchase price: $3.59
# stock sell price: $3.45
# -----------------------------------------------------------------------
# 299 KGC
# stock purchase price: $3.77
# stock sell price: $5.19
# -----------------------------------------------------------------------
# 300 MDR
# stock purchase price: $3.22
# stock sell price: $4.41
# -----------------------------------------------------------------------
# 301 MDR
# stock purchase price: $3.3
# stock sell price: $7.36
# -----------------------------------------------------------------------
# 302 MDR
# stock purchase price: $7.68
# stock sell price: $7.56
# -----------------------------------------------------------------------
# 303 MDR
# stock purchase price: $7.74
# stock sell price: $8.24
# -----------------------------------------------------------------------
# 304 MDR
# stock purchase price: $8.24
# stock sell price: $4.64
# -----------------------------------------------------------------------
# 305 PAR
# stock purchase price: $5.09
# stock sell price: $4.19
# -----------------------------------------------------------------------
# 306 PAR
# stock purchase price: $4.35
# stock sell price: $4.76
# -----------------------------------------------------------------------
# 307 PAR
# stock purchase price: $4.7
# stock sell price: $4.02
# -----------------------------------------------------------------------
# 308 ACCO
# stock purchase price: $8.69
# stock sell price: $9.0
# -----------------------------------------------------------------------
# 309 RGS
# stock purchase price: $14.18
# stock sell price: $18.65
# -----------------------------------------------------------------------
# 310 RGS
# stock purchase price: $18.65
# stock sell price: $15.46
# -----------------------------------------------------------------------
# 311 RGS
# stock purchase price: $15.65
# stock sell price: $16.39
# -----------------------------------------------------------------------
# 312 RGS
# stock purchase price: $15.94
# stock sell price: $11.73
# -----------------------------------------------------------------------
# 313 RGS
# stock purchase price: $12.57
# stock sell price: $13.28
# -----------------------------------------------------------------------
# 314 RGS
# stock purchase price: $13.03
# stock sell price: $21.46
# -----------------------------------------------------------------------
# 315 MUR
# stock purchase price: $49.11
# stock sell price: $19.3
# -----------------------------------------------------------------------
# 316 MUR
# stock purchase price: $17.18
# stock sell price: $28.29
# -----------------------------------------------------------------------
# 317 MUR
# stock purchase price: $28.77
# stock sell price: $25.75
# -----------------------------------------------------------------------
# 318 MUR
# stock purchase price: $25.65
# stock sell price: $30.64
# -----------------------------------------------------------------------
# 319 MUR
# stock purchase price: $30.64
# stock sell price: $18.11
# -----------------------------------------------------------------------
# 320 HL
# stock purchase price: $3.57
# stock sell price: $3.26
# -----------------------------------------------------------------------
# 321 HL
# stock purchase price: $3.34
# stock sell price: $2.49
# -----------------------------------------------------------------------
# 322 HL
# stock purchase price: $2.58
# stock sell price: $5.16
# -----------------------------------------------------------------------
# 323 HL
# stock purchase price: $3.6
# stock sell price: $2.34
# -----------------------------------------------------------------------
# 324 HL
# stock purchase price: $2.45
# stock sell price: $1.89
# -----------------------------------------------------------------------
# 325 TRCO
# stock purchase price: $39.18
# stock sell price: $39.09
# -----------------------------------------------------------------------
# 326 TRCO
# stock purchase price: $37.16
# stock sell price: $40.63
# -----------------------------------------------------------------------
# 327 TRCO
# stock purchase price: $40.95
# stock sell price: $46.08
# -----------------------------------------------------------------------
# 328 TRCO
# stock purchase price: $46.07
# stock sell price: $46.61
# -----------------------------------------------------------------------
# 329 ATGE
# stock purchase price: $26.16
# stock sell price: $23.04
# -----------------------------------------------------------------------
# 330 ATGE
# stock purchase price: $22.66
# stock sell price: $33.95
# -----------------------------------------------------------------------
# 331 T
# stock purchase price: $31.13
# stock sell price: $35.38
# -----------------------------------------------------------------------
# 332 IVC
# stock purchase price: $17.76
# stock sell price: $14.49
# -----------------------------------------------------------------------
# 333 IVC
# stock purchase price: $12.78
# stock sell price: $19.71
# -----------------------------------------------------------------------
# 334 IVC
# stock purchase price: $19.51
# stock sell price: $19.68
# -----------------------------------------------------------------------
# 335 IVC
# stock purchase price: $18.7
# stock sell price: $12.68
# -----------------------------------------------------------------------
# 336 IVC
# stock purchase price: $12.61
# stock sell price: $11.55
# -----------------------------------------------------------------------
# 337 IVC
# stock purchase price: $11.45
# stock sell price: $17.25
# -----------------------------------------------------------------------
# 338 IVC
# stock purchase price: $8.75
# stock sell price: $5.05
# -----------------------------------------------------------------------
# 339 REX
# stock purchase price: $16.03
# stock sell price: $28.37
# -----------------------------------------------------------------------
# 340 REX
# stock purchase price: $28.41
# stock sell price: $19.44
# -----------------------------------------------------------------------
# 341 REX
# stock purchase price: $17.5
# stock sell price: $62.39
# -----------------------------------------------------------------------
# 342 REX
# stock purchase price: $63.88
# stock sell price: $61.76
# -----------------------------------------------------------------------
# 343 REX
# stock purchase price: $66.61
# stock sell price: $53.48
# -----------------------------------------------------------------------
# 344 REX
# stock purchase price: $52.92
# stock sell price: $88.13
# -----------------------------------------------------------------------
# 345 REX
# stock purchase price: $83.03
# stock sell price: $72.62
# -----------------------------------------------------------------------
# 346 MGA
# stock purchase price: $48.75
# stock sell price: $57.84
# -----------------------------------------------------------------------
# 347 GOLD
# stock purchase price: $12.58
# stock sell price: $13.58
# -----------------------------------------------------------------------
# 348 GOLD
# stock purchase price: $13.54
# stock sell price: $19.87
# -----------------------------------------------------------------------
# 349 CLF
# stock purchase price: $29.29
# stock sell price: $21.9
# -----------------------------------------------------------------------
# 350 CLF
# stock purchase price: $22.88
# stock sell price: $6.92
# -----------------------------------------------------------------------
# 351 OSK
# stock purchase price: $19.79
# stock sell price: $30.83
# -----------------------------------------------------------------------
# 352 CRY
# stock purchase price: $5.19
# stock sell price: $6.05
# -----------------------------------------------------------------------
# 353 POR
# stock purchase price: $24.74
# stock sell price: $30.29
# -----------------------------------------------------------------------
# 354 POR
# stock purchase price: $28.75
# stock sell price: $31.73
# -----------------------------------------------------------------------
# 355 INT
# stock purchase price: $23.61
# stock sell price: $29.65
# -----------------------------------------------------------------------
# 356 INT
# stock purchase price: $30.1
# stock sell price: $37.11
# -----------------------------------------------------------------------
# 357 MGM
# stock purchase price: $14.45
# stock sell price: $12.78
# -----------------------------------------------------------------------
# 358 MGM
# stock purchase price: $13.16
# stock sell price: $26.61
# -----------------------------------------------------------------------
# 359 MGM
# stock purchase price: $26.61
# stock sell price: $27.09
# ...
# stock purchase price: $19.15
# stock sell price: $16.75
# -----------------------------------------------------------------------
# 1339 ENLC
# stock purchase price: $15.3
# stock sell price: $11.19
# -----------------------------------------------------------------------
# 1340 ENLC
# stock purchase price: $11.32
# stock sell price: $7.61
# -----------------------------------------------------------------------
# 1341 PRTY
# stock purchase price: $7.79
# stock sell price: $4.6
# -----------------------------------------------------------------------
# 1342 PE
# stock purchase price: $18.56
# stock sell price: $17.37
# -----------------------------------------------------------------------
# 1343 RUBI
# stock purchase price: $5.47
# stock sell price: $2.09
# -----------------------------------------------------------------------
# 1344 RUBI
# stock purchase price: $2.38
# stock sell price: $6.01
# -----------------------------------------------------------------------
# 1345 LPG
# stock purchase price: $7.9
# stock sell price: $8.1
# -----------------------------------------------------------------------
# 1346 LPG
# stock purchase price: $8.09
# stock sell price: $9.7
# -----------------------------------------------------------------------
# 1347 LPG
# stock purchase price: $8.78
# stock sell price: $10.21
# -----------------------------------------------------------------------
# 1348 PSV
# stock purchase price: $0.9573
# stock sell price: $1.13
# -----------------------------------------------------------------------
# 1349 PSV
# stock purchase price: $1.14
# stock sell price: $4.3901
# -----------------------------------------------------------------------
# 1350 PSV
# stock purchase price: $3.1
# stock sell price: $1.5
# -----------------------------------------------------------------------
# 1351 RYAM
# stock purchase price: $13.21
# stock sell price: $3.16
# -----------------------------------------------------------------------
# 1352 TMST
# stock purchase price: $17.66
# stock sell price: $14.67
# -----------------------------------------------------------------------
# 1353 TMST
# stock purchase price: $17.53
# stock sell price: $11.17
# -----------------------------------------------------------------------
# 1354 TMST
# stock purchase price: $12.42
# stock sell price: $4.97
# -----------------------------------------------------------------------
# 1355 GLOP
# stock purchase price: $24.0
# stock sell price: $23.0
# -----------------------------------------------------------------------
# 1356 GLOP
# stock purchase price: $24.55
# stock sell price: $19.95
# -----------------------------------------------------------------------
# 1357 GLOP
# stock purchase price: $22.63
# stock sell price: $18.88
# -----------------------------------------------------------------------
# 1358 VRTV
# stock purchase price: $39.1
# stock sell price: $27.48
# -----------------------------------------------------------------------
# 1359 VRTV
# stock purchase price: $27.48
# stock sell price: $15.94
# -----------------------------------------------------------------------
# 1360 DNOW
# stock purchase price: $9.9
# stock sell price: $15.86
# -----------------------------------------------------------------------
# 1361 DNOW
# stock purchase price: $15.3
# stock sell price: $11.59
# -----------------------------------------------------------------------
# 1362 GMS
# stock purchase price: $19.7
# stock sell price: $29.44
# -----------------------------------------------------------------------
# 1363 MR
# stock purchase price: $1.35
# stock sell price: $14.24
# -----------------------------------------------------------------------
# 1364 MR
# stock purchase price: $13.98
# stock sell price: $3.07
# -----------------------------------------------------------------------
# 1365 VEC
# stock purchase price: $26.96
# stock sell price: $40.54
# -----------------------------------------------------------------------
# 1366 HMLP
# stock purchase price: $18.56
# stock sell price: $14.3
# -----------------------------------------------------------------------
# 1367 NEP
# stock purchase price: $30.62
# stock sell price: $38.76
# -----------------------------------------------------------------------
# 1368 NEP
# stock purchase price: $37.46
# stock sell price: $45.18
# -----------------------------------------------------------------------
# 1369 NEP
# stock purchase price: $44.6
# stock sell price: $51.27
# -----------------------------------------------------------------------
# 1370 EURN
# stock purchase price: $11.14
# stock sell price: $7.95
# -----------------------------------------------------------------------
# 1371 EURN
# stock purchase price: $7.8
# stock sell price: $8.6
# -----------------------------------------------------------------------
# 1372 EURN
# stock purchase price: $8.6
# stock sell price: $9.18
# -----------------------------------------------------------------------
# 1373 EURN
# stock purchase price: $9.38
# stock sell price: $7.87
# -----------------------------------------------------------------------
# 1374 WLKP
# stock purchase price: $24.85
# stock sell price: $23.25
# -----------------------------------------------------------------------
# 1375 WLKP
# stock purchase price: $22.6
# stock sell price: $22.63
# -----------------------------------------------------------------------
# 1376 WLKP
# stock purchase price: $N/A
# stock sell price: $21.18
# -----------------------------------------------------------------------
# 1377 FCAU
# stock purchase price: $15.24
# stock sell price: $13.2
# -----------------------------------------------------------------------
# 1378 ATTO
# stock purchase price: $3.6
# stock sell price: $2.29
# -----------------------------------------------------------------------
# 1379 VSLR
# stock purchase price: $3.0
# stock sell price: $4.1
# -----------------------------------------------------------------------
# 1380 VSLR
# stock purchase price: $4.1
# stock sell price: $5.34
# -----------------------------------------------------------------------
# 1381 VSLR
# stock purchase price: $4.81
# stock sell price: $8.31
# -----------------------------------------------------------------------
# 1382 KEN
# stock purchase price: $15.55
# stock sell price: $19.876
# -----------------------------------------------------------------------
# 1383 KEN
# stock purchase price: $19.51
# stock sell price: $20.79
# -----------------------------------------------------------------------
# 1384 CJ
# stock purchase price: $N/A
# stock sell price: $N/A
# -----------------------------------------------------------------------
# 1385 CJ
# stock purchase price: $N/A
# stock sell price: $32.49
# -----------------------------------------------------------------------
# 1386 CJ
# stock purchase price: $16.18
# stock sell price: $9.27
# -----------------------------------------------------------------------
# 1387 VSTO
# stock purchase price: $22.4
# stock sell price: $16.45
# -----------------------------------------------------------------------
# 1388 VSTO
# stock purchase price: $16.44
# stock sell price: $7.79
# -----------------------------------------------------------------------
# 1389 VSTO
# stock purchase price: $7.79
# stock sell price: $5.25
# -----------------------------------------------------------------------
# 1390 JAX
# stock purchase price: $N/A
# stock sell price: $N/A
# -----------------------------------------------------------------------
# 1391 JAX
# stock purchase price: $11.26
# stock sell price: $11.61
# -----------------------------------------------------------------------
# 1392 QSR
# stock purchase price: $39.65
# stock sell price: $39.14
# -----------------------------------------------------------------------
# 1393 IGT
# stock purchase price: $13.82
# stock sell price: $11.43
# -----------------------------------------------------------------------
# 1394 SUM
# stock purchase price: $15.83
# stock sell price: $21.01
# -----------------------------------------------------------------------
# 1395 BKI
# stock purchase price: $28.73
# stock sell price: $38.45
# -----------------------------------------------------------------------
# 1396 OR
# stock purchase price: $6.21
# stock sell price: $13.2835
# -----------------------------------------------------------------------
# 1397 OR
# stock purchase price: $11.13
# stock sell price: $N/A
# -----------------------------------------------------------------------
# 1398 OR
# stock purchase price: $9.55
# stock sell price: $11.66
# -----------------------------------------------------------------------
# 1399 OR
# stock purchase price: $11.86
# stock sell price: $12.97
# -----------------------------------------------------------------------
# 1400 EVH
# stock purchase price: $13.8
# stock sell price: $12.45
# -----------------------------------------------------------------------
# 1401 TGE
# stock purchase price: $20.15
# stock sell price: $22.63
# -----------------------------------------------------------------------
# 1402 BNED
# stock purchase price: $5.6
# stock sell price: $3.15
# -----------------------------------------------------------------------
# 1403 BNED
# stock purchase price: $3.14
# stock sell price: $3.66
# -----------------------------------------------------------------------
# 1404 AGR
# stock purchase price: $50.79
# stock sell price: $50.26
# -----------------------------------------------------------------------
# 1405 AGR
# stock purchase price: $49.36
# stock sell price: $51.46
# -----------------------------------------------------------------------
# 1406 GCI
# stock purchase price: $10.63
# stock sell price: $10.49
# -----------------------------------------------------------------------
# 1407 EXTN
# stock purchase price: $18.29
# stock sell price: $10.39
# -----------------------------------------------------------------------
# 1408 HPE
# stock purchase price: $14.49
# stock sell price: $13.49
# -----------------------------------------------------------------------
# 1409 NBLX
# stock purchase price: $36.9
# stock sell price: $24.03
# -----------------------------------------------------------------------
# 1410 BBU
# stock purchase price: $39.1
# stock sell price: $32.14
# -----------------------------------------------------------------------
# 1411 AFI
# stock purchase price: $13.45
# stock sell price: $6.45
# -----------------------------------------------------------------------
# 1412 FTS
# stock purchase price: $33.55
# stock sell price: $28.6091
# -----------------------------------------------------------------------
# 1413 FTS
# stock purchase price: $28.4655
# stock sell price: $30.3
# -----------------------------------------------------------------------
# 1414 FTS
# stock purchase price: $31.36
# stock sell price: $27.77
# -----------------------------------------------------------------------
# 1415 FTS
# stock purchase price: $28.0378
# stock sell price: $32.61
# -----------------------------------------------------------------------
# 1416 FTS
# stock purchase price: $32.61
# stock sell price: $32.72
# -----------------------------------------------------------------------
# 1417 FTS
# stock purchase price: $33.24
# stock sell price: $35.82
# -----------------------------------------------------------------------
# 1418 FTS
# stock purchase price: $36.68
# stock sell price: $42.28
# -----------------------------------------------------------------------
# 1419 ASH
# stock purchase price: $55.7
# stock sell price: $76.59
# -----------------------------------------------------------------------
# 1420 ASH
# stock purchase price: $73.71
# stock sell price: $82.66
# -----------------------------------------------------------------------
# 1421 AA
# stock purchase price: $27.54
# stock sell price: $17.61
# -----------------------------------------------------------------------
# 1422 CNDT
# stock purchase price: $13.98
# stock sell price: $5.99
# -----------------------------------------------------------------------
# 1423 INSW
# stock purchase price: $17.55
# stock sell price: $17.3
# -----------------------------------------------------------------------
# 1424 DXC
# stock purchase price: $38.2
# stock sell price: $24.71
# -----------------------------------------------------------------------
# 1425 DK
# stock purchase price: $15.06
# stock sell price: $37.7
# -----------------------------------------------------------------------
# 1426 DK
# stock purchase price: $15.18
# stock sell price: $24.17
# -----------------------------------------------------------------------
# 1427 KL
# stock purchase price: $3.09
# stock sell price: $3.6586
# -----------------------------------------------------------------------
# 1428 KL
# stock purchase price: $3.632
# stock sell price: $4.0507
# -----------------------------------------------------------------------
# 1429 HPR
# stock purchase price: $19.66
# stock sell price: $23.75
# -----------------------------------------------------------------------
# 1430 HPR
# stock purchase price: $8.22
# stock sell price: $5.4
# -----------------------------------------------------------------------
# 1431 HPR
# stock purchase price: $5.68
# stock sell price: $4.17
# -----------------------------------------------------------------------
# 1432 HPR
# stock purchase price: $4.46
# stock sell price: $4.82
# -----------------------------------------------------------------------
# 1433 HPR
# stock purchase price: $4.84
# stock sell price: $2.43
# -----------------------------------------------------------------------
# 1434 HPR
# stock purchase price: $2.3
# stock sell price: $1.13
# -----------------------------------------------------------------------
# 1435 NTR
# stock purchase price: $51.11
# stock sell price: $49.19
# -----------------------------------------------------------------------
# 1436 BH
# stock purchase price: $357.12
# stock sell price: $345.22
# -----------------------------------------------------------------------
# 1437 BH
# stock purchase price: $353.92
# stock sell price: $479.24
# -----------------------------------------------------------------------
# 1438 BH
# stock purchase price: $479.24
# stock sell price: $375.26
# -----------------------------------------------------------------------
# 1439 BH
# stock purchase price: $376.95
# stock sell price: $368.84
# -----------------------------------------------------------------------
# 1440 BH
# stock purchase price: $381.85
# stock sell price: $422.85
# -----------------------------------------------------------------------
# 1441 BH
# stock purchase price: $411.01
# stock sell price: $440.62
# -----------------------------------------------------------------------
# 1442 BH
# stock purchase price: $426.91
# stock sell price: $143.48
# -----------------------------------------------------------------------
# 1443 BH
# stock purchase price: $127.24
# stock sell price: $85.8
# -----------------------------------------------------------------------
# 1444 WRK
# stock purchase price: $57.06
# stock sell price: $64.74
# -----------------------------------------------------------------------
# 1445 WRK
# stock purchase price: $50.63
# stock sell price: $51.2
# -----------------------------------------------------------------------
# 1446 WRK
# stock purchase price: $46.07
# stock sell price: $33.01
# -----------------------------------------------------------------------
# 1447 SDRL
# stock purchase price: $3657.73828125
# stock sell price: $993.4266967773438
# -----------------------------------------------------------------------
# 1448 SDRL
# stock purchase price: $934.5172729492188
# stock sell price: $155.3065948486328
# -----------------------------------------------------------------------
# 1449 SDRL
# stock purchase price: $155.3065948486328
# stock sell price: $168.69509887695312
# -----------------------------------------------------------------------
# 1450 SDRL
# stock purchase price: $104.4302978515625
# stock sell price: $3.3
# -----------------------------------------------------------------------
# 1451 SDRL
# stock purchase price: $9.25
# stock sell price: $2.24
# -----------------------------------------------------------------------
# 1452 XRX
# stock purchase price: $8.37
# stock sell price: $8.02
# -----------------------------------------------------------------------
# 1453 XRX
# stock purchase price: $7.89
# stock sell price: $10.67
# -----------------------------------------------------------------------
# 1454 XRX
# stock purchase price: $10.78
# stock sell price: $13.98
# -----------------------------------------------------------------------
# 1455 XRX
# stock purchase price: $9.59
# stock sell price: $7.44
# -----------------------------------------------------------------------
# 1456 XRX
# stock purchase price: $30.85
# stock sell price: $29.11

# %%
# investigate observations with 'N/A' Stock_Purchase_Price or Stock_Sell_Price 
stock_price_df.query('Stock_Purchase_Price=="N/A" | Stock_Sell_Price=="N/A"')
# Out:
#      Ticker_Symbol                  Company_Name  Data_Date BM_Quintile  \
# 59            CATO              CATO CORP  -CL A 2018-01-31   Very High
# 163            OSG    OVERSEAS SHIPHOLDING GROUP 2011-12-31   Very High
# 164            OSG    OVERSEAS SHIPHOLDING GROUP 2012-12-31   Very High
# 171            PKD            PARKER DRILLING CO 2012-12-31   Very High
# 172            PKD            PARKER DRILLING CO 2014-12-31   Very High
# 173            PKD            PARKER DRILLING CO 2015-12-31   Very High
# 174            PKD            PARKER DRILLING CO 2016-12-31   Very High
# 175            PKD            PARKER DRILLING CO 2017-12-31   Very High
# 204            SUP      SUPERIOR INDUSTRIES INTL 2017-12-31   Very High
# 288           SBOW       SILVERBOW RESOURCES INC 2012-12-31   Very High
# 289           SBOW       SILVERBOW RESOURCES INC 2013-12-31   Very High
# 290           SBOW       SILVERBOW RESOURCES INC 2014-12-31   Very High
# 500            GES                     GUESS INC 2017-01-31   Very High
# 503            FRO                 FRONTLINE LTD 2018-12-31   Very High
# 523            EAF    GRAFTECH INTERNATIONAL LTD 2012-12-31   Very High
# 524            EAF    GRAFTECH INTERNATIONAL LTD 2013-12-31   Very High
# 525            EAF    GRAFTECH INTERNATIONAL LTD 2014-12-31   Very High
# 555            CBZ                      CBIZ INC 2014-12-31   Very High
# 646           ARCH                 ARCH COAL INC 2011-12-31   Very High
# 647           ARCH                 ARCH COAL INC 2012-12-31   Very High
# 648           ARCH                 ARCH COAL INC 2013-12-31   Very High
# 649           ARCH                 ARCH COAL INC 2014-12-31   Very High
# 684            BTU           PEABODY ENERGY CORP 2014-12-31   Very High
# 685            BTU           PEABODY ENERGY CORP 2015-12-31   Very High
# 762            HOS    HORNBECK OFFSHORE SVCS INC 2017-12-31   Very High
# 797            TRQ  TURQUOISE HILL RESOURCES LTD 2017-12-31   Very High
# 921            GNK      GENCO SHIPPING & TRADING 2011-12-31   Very High
# 922            GNK      GENCO SHIPPING & TRADING 2012-12-31   Very High
# 923            GNK      GENCO SHIPPING & TRADING 2013-12-31   Very High
# 930            GME                 GAMESTOP CORP 2012-01-31   Very High
# 932            GME                 GAMESTOP CORP 2017-01-31   Very High
# 937            DHT              DHT HOLDINGS INC 2013-12-31   Very High
# 966            OBE           OBSIDIAN ENERGY LTD 2016-12-31   Very High
# 976             SD          SANDRIDGE ENERGY INC 2012-12-31   Very High
# 977             SD          SANDRIDGE ENERGY INC 2013-12-31   Very High
# 978             SD          SANDRIDGE ENERGY INC 2014-12-31   Very High
# 995            DAC                   DANAOS CORP 2012-12-31   Very High
# 996            DAC                   DANAOS CORP 2013-12-31   Very High
# 1072           TGH  TEXTAINER GROUP HOLDINGS LTD 2016-12-31   Very High
# 1240            RH                            RH 2017-01-31   Very High
# 1258          AMPY           AMPLIFY ENERGY CORP 2016-12-31   Very High
# 1271          FELP           FORESIGHT ENERGY LP 2018-12-31   Very High
# 1332          CVEO                    CIVEO CORP 2018-12-31   Very High
# 1376          WLKP   WESTLAKE CHEMICAL PRTNRS LP 2018-12-31   Very High
# 1384            CJ       C&J ENERGY SERVICES INC 2014-12-31   Very High
# 1385            CJ       C&J ENERGY SERVICES INC 2015-12-31   Very High
# 1390           JAX   J. ALEXANDER'S HOLDINGS INC 2011-12-31   Very High
# 1397            OR         OSISKO GOLD ROYALTIES 2016-12-31   Very High
#
#       F_SCORE Purchase_Date   Sell_Date Stock_Purchase_Price Stock_Sell_Price
# 59          5    2018-03-30  2019-04-01                  N/A            15.28
# 163         1    2012-03-20  2013-03-20                  N/A              N/A
# 164         4    2013-09-06  2014-09-08                  N/A              N/A
# 171         6    2013-03-25  2014-03-25                  N/A              N/A
# 172         5    2015-03-19  2016-03-21                  N/A              N/A
# 173         3    2016-03-22  2017-03-22                  N/A              N/A
# 174         3    2017-03-17  2018-03-19                  N/A              N/A
# 175         6    2018-04-09  2019-04-09                  N/A            17.64
# 204         5    2018-03-30  2019-04-01                  N/A             5.51
# 288         3    2013-03-06  2014-03-06                  N/A              N/A
# 289         3    2014-03-24  2015-03-24                  N/A              N/A
# 290         3    2015-03-24  2016-03-24                  N/A              N/A
# 500         4    2017-03-30  2018-03-30                11.13              N/A
# 503         5    2019-04-19  2019-09-03                  N/A             8.14
# 523         5    2013-03-11  2014-03-11                  N/A              N/A
# 524         4    2014-03-14  2015-03-16                  N/A            0.002
# 525         3    2015-03-27  2016-03-28                  N/A              N/A
# 555         6    2015-04-03  2016-04-04                  N/A            10.27
# 646         4    2012-03-19  2013-03-19                  N/A              N/A
# 647         3    2013-03-19  2014-03-19                  N/A              N/A
# 648         3    2014-03-24  2015-03-24                  N/A              N/A
# 649         5    2015-03-20  2016-03-21                  N/A             0.29
# 684         4    2015-03-09  2016-03-09                  N/A              N/A
# 685         3    2016-03-28  2017-03-28                  N/A              N/A
# 762         2    2018-04-19  2019-04-19                 3.73              N/A
# 797         4    2018-03-30  2019-04-01                  N/A             1.65
# 921         4    2012-03-19  2013-03-19                  N/A              N/A
# 922         2    2013-03-21  2014-03-21                  N/A              N/A
# 923         4    2014-04-21  2015-04-21                  N/A             7.05
# 930         6    2012-03-29  2013-03-29                22.59              N/A
# 932         6    2017-03-30  2018-03-30                22.46              N/A
# 937         6    2014-04-03  2015-04-03                 7.99              N/A
# 966         5    2017-03-30  2018-03-30                 1.66              N/A
# 976         6    2013-03-19  2014-03-19                  N/A              N/A
# 977         6    2014-03-19  2015-03-19                  N/A              N/A
# 978         6    2015-02-27  2016-02-29                  N/A              N/A
# 995         5    2013-03-29  2014-03-31                  N/A              7.5
# 996         7    2014-04-03  2015-04-03                 7.25              N/A
# 1072        3    2017-04-14  2018-04-16                  N/A             17.6
# 1240        4    2017-03-30  2018-03-30                44.95              N/A
# 1258        4    2017-04-14  2018-04-16                  N/A            10.25
# 1271        5    2019-04-19  2019-09-03                  N/A             0.38
# 1332        3    2019-04-19  2019-09-03                  N/A             1.37
# 1376        5    2019-04-19  2019-09-03                  N/A            21.18
# 1384        4    2015-03-10  2016-03-10                  N/A              N/A
# 1385        3    2016-03-25  2017-03-27                  N/A            32.49
# 1390        7    2012-04-25  2013-04-25                  N/A              N/A
# 1397        4    2017-03-30  2018-03-30                11.13              N/A

# %%
# manually input 'N/A' observations by looking up on compustat

# observation for index 59
# change Purchase_Date to 2018-04-02
stock_price_df.loc[59, 'Purchase_Date'] = datetime.strptime(stock_price_df.loc[59, 'Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') - timedelta(days=3)
stock_price_df.loc[59, 'Stock_Purchase_Price'] = 14.62

# observation for index 163
stock_price_df.loc[163, 'Stock_Purchase_Price'] = 11.29
stock_price_df.loc[163, 'Stock_Sell_Price'] = 2.18

# observation for index 164
stock_price_df.loc[164, 'Stock_Purchase_Price'] = 3.07
stock_price_df.loc[164, 'Stock_Sell_Price'] = 6.05

# observation for index 171
stock_price_df.loc[171, 'Stock_Purchase_Price'] = 4.62
stock_price_df.loc[171, 'Stock_Sell_Price'] = 7.24

# observation for index 172
stock_price_df.loc[172, 'Stock_Purchase_Price'] = 3.11
stock_price_df.loc[172, 'Stock_Sell_Price'] = 2.28

# observation for index 173
stock_price_df.loc[173, 'Stock_Purchase_Price'] = 2.14
stock_price_df.loc[173, 'Stock_Sell_Price'] = 1.45

# observation for index 174
stock_price_df.loc[174, 'Stock_Purchase_Price'] = 1.6
stock_price_df.loc[174, 'Stock_Sell_Price'] = 0.7619

# observation for index 175
stock_price_df.loc[175, 'Stock_Purchase_Price'] = 0.493

# observation for index 204
# change Purchase_Date to 2018-04-02
stock_price_df.loc[204, 'Purchase_Date'] = datetime.strptime(stock_price_df.loc[204, 'Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[204, 'Stock_Purchase_Price'] = 13.05

# observation for index 288
stock_price_df.loc[288, 'Stock_Purchase_Price'] = 13.9
stock_price_df.loc[288, 'Stock_Sell_Price'] = 9.81

# observation for index 289
stock_price_df.loc[289, 'Stock_Purchase_Price'] = 10.4
stock_price_df.loc[289, 'Stock_Sell_Price'] = 2.18

# observation for index 290
stock_price_df.loc[290, 'Stock_Purchase_Price'] = 2.18
stock_price_df.loc[290, 'Stock_Sell_Price'] = 0.09

# observation for index 500
# change Purchase_Date to 2018-04-02
stock_price_df.loc[500, 'Sell_Date'] = datetime.strptime(stock_price_df.loc[500, 'Sell_Date'], '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[500, 'Stock_Sell_Price'] = 20.88

# observation for index 503
# change Purchase_Date to 2019-04-22
stock_price_df.loc[503, 'Purchase_Date'] = datetime.strptime(stock_price_df.loc[503, 'Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[503, 'Stock_Purchase_Price'] = 8.14

# observation for index 523
stock_price_df.loc[523, 'Stock_Purchase_Price'] = 7.01
stock_price_df.loc[523, 'Stock_Sell_Price'] = 10.26

# observation for index 524
stock_price_df.loc[524, 'Stock_Purchase_Price'] = 10.16
stock_price_df.loc[524, 'Stock_Sell_Price'] = 4.02

# observation for index 525
# cannot source pricing data; therefore leave as 'N/A'

# observation for index 555
# change Purchase_Date to 2015-04-06
stock_price_df.loc[555, 'Purchase_Date'] = datetime.strptime(stock_price_df.loc[555, 'Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[555, 'Stock_Purchase_Price'] = 9.38

# observation for index 646
stock_price_df.loc[646, 'Stock_Purchase_Price'] = 12.29
stock_price_df.loc[646, 'Stock_Sell_Price'] = 5.46

# observation for index 647
stock_price_df.loc[647, 'Stock_Purchase_Price'] = 5.46
stock_price_df.loc[647, 'Stock_Sell_Price'] = 4.35

# observation for index 648
stock_price_df.loc[648, 'Stock_Purchase_Price'] = 4.69
stock_price_df.loc[648, 'Stock_Sell_Price'] = 1.03

# observation for index 649
stock_price_df.loc[649, 'Stock_Purchase_Price'] = 0.9048

# observation for index 684
stock_price_df.loc[684, 'Stock_Purchase_Price'] = 6.35
stock_price_df.loc[684, 'Stock_Sell_Price'] = 5.89

# observation for index 685
stock_price_df.loc[685, 'Stock_Purchase_Price'] = 2.41
stock_price_df.loc[685, 'Stock_Sell_Price'] = 2.22

# observation for index 762
# change Purchase_Date to 2019-04-22
stock_price_df.loc[762, 'Sell_Date'] = datetime.strptime(stock_price_df.loc[762, 'Sell_Date'], '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[762, 'Stock_Sell_Price'] = 1.48

# observation for index 797
# change Purchase_Date to 2018-04-02
stock_price_df.loc[797, 'Purchase_Date'] = datetime.strptime(stock_price_df.loc[797, 'Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[797, 'Stock_Purchase_Price'] = 2.99

# observation for index 921
stock_price_df.loc[921, 'Stock_Purchase_Price'] = 6.87
stock_price_df.loc[921, 'Stock_Sell_Price'] = 2.79

# observation for index 922
stock_price_df.loc[922, 'Stock_Purchase_Price'] = 3.01
stock_price_df.loc[922, 'Stock_Sell_Price'] = 1.54

# observation for index 923
stock_price_df.loc[923, 'Stock_Purchase_Price'] = 1.7

# observation for index 930
# change Purchase_Date to 2013-04-01
stock_price_df.loc[930, 'Sell_Date'] = datetime.strptime(stock_price_df.loc[930, 'Sell_Date'], '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[930, 'Stock_Sell_Price'] = 29.76

# observation for index 932
# change Purchase_Date to 2018-04-02
stock_price_df.loc[932, 'Sell_Date'] = datetime.strptime(stock_price_df.loc[932, 'Sell_Date'], '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[932, 'Stock_Sell_Price'] = 12.82

# observation for index 937
# change Purchase_Date to 2015-04-06
stock_price_df.loc[937, 'Sell_Date'] = datetime.strptime(stock_price_df.loc[937, 'Sell_Date'], '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[937, 'Stock_Sell_Price'] = 7.24

# observation for index 966
# change Purchase_Date to 2018-04-30
stock_price_df.loc[966, 'Sell_Date'] = datetime.strptime(stock_price_df.loc[966, 'Sell_Date'], '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[966, 'Stock_Sell_Price'] = 1.04

# observation for index 976
stock_price_df.loc[976, 'Stock_Purchase_Price'] = 5.38
stock_price_df.loc[976, 'Stock_Sell_Price'] = 6.38

# observation for index 977
stock_price_df.loc[977, 'Stock_Purchase_Price'] = 6.38
stock_price_df.loc[977, 'Stock_Sell_Price'] = 1.57

# observation for index 978
stock_price_df.loc[978, 'Stock_Purchase_Price'] = 1.77
stock_price_df.loc[978, 'Stock_Sell_Price'] = 0.0426

# observation for index 995
# change Purchase_Date to 2013-04-01
stock_price_df.loc[995, 'Purchase_Date'] = datetime.strptime(stock_price_df.loc[995, 'Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[995, 'Stock_Purchase_Price'] = 4.11

# observation for index 996
# change Purchase_Date to 2015-04-06
stock_price_df.loc[996, 'Sell_Date'] = datetime.strptime(stock_price_df.loc[996, 'Sell_Date'], '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[996, 'Stock_Sell_Price'] = 6.46

# observation for index 1072
# change Purchase_Date to 2017-04-17
stock_price_df.loc[1072, 'Purchase_Date'] = datetime.strptime(stock_price_df.loc[1072, 'Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[1072, 'Stock_Purchase_Price'] = 13.9

# observation for index 1240
# change Purchase_Date to 2018-04-02
stock_price_df.loc[1240, 'Sell_Date'] = datetime.strptime(stock_price_df.loc[1240, 'Sell_Date'], '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[1240, 'Stock_Sell_Price'] = 89.44

# observation for index 1258
# change Purchase_Date to 2017-04-17
stock_price_df.loc[1258, 'Purchase_Date'] = datetime.strptime(stock_price_df.loc[1258, 'Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[1258, 'Stock_Purchase_Price'] = 0.128

# observation for index 1271
# change Purchase_Date to 2019-04-22
stock_price_df.loc[1271, 'Purchase_Date'] = datetime.strptime(stock_price_df.loc[1271, 'Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[1271, 'Stock_Purchase_Price'] = 1.56

# observation for index 1332
# change Purchase_Date to 2019-04-22
stock_price_df.loc[1332, 'Purchase_Date'] = datetime.strptime(stock_price_df.loc[1332, 'Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[1332, 'Stock_Purchase_Price'] = 2.12

# observation for index 1376
# change Purchase_Date to 2019-04-22
stock_price_df.loc[1376, 'Purchase_Date'] = datetime.strptime(stock_price_df.loc[1376, 'Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[1376, 'Stock_Purchase_Price'] = 22.67

# observation for index 1384
stock_price_df.loc[1384, 'Stock_Purchase_Price'] = 11.9
stock_price_df.loc[1384, 'Stock_Sell_Price'] = 1.75

# observation for index 1385
# change Purchase_Date to 2019-03-28
stock_price_df.loc[1385, 'Purchase_Date'] = datetime.strptime(stock_price_df.loc[1385, 'Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[1385, 'Stock_Purchase_Price'] = 1.46

# observation for index 1390
# cannot source pricing data; therefore leave as 'N/A'

# observation for index 1397
# change Purchase_Date to 2018-04-02
stock_price_df.loc[1397, 'Sell_Date'] = datetime.strptime(stock_price_df.loc[1397, 'Sell_Date'], '%Y-%m-%d') + timedelta(days=3)
stock_price_df.loc[1397, 'Stock_Sell_Price'] = 9.84

# %%
stock_price_df.count()
# Out:
# Ticker_Symbol           1455
# Company_Name            1455
# Data_Date               1455
# BM_Quintile             1455
# F_SCORE                 1455
# Purchase_Date           1455
# Sell_Date               1455
# Stock_Purchase_Price    1455
# Stock_Sell_Price        1455
# dtype: int64

# %% [markdown]
# ## Calculation of Holding Period Returns (Long and Short)

# %%
# calculate holding period return for a unit of stock (i.e. one stock in each observation in stock_price_df)
# the return for a long position and short position will be calculated
# note: the return be stored in a new column in stock_price_df

# create long holding period return column in stock_price_df
stock_price_df['Long_Holding_Period_Return_(%)'] = 0
# create short holding period return column in stock_price_df
stock_price_df['Short_Holding_Period_Return_(%)'] = 0
# calculate Long_Holding_Period_Return and Short_Holding_Period_Return_(%)
# note: long holding period return return = (stock sell price / stock purchase price) - 1
# note: short holding period return = (stock purchase price / stock sell price) - 1
# check if Stock_Purchase_Price and Stock_Sell_Price are not equal to 'N/A'
# if Stock_Purchase_Price and Stock_Sell_Price are equal to 'N/A', set long holding period return and short holding period return to 'N/A'
# otherwise long holding period return and short holding period return equals that of the prvious formulas above
for idx, row in stock_price_df.iterrows():
    if (row['Stock_Purchase_Price']=='N/A') & (row['Stock_Sell_Price']=='N/A'):
        stock_price_df.loc[idx, 'Long_Holding_Period_Return_(%)'] = 'N/A'
        stock_price_df.loc[idx, 'Short_Holding_Period_Return_(%)'] = 'N/A'
    else:
        stock_price_df.loc[idx, 'Long_Holding_Period_Return_(%)'] = (row['Stock_Sell_Price'] / row['Stock_Purchase_Price']) - 1
        stock_price_df.loc[idx, 'Short_Holding_Period_Return_(%)'] = (row['Stock_Purchase_Price'] / row['Stock_Sell_Price']) - 1

# %%
# convert 'Sell_Date' column to timestamp in stock_price_df
stock_price_df['Sell_Date'] = pd.to_datetime(stock_price_df['Sell_Date'])

# %% [markdown]
# ## Calculation of Annualized Holding Period Returns

# %%
# note: to compare against a suitable benchmark, it is necessary to calculate the annualized hold period return of each
#       observation in stock_price_df
#       the annualized holding period return is given by (1 + holding period return)^(365/days stock has been traded) - 1

# create new column to store long annualized holding period returns
stock_price_df['Long_Annualized_Holding_Period_Return_(%)'] = ''
# create new column to store short annualized holding period returns
stock_price_df['Short_Annualized_Holding_Period_Return_(%)'] = ''

for idx, row in stock_price_df.iterrows():
    if row['Long_Holding_Period_Return_(%)']=='N/A' and row['Short_Holding_Period_Return_(%)']=='N/A':
        stock_price_df.loc[idx, 'Long_Annualized_Holding_Period_Return_(%)'] = 'N/A'
        stock_price_df.loc[idx, 'Short_Annualized_Holding_Period_Return_(%)'] = 'N/A'
    else:
        purchase_date = datetime.strptime(stock_price_df.loc[idx, 'Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d')
        sell_date = datetime.strptime(stock_price_df.loc[idx, 'Sell_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d')
        holding_days = (sell_date - purchase_date).days
        stock_price_df.loc[idx, 'Long_Annualized_Holding_Period_Return_(%)'] = ((1 + row['Long_Holding_Period_Return_(%)'])**(365/holding_days) - 1)
        stock_price_df.loc[idx, 'Short_Annualized_Holding_Period_Return_(%)'] = ((1 + row['Short_Holding_Period_Return_(%)'])**(365/holding_days) - 1)

# %% [markdown]
# ## COMPUSTAT - SPDR S&P 500 ETF Data Extraction

# %%
# note: SPDR S&P 500 is a ETF which 'mimics' the movements of the S&P 500 index
# note: the return of the S&P 500 is used throughout investment management to assess the performance of portfolios
# note: the index acts as a benchmark and as a component to calculating excess returns
# note: the long holding period return and short holding period return will be calculated for SPDR relative to each observation in stock_price_df

# create a new column to store the purchase price of SPDR
stock_price_df['SPDR_Purchase_Price'] = ''
# create a new column to store the sell price of SPDR
stock_price_df['SPDR_Sell_Price'] = ''

# retrive the purchase price and sell price of the SPDR ETF for the purchase date and sell date for each observation in stock_price_df
for idx, row in stock_price_df.iterrows():
    if row['Long_Holding_Period_Return_(%)']=='N/A' and row['Short_Holding_Period_Return_(%)']=='N/A':
        stock_price_df.loc[idx, 'SPDR_Purchase_Price'] = 'N/A'
        stock_price_df.loc[idx, 'SPDR_Sell_Price'] = 'N/A'
    else:
        spdr_purchase_price = db.raw_sql("""SELECT DISTINCT prccd
                                            FROM comp.secd WHERE tic='SPY'
                                            AND datadate=%s""", params=([row['Purchase_Date'].strftime('%Y-%m-%d')]))
        spdr_sell_price = db.raw_sql("""SELECT DISTINCT prccd
                                            FROM comp.secd WHERE tic='SPY'
                                            AND datadate=%s""", params=([row['Sell_Date'].strftime('%Y-%m-%d')]))
        stock_price_df.loc[idx, 'SPDR_Purchase_Price'] = spdr_purchase_price['prccd'][0]
        stock_price_df.loc[idx, 'SPDR_Sell_Price'] = spdr_sell_price['prccd'][0]
        # provide user feedback
        print('-----------------------------------------------------------------------')
        print(idx, row['Ticker_Symbol'])
        print('spdr purchase date:', row['Purchase_Date'].strftime('%Y-%m-%d'))
        print('spdr purchase price $', spdr_purchase_price['prccd'][0], sep='')
        print('spdr sell date', row['Sell_Date'].strftime('%Y-%m-%d'))
        print('spdr sell price $', spdr_sell_price['prccd'][0], sep='')
# Out:
# -----------------------------------------------------------------------
# 0 AIR
# spdr purchase date: 2012-07-23
# spdr purchase price $135.09
# spdr sell date 2013-07-23
# spdr sell price $169.14
# -----------------------------------------------------------------------
# 1 AIR
# spdr purchase date: 2013-08-01
# spdr purchase price $170.66
# spdr sell date 2014-08-01
# spdr sell price $192.5
# -----------------------------------------------------------------------
# 2 AIR
# spdr purchase date: 2014-07-21
# spdr purchase price $197.34
# spdr sell date 2015-07-21
# spdr sell price $211.75
# -----------------------------------------------------------------------
# 3 AIR
# spdr purchase date: 2016-07-18
# spdr purchase price $216.4092
# spdr sell date 2017-07-18
# spdr sell price $245.66
# -----------------------------------------------------------------------
# 4 AIR
# spdr purchase date: 2019-07-18
# spdr purchase price $298.83
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 5 HES
# spdr purchase date: 2012-02-28
# spdr purchase price $137.559
# spdr sell date 2013-02-27
# spdr sell price $151.91
# -----------------------------------------------------------------------
# 6 HES
# spdr purchase date: 2013-03-04
# spdr purchase price $152.92
# spdr sell date 2014-03-04
# spdr sell price $187.58
# -----------------------------------------------------------------------
# 7 HES
# spdr purchase date: 2014-03-04
# spdr purchase price $187.58
# spdr sell date 2015-03-04
# spdr sell price $210.2301
# -----------------------------------------------------------------------
# 8 HES
# spdr purchase date: 2015-03-02
# spdr purchase price $211.99
# spdr sell date 2016-03-02
# spdr sell price $199.0
# -----------------------------------------------------------------------
# 9 HES
# spdr purchase date: 2016-02-29
# spdr purchase price $193.56
# spdr sell date 2017-02-28
# spdr sell price $236.47
# -----------------------------------------------------------------------
# 10 HES
# spdr purchase date: 2018-02-26
# spdr purchase price $277.9
# spdr sell date 2019-02-26
# spdr sell price $279.32
# -----------------------------------------------------------------------
# 11 HES
# spdr purchase date: 2019-02-25
# spdr purchase price $279.52
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 12 AP
# spdr purchase date: 2012-03-23
# spdr purchase price $139.65
# spdr sell date 2013-03-25
# spdr sell price $154.95
# -----------------------------------------------------------------------
# 13 AP
# spdr purchase date: 2013-03-22
# spdr purchase price $155.6
# spdr sell date 2014-03-24
# spdr sell price $185.43
# -----------------------------------------------------------------------
# 14 AP
# spdr purchase date: 2014-03-20
# spdr purchase price $187.747
# spdr sell date 2015-03-20
# spdr sell price $210.41
# -----------------------------------------------------------------------
# 15 AP
# spdr purchase date: 2015-03-24
# spdr purchase price $208.82
# spdr sell date 2016-03-24
# spdr sell price $203.12
# -----------------------------------------------------------------------
# 16 AP
# spdr purchase date: 2016-04-04
# spdr purchase price $206.25
# spdr sell date 2017-04-04
# spdr sell price $235.48
# -----------------------------------------------------------------------
# 17 AP
# spdr purchase date: 2018-04-09
# spdr purchase price $261.0
# spdr sell date 2019-04-09
# spdr sell price $287.31
# -----------------------------------------------------------------------
# 18 AP
# spdr purchase date: 2019-04-10
# spdr purchase price $288.29
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 19 APA
# spdr purchase date: 2012-03-02
# spdr purchase price $137.312
# spdr sell date 2013-03-04
# spdr sell price $152.92
# -----------------------------------------------------------------------
# 20 APA
# spdr purchase date: 2013-03-04
# spdr purchase price $152.92
# spdr sell date 2014-03-04
# spdr sell price $187.58
# -----------------------------------------------------------------------
# 21 APA
# spdr purchase date: 2014-03-03
# spdr purchase price $184.98
# spdr sell date 2015-03-03
# spdr sell price $211.12
# -----------------------------------------------------------------------
# 22 APA
# spdr purchase date: 2015-03-03
# spdr purchase price $211.12
# spdr sell date 2016-03-03
# spdr sell price $199.775
# -----------------------------------------------------------------------
# 23 APA
# spdr purchase date: 2019-03-11
# spdr purchase price $278.44
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 24 SSI
# spdr purchase date: 2011-04-07
# spdr purchase price $133.32
# spdr sell date 2012-04-09
# spdr sell price $138.22
# -----------------------------------------------------------------------
# 25 SSI
# spdr purchase date: 2012-04-09
# spdr purchase price $138.22
# spdr sell date 2013-04-09
# spdr sell price $156.75
# -----------------------------------------------------------------------
# 26 SSI
# spdr purchase date: 2016-04-19
# spdr purchase price $209.9
# spdr sell date 2017-04-19
# spdr sell price $233.44
# -----------------------------------------------------------------------
# 27 SSI
# spdr purchase date: 2017-04-13
# spdr purchase price $232.51
# spdr sell date 2018-04-13
# spdr sell price $265.15
# -----------------------------------------------------------------------
# 28 SSI
# spdr purchase date: 2018-05-29
# spdr purchase price $269.02
# spdr sell date 2019-05-29
# spdr sell price $278.27
# -----------------------------------------------------------------------
# 29 SSI
# spdr purchase date: 2019-05-06
# spdr purchase price $292.82
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 30 TREC
# spdr purchase date: 2019-04-11
# spdr purchase price $288.21
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 31 ADM
# spdr purchase date: 2011-08-26
# spdr purchase price $117.97
# spdr sell date 2012-08-27
# spdr sell price $141.54
# -----------------------------------------------------------------------
# 32 ADM
# spdr purchase date: 2012-08-29
# spdr purchase price $141.51
# spdr sell date 2013-08-29
# spdr sell price $164.17
# -----------------------------------------------------------------------
# 33 ADM
# spdr purchase date: 2016-02-22
# spdr purchase price $194.78
# spdr sell date 2017-02-21
# spdr sell price $236.49
# -----------------------------------------------------------------------
# 34 ADM
# spdr purchase date: 2018-02-20
# spdr purchase price $271.4
# spdr sell date 2019-02-20
# spdr sell price $278.41
# -----------------------------------------------------------------------
# 35 ADM
# spdr purchase date: 2019-02-21
# spdr purchase price $277.42
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 36 SWN
# spdr purchase date: 2016-02-26
# spdr purchase price $195.0892
# spdr sell date 2017-02-27
# spdr sell price $237.11
# -----------------------------------------------------------------------
# 37 SWN
# spdr purchase date: 2019-03-14
# spdr purchase price $281.16
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 38 ARW
# spdr purchase date: 2012-02-03
# spdr purchase price $134.54
# spdr sell date 2013-02-04
# spdr sell price $149.535
# -----------------------------------------------------------------------
# 39 ARW
# spdr purchase date: 2013-02-08
# spdr purchase price $151.8
# spdr sell date 2014-02-10
# spdr sell price $180.01
# -----------------------------------------------------------------------
# 40 ARW
# spdr purchase date: 2016-02-10
# spdr purchase price $185.27
# spdr sell date 2017-02-09
# spdr sell price $230.6
# -----------------------------------------------------------------------
# 41 ARW
# spdr purchase date: 2019-02-11
# spdr purchase price $270.62
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 42 ESTE
# spdr purchase date: 2018-04-16
# spdr purchase price $267.33
# spdr sell date 2019-04-16
# spdr sell price $290.16
# -----------------------------------------------------------------------
# 43 ESTE
# spdr purchase date: 2019-04-08
# spdr purchase price $288.79
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 44 BGG
# spdr purchase date: 2019-08-27
# spdr purchase price $286.87
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 45 CAL
# spdr purchase date: 2012-04-04
# spdr purchase price $139.86
# spdr sell date 2013-04-04
# spdr sell price $155.86
# -----------------------------------------------------------------------
# 46 CBT
# spdr purchase date: 2011-12-08
# spdr purchase price $123.95
# spdr sell date 2012-12-10
# spdr sell price $142.473
# -----------------------------------------------------------------------
# 47 CBT
# spdr purchase date: 2012-12-03
# spdr purchase price $141.45
# spdr sell date 2013-12-03
# spdr sell price $179.75
# -----------------------------------------------------------------------
# 48 CACI
# spdr purchase date: 2012-09-06
# spdr purchase price $143.77
# spdr sell date 2013-09-06
# spdr sell price $166.04
# -----------------------------------------------------------------------
# 49 CACI
# spdr purchase date: 2013-09-04
# spdr purchase price $165.75
# spdr sell date 2014-09-04
# spdr sell price $200.2101
# -----------------------------------------------------------------------
# 50 CACI
# spdr purchase date: 2014-09-15
# spdr purchase price $198.981
# spdr sell date 2015-09-15
# spdr sell price $198.46
# -----------------------------------------------------------------------
# 51 LUB
# spdr purchase date: 2011-11-16
# spdr purchase price $124.08
# spdr sell date 2012-11-16
# spdr sell price $136.37
# -----------------------------------------------------------------------
# 52 LUB
# spdr purchase date: 2012-11-16
# spdr purchase price $136.37
# spdr sell date 2013-11-18
# spdr sell price $179.42
# -----------------------------------------------------------------------
# 53 LUB
# spdr purchase date: 2013-11-15
# spdr purchase price $180.05
# spdr sell date 2014-11-17
# spdr sell price $204.37
# -----------------------------------------------------------------------
# 54 LUB
# spdr purchase date: 2014-11-21
# spdr purchase price $206.68
# spdr sell date 2015-11-23
# spdr sell price $209.07
# -----------------------------------------------------------------------
# 55 LUB
# spdr purchase date: 2015-11-30
# spdr purchase price $208.69
# spdr sell date 2016-11-30
# spdr sell price $220.38
# -----------------------------------------------------------------------
# 56 LUB
# spdr purchase date: 2016-12-06
# spdr purchase price $221.7
# spdr sell date 2017-12-06
# spdr sell price $263.24
# -----------------------------------------------------------------------
# 57 LUB
# spdr purchase date: 2017-12-07
# spdr purchase price $264.07
# spdr sell date 2018-12-07
# spdr sell price $263.57
# -----------------------------------------------------------------------
# 58 LUB
# spdr purchase date: 2018-12-12
# spdr purchase price $265.46
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 59 CATO
# spdr purchase date: 2018-03-27
# spdr purchase price $260.6
# spdr sell date 2019-04-01
# spdr sell price $285.83
# -----------------------------------------------------------------------
# 60 CATO
# spdr purchase date: 2019-04-08
# spdr purchase price $288.79
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 61 GCO
# spdr purchase date: 2018-04-13
# spdr purchase price $265.15
# spdr sell date 2019-04-15
# spdr sell price $289.97
# -----------------------------------------------------------------------
# 62 GCO
# spdr purchase date: 2019-04-15
# spdr purchase price $289.97
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 63 CTL
# spdr purchase date: 2012-02-29
# spdr purchase price $137.02
# spdr sell date 2013-02-28
# spdr sell price $151.61
# -----------------------------------------------------------------------
# 64 CTL
# spdr purchase date: 2014-03-03
# spdr purchase price $184.98
# spdr sell date 2015-03-03
# spdr sell price $211.12
# -----------------------------------------------------------------------
# 65 CTL
# spdr purchase date: 2016-02-29
# spdr purchase price $193.56
# spdr sell date 2017-02-28
# spdr sell price $236.47
# -----------------------------------------------------------------------
# 66 CTL
# spdr purchase date: 2017-02-28
# spdr purchase price $236.47
# spdr sell date 2018-02-28
# spdr sell price $271.65
# -----------------------------------------------------------------------
# 67 CTL
# spdr purchase date: 2018-03-06
# spdr purchase price $272.88
# spdr sell date 2019-03-06
# spdr sell price $277.33
# -----------------------------------------------------------------------
# 68 CTL
# spdr purchase date: 2019-03-13
# spdr purchase price $281.34
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 69 CSS
# spdr purchase date: 2011-06-08
# spdr purchase price $128.42
# spdr sell date 2012-06-08
# spdr sell price $133.1
# -----------------------------------------------------------------------
# 70 CSS
# spdr purchase date: 2012-06-08
# spdr purchase price $133.1
# spdr sell date 2013-06-10
# spdr sell price $164.8
# -----------------------------------------------------------------------
# 71 CSS
# spdr purchase date: 2013-06-06
# spdr purchase price $162.73
# spdr sell date 2014-06-06
# spdr sell price $195.375
# -----------------------------------------------------------------------
# 72 CSS
# spdr purchase date: 2014-06-04
# spdr purchase price $193.19
# spdr sell date 2015-06-04
# spdr sell price $210.1292
# -----------------------------------------------------------------------
# 73 CSS
# spdr purchase date: 2015-06-09
# spdr purchase price $208.45
# spdr sell date 2016-06-09
# spdr sell price $212.08
# -----------------------------------------------------------------------
# 74 CSS
# spdr purchase date: 2016-05-25
# spdr purchase price $209.28
# spdr sell date 2017-05-25
# spdr sell price $241.76
# -----------------------------------------------------------------------
# 75 CSS
# spdr purchase date: 2017-06-21
# spdr purchase price $242.95
# spdr sell date 2018-06-21
# spdr sell price $274.24
# -----------------------------------------------------------------------
# 76 CSS
# spdr purchase date: 2018-07-02
# spdr purchase price $271.86
# spdr sell date 2019-07-02
# spdr sell price $296.43
# -----------------------------------------------------------------------
# 77 CSS
# spdr purchase date: 2019-06-27
# spdr purchase price $291.5
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 78 CMC
# spdr purchase date: 2011-11-07
# spdr purchase price $126.26
# spdr sell date 2012-11-07
# spdr sell price $139.72
# -----------------------------------------------------------------------
# 79 CMC
# spdr purchase date: 2012-11-05
# spdr purchase price $141.8486
# spdr sell date 2013-11-05
# spdr sell price $176.27
# -----------------------------------------------------------------------
# 80 TAP
# spdr purchase date: 2012-02-28
# spdr purchase price $137.559
# spdr sell date 2013-02-27
# spdr sell price $151.91
# -----------------------------------------------------------------------
# 81 TAP
# spdr purchase date: 2013-02-25
# spdr purchase price $149.0
# spdr sell date 2014-02-25
# spdr sell price $184.84
# -----------------------------------------------------------------------
# 82 TAP
# spdr purchase date: 2014-02-18
# spdr purchase price $184.24
# spdr sell date 2015-02-18
# spdr sell price $210.13
# -----------------------------------------------------------------------
# 83 TAP
# spdr purchase date: 2019-02-12
# spdr purchase price $274.1
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 84 GLW
# spdr purchase date: 2012-02-15
# spdr purchase price $134.56
# spdr sell date 2013-02-14
# spdr sell price $152.29
# -----------------------------------------------------------------------
# 85 GLW
# spdr purchase date: 2013-02-19
# spdr purchase price $153.25
# spdr sell date 2014-02-19
# spdr sell price $183.02
# -----------------------------------------------------------------------
# 86 GLW
# spdr purchase date: 2014-02-11
# spdr purchase price $181.98
# spdr sell date 2015-02-11
# spdr sell price $206.93
# -----------------------------------------------------------------------
# 87 GLW
# spdr purchase date: 2016-02-16
# spdr purchase price $189.78
# spdr sell date 2017-02-15
# spdr sell price $234.92
# -----------------------------------------------------------------------
# 88 CTS
# spdr purchase date: 2012-03-08
# spdr purchase price $137.04
# spdr sell date 2013-03-08
# spdr sell price $155.44
# -----------------------------------------------------------------------
# 89 CW
# spdr purchase date: 2013-02-27
# spdr purchase price $151.91
# spdr sell date 2014-02-27
# spdr sell price $185.82
# -----------------------------------------------------------------------
# 90 DAN
# spdr purchase date: 2012-03-07
# spdr purchase price $135.69
# spdr sell date 2013-03-07
# spdr sell price $154.776
# -----------------------------------------------------------------------
# 91 DAN
# spdr purchase date: 2013-02-26
# spdr purchase price $150.02
# spdr sell date 2014-02-26
# spdr sell price $184.85
# -----------------------------------------------------------------------
# 92 DDS
# spdr purchase date: 2011-04-01
# spdr purchase price $133.15
# spdr sell date 2012-04-02
# spdr sell price $141.84
# -----------------------------------------------------------------------
# 93 DDS
# spdr purchase date: 2012-04-03
# spdr purchase price $141.26
# spdr sell date 2013-04-03
# spdr sell price $155.23
# -----------------------------------------------------------------------
# 94 DDS
# spdr purchase date: 2017-03-31
# spdr purchase price $235.74
# spdr sell date 2018-04-02
# spdr sell price $257.47
# -----------------------------------------------------------------------
# 95 DDS
# spdr purchase date: 2018-04-10
# spdr purchase price $265.15
# spdr sell date 2019-04-10
# spdr sell price $288.29
# -----------------------------------------------------------------------
# 96 DDS
# spdr purchase date: 2019-04-08
# spdr purchase price $288.79
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 97 DCO
# spdr purchase date: 2012-03-15
# spdr purchase price $140.72
# spdr sell date 2013-03-15
# spdr sell price $155.83
# -----------------------------------------------------------------------
# 98 DCO
# spdr purchase date: 2013-03-22
# spdr purchase price $155.6
# spdr sell date 2014-03-24
# spdr sell price $185.43
# -----------------------------------------------------------------------
# 99 DCO
# spdr purchase date: 2015-04-16
# spdr purchase price $210.37
# spdr sell date 2016-04-18
# spdr sell price $209.2392
# -----------------------------------------------------------------------
# 100 DCO
# spdr purchase date: 2016-03-24
# spdr purchase price $203.12
# spdr sell date 2017-03-24
# spdr sell price $233.86
# -----------------------------------------------------------------------
# 101 KODK
# spdr purchase date: 2018-04-09
# spdr purchase price $261.0
# spdr sell date 2019-04-09
# spdr sell price $287.31
# -----------------------------------------------------------------------
# 102 KODK
# spdr purchase date: 2019-04-16
# spdr purchase price $290.16
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 103 EBF
# spdr purchase date: 2011-05-11
# spdr purchase price $134.44
# spdr sell date 2012-05-11
# spdr sell price $135.61
# -----------------------------------------------------------------------
# 104 EBF
# spdr purchase date: 2012-05-16
# spdr purchase price $132.829
# spdr sell date 2013-05-16
# spdr sell price $165.34
# -----------------------------------------------------------------------
# 105 EBF
# spdr purchase date: 2013-05-14
# spdr purchase price $165.23
# spdr sell date 2014-05-14
# spdr sell price $189.06
# -----------------------------------------------------------------------
# 106 EBF
# spdr purchase date: 2014-05-15
# spdr purchase price $187.4
# spdr sell date 2015-05-15
# spdr sell price $212.44
# -----------------------------------------------------------------------
# 107 EQT
# spdr purchase date: 2016-02-16
# spdr purchase price $189.78
# spdr sell date 2017-02-15
# spdr sell price $234.92
# -----------------------------------------------------------------------
# 108 EQT
# spdr purchase date: 2018-02-20
# spdr purchase price $271.4
# spdr sell date 2019-02-20
# spdr sell price $278.41
# -----------------------------------------------------------------------
# 109 EQT
# spdr purchase date: 2019-02-19
# spdr purchase price $277.85
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 110 FOE
# spdr purchase date: 2012-03-22
# spdr purchase price $139.2
# spdr sell date 2013-03-22
# spdr sell price $155.6
# -----------------------------------------------------------------------
# 111 F
# spdr purchase date: 2019-02-26
# spdr purchase price $279.32
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 112 GLT
# spdr purchase date: 2016-03-21
# spdr purchase price $204.67
# spdr sell date 2017-03-21
# spdr sell price $233.73
# -----------------------------------------------------------------------
# 113 GLT
# spdr purchase date: 2019-03-13
# spdr purchase price $281.34
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 114 GTN
# spdr purchase date: 2012-03-27
# spdr purchase price $141.17
# spdr sell date 2013-03-27
# spdr sell price $156.19
# -----------------------------------------------------------------------
# 115 GTN
# spdr purchase date: 2013-04-02
# spdr purchase price $156.82
# spdr sell date 2014-04-02
# spdr sell price $188.88
# -----------------------------------------------------------------------
# 116 GTN
# spdr purchase date: 2019-03-12
# spdr purchase price $279.49
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 117 HHS
# spdr purchase date: 2013-03-26
# spdr purchase price $156.19
# spdr sell date 2014-03-26
# spdr sell price $184.97
# -----------------------------------------------------------------------
# 118 HP
# spdr purchase date: 2015-11-25
# spdr purchase price $209.32
# spdr sell date 2016-11-25
# spdr sell price $221.52
# -----------------------------------------------------------------------
# 119 HPQ
# spdr purchase date: 2012-12-31
# spdr purchase price $142.41
# spdr sell date 2013-12-31
# spdr sell price $184.69
# -----------------------------------------------------------------------
# 120 HFC
# spdr purchase date: 2012-03-16
# spdr purchase price $140.3
# spdr sell date 2013-03-18
# spdr sell price $154.97
# -----------------------------------------------------------------------
# 121 HFC
# spdr purchase date: 2015-03-06
# spdr purchase price $207.5
# spdr sell date 2016-03-07
# spdr sell price $200.59
# -----------------------------------------------------------------------
# 122 HFC
# spdr purchase date: 2017-03-08
# spdr purchase price $236.56
# spdr sell date 2018-03-08
# spdr sell price $274.1
# -----------------------------------------------------------------------
# 123 GFF
# spdr purchase date: 2011-11-29
# spdr purchase price $120.05
# spdr sell date 2012-11-29
# spdr sell price $142.12
# -----------------------------------------------------------------------
# 124 GFF
# spdr purchase date: 2012-11-28
# spdr purchase price $141.46
# spdr sell date 2013-11-29
# spdr sell price $181.0
# -----------------------------------------------------------------------
# 125 GFF
# spdr purchase date: 2013-12-03
# spdr purchase price $179.75
# spdr sell date 2014-12-03
# spdr sell price $207.89
# -----------------------------------------------------------------------
# 126 GFF
# spdr purchase date: 2014-11-24
# spdr purchase price $207.26
# spdr sell date 2015-11-24
# spdr sell price $209.35
# -----------------------------------------------------------------------
# 127 AXE
# spdr purchase date: 2019-03-11
# spdr purchase price $278.44
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 128 JEC
# spdr purchase date: 2015-11-24
# spdr purchase price $209.35
# spdr sell date 2016-11-25
# spdr sell price $221.52
# -----------------------------------------------------------------------
# 129 KFY
# spdr purchase date: 2013-07-02
# spdr purchase price $161.21
# spdr sell date 2014-07-02
# spdr sell price $197.23
# -----------------------------------------------------------------------
# 130 LCI
# spdr purchase date: 2012-09-20
# spdr purchase price $146.71
# spdr sell date 2013-09-20
# spdr sell price $170.72
# -----------------------------------------------------------------------
# 131 LCI
# spdr purchase date: 2018-08-30
# spdr purchase price $290.3
# spdr sell date 2019-08-30
# spdr sell price $292.45
# -----------------------------------------------------------------------
# 132 LCI
# spdr purchase date: 2019-08-28
# spdr purchase price $288.89
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 133 VHI
# spdr purchase date: 2016-03-24
# spdr purchase price $203.12
# spdr sell date 2017-03-24
# spdr sell price $233.86
# -----------------------------------------------------------------------
# 134 VHI
# spdr purchase date: 2019-03-28
# spdr purchase price $280.71
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 135 LPX
# spdr purchase date: 2012-03-19
# spdr purchase price $140.85
# spdr sell date 2013-03-19
# spdr sell price $154.61
# -----------------------------------------------------------------------
# 136 LXU
# spdr purchase date: 2016-03-22
# spdr purchase price $204.56
# spdr sell date 2017-03-22
# spdr sell price $234.28
# -----------------------------------------------------------------------
# 137 LXU
# spdr purchase date: 2017-03-15
# spdr purchase price $238.95
# spdr sell date 2018-03-15
# spdr sell price $275.0
# -----------------------------------------------------------------------
# 138 LXU
# spdr purchase date: 2018-03-20
# spdr purchase price $270.95
# spdr sell date 2019-03-20
# spdr sell price $281.55
# -----------------------------------------------------------------------
# 139 LXU
# spdr purchase date: 2019-03-18
# spdr purchase price $282.33
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 140 LDL
# spdr purchase date: 2012-03-21
# spdr purchase price $140.21
# spdr sell date 2013-03-21
# spdr sell price $154.359
# -----------------------------------------------------------------------
# 141 LDL
# spdr purchase date: 2019-03-18
# spdr purchase price $282.33
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 142 MTW
# spdr purchase date: 2019-02-21
# spdr purchase price $277.42
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 143 MCS
# spdr purchase date: 2011-08-22
# spdr purchase price $112.73
# spdr sell date 2012-08-22
# spdr sell price $141.82
# -----------------------------------------------------------------------
# 144 MCS
# spdr purchase date: 2012-08-16
# spdr purchase price $141.99
# spdr sell date 2013-08-16
# spdr sell price $165.83
# -----------------------------------------------------------------------
# 145 MCS
# spdr purchase date: 2013-08-20
# spdr purchase price $165.58
# spdr sell date 2014-08-20
# spdr sell price $198.92
# -----------------------------------------------------------------------
# 146 ETR
# spdr purchase date: 2013-02-28
# spdr purchase price $151.61
# spdr sell date 2014-02-28
# spdr sell price $186.29
# -----------------------------------------------------------------------
# 147 ETR
# spdr purchase date: 2014-03-03
# spdr purchase price $184.98
# spdr sell date 2015-03-03
# spdr sell price $211.12
# -----------------------------------------------------------------------
# 148 THC
# spdr purchase date: 2016-02-24
# spdr purchase price $193.2
# spdr sell date 2017-02-23
# spdr sell price $236.44
# -----------------------------------------------------------------------
# 149 THC
# spdr purchase date: 2017-03-16
# spdr purchase price $238.48
# spdr sell date 2018-03-16
# spdr sell price $274.2
# -----------------------------------------------------------------------
# 150 THC
# spdr purchase date: 2018-03-13
# spdr purchase price $276.72
# spdr sell date 2019-03-13
# spdr sell price $281.34
# -----------------------------------------------------------------------
# 151 THC
# spdr purchase date: 2019-03-14
# spdr purchase price $281.16
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 152 GPX
# spdr purchase date: 2019-04-18
# spdr purchase price $290.02
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 153 NR
# spdr purchase date: 2016-03-21
# spdr purchase price $204.67
# spdr sell date 2017-03-21
# spdr sell price $233.73
# -----------------------------------------------------------------------
# 154 NR
# spdr purchase date: 2019-03-11
# spdr purchase price $278.44
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 155 NL
# spdr purchase date: 2016-03-23
# spdr purchase price $203.2092
# spdr sell date 2017-03-23
# spdr sell price $234.03
# -----------------------------------------------------------------------
# 156 NL
# spdr purchase date: 2019-04-01
# spdr purchase price $285.83
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 157 NBL
# spdr purchase date: 2019-02-20
# spdr purchase price $278.41
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 158 MOV
# spdr purchase date: 2011-04-14
# spdr purchase price $131.56
# spdr sell date 2012-04-16
# spdr sell price $137.05
# -----------------------------------------------------------------------
# 159 MOV
# spdr purchase date: 2012-04-10
# spdr purchase price $135.9
# spdr sell date 2013-04-10
# spdr sell price $158.67
# -----------------------------------------------------------------------
# 160 OII
# spdr purchase date: 2019-03-19
# spdr purchase price $282.4
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 161 OLN
# spdr purchase date: 2016-03-16
# spdr purchase price $203.34
# spdr sell date 2017-03-16
# spdr sell price $238.48
# -----------------------------------------------------------------------
# 162 OLN
# spdr purchase date: 2019-03-19
# spdr purchase price $282.4
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 163 OSG
# spdr purchase date: 2012-03-20
# spdr purchase price $140.44
# spdr sell date 2013-03-20
# spdr sell price $155.69
# -----------------------------------------------------------------------
# 164 OSG
# spdr purchase date: 2013-09-06
# spdr purchase price $166.04
# spdr sell date 2014-09-08
# spdr sell price $200.59
# -----------------------------------------------------------------------
# 165 OSG
# spdr purchase date: 2016-03-18
# spdr purchase price $204.38
# spdr sell date 2017-03-20
# spdr sell price $236.77
# -----------------------------------------------------------------------
# 166 OSG
# spdr purchase date: 2017-04-11
# spdr purchase price $235.06
# spdr sell date 2018-04-11
# spdr sell price $263.76
# -----------------------------------------------------------------------
# 167 OSG
# spdr purchase date: 2018-04-16
# spdr purchase price $267.33
# spdr sell date 2019-04-16
# spdr sell price $290.16
# -----------------------------------------------------------------------
# 168 OSG
# spdr purchase date: 2019-04-12
# spdr purchase price $290.16
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 169 OMI
# spdr purchase date: 2018-03-12
# spdr purchase price $278.52
# spdr sell date 2019-03-12
# spdr sell price $279.49
# -----------------------------------------------------------------------
# 170 OMI
# spdr purchase date: 2019-03-19
# spdr purchase price $282.4
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 171 PKD
# spdr purchase date: 2013-03-25
# spdr purchase price $154.95
# spdr sell date 2014-03-25
# spdr sell price $186.31
# -----------------------------------------------------------------------
# 172 PKD
# spdr purchase date: 2015-03-19
# spdr purchase price $209.5
# spdr sell date 2016-03-21
# spdr sell price $204.67
# -----------------------------------------------------------------------
# 173 PKD
# spdr purchase date: 2016-03-22
# spdr purchase price $204.56
# spdr sell date 2017-03-22
# spdr sell price $234.28
# -----------------------------------------------------------------------
# 174 PKD
# spdr purchase date: 2017-03-17
# spdr purchase price $237.03
# spdr sell date 2018-03-19
# spdr sell price $270.49
# -----------------------------------------------------------------------
# 175 PKD
# spdr purchase date: 2018-04-09
# spdr purchase price $261.0
# spdr sell date 2019-04-09
# spdr sell price $287.31
# -----------------------------------------------------------------------
# 176 PKD
# spdr purchase date: 2019-06-07
# spdr purchase price $287.65
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 177 TPC
# spdr purchase date: 2012-03-26
# spdr purchase price $141.61
# spdr sell date 2013-03-26
# spdr sell price $156.19
# -----------------------------------------------------------------------
# 178 TPC
# spdr purchase date: 2013-03-20
# spdr purchase price $155.69
# spdr sell date 2014-03-20
# spdr sell price $187.747
# -----------------------------------------------------------------------
# 179 TPC
# spdr purchase date: 2014-03-10
# spdr purchase price $188.16
# spdr sell date 2015-03-10
# spdr sell price $204.98
# -----------------------------------------------------------------------
# 180 TPC
# spdr purchase date: 2015-03-16
# spdr purchase price $208.58
# spdr sell date 2016-03-16
# spdr sell price $203.34
# -----------------------------------------------------------------------
# 181 TPC
# spdr purchase date: 2016-03-15
# spdr purchase price $202.17
# spdr sell date 2017-03-15
# spdr sell price $238.95
# -----------------------------------------------------------------------
# 182 TPC
# spdr purchase date: 2017-03-09
# spdr purchase price $236.86
# spdr sell date 2018-03-09
# spdr sell price $278.87
# -----------------------------------------------------------------------
# 183 TPC
# spdr purchase date: 2018-04-02
# spdr purchase price $257.47
# spdr sell date 2019-04-02
# spdr sell price $285.97
# -----------------------------------------------------------------------
# 184 TPC
# spdr purchase date: 2019-03-01
# spdr purchase price $280.42
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 185 RAD
# spdr purchase date: 2019-05-20
# spdr purchase price $283.95
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 186 R
# spdr purchase date: 2019-03-08
# spdr purchase price $274.46
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 187 LUV
# spdr purchase date: 2012-02-10
# spdr purchase price $134.361
# spdr sell date 2013-02-11
# spdr sell price $151.77
# -----------------------------------------------------------------------
# 188 LUV
# spdr purchase date: 2013-02-08
# spdr purchase price $151.8
# spdr sell date 2014-02-10
# spdr sell price $180.01
# -----------------------------------------------------------------------
# 189 CVX
# spdr purchase date: 2016-02-29
# spdr purchase price $193.56
# spdr sell date 2017-02-28
# spdr sell price $236.47
# -----------------------------------------------------------------------
# 190 SCX
# spdr purchase date: 2011-09-19
# spdr purchase price $120.31
# spdr sell date 2012-09-19
# spdr sell price $146.7
# -----------------------------------------------------------------------
# 191 SCX
# spdr purchase date: 2012-09-17
# spdr purchase price $146.74
# spdr sell date 2013-09-17
# spdr sell price $171.07
# -----------------------------------------------------------------------
# 192 SCX
# spdr purchase date: 2013-09-18
# spdr purchase price $173.051
# spdr sell date 2014-09-18
# spdr sell price $201.82
# -----------------------------------------------------------------------
# 193 SCX
# spdr purchase date: 2014-09-17
# spdr purchase price $200.75
# spdr sell date 2015-09-17
# spdr sell price $199.73
# -----------------------------------------------------------------------
# 194 SCX
# spdr purchase date: 2015-09-04
# spdr purchase price $192.59
# spdr sell date 2016-09-06
# spdr sell price $219.0308
# -----------------------------------------------------------------------
# 195 SCX
# spdr purchase date: 2016-09-07
# spdr purchase price $219.01
# spdr sell date 2017-09-07
# spdr sell price $246.87
# -----------------------------------------------------------------------
# 196 SCX
# spdr purchase date: 2017-09-05
# spdr purchase price $246.06
# spdr sell date 2018-09-05
# spdr sell price $289.03
# -----------------------------------------------------------------------
# 197 SCX
# spdr purchase date: 2018-09-14
# spdr purchase price $290.88
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 198 SCX
# spdr purchase date: 2019-08-26
# spdr purchase price $288.0
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 199 SUP
# spdr purchase date: 2012-03-20
# spdr purchase price $140.44
# spdr sell date 2013-03-20
# spdr sell price $155.69
# -----------------------------------------------------------------------
# 200 SUP
# spdr purchase date: 2013-03-27
# spdr purchase price $156.19
# spdr sell date 2014-03-27
# spdr sell price $184.58
# -----------------------------------------------------------------------
# 201 SUP
# spdr purchase date: 2014-03-27
# spdr purchase price $184.58
# spdr sell date 2015-03-27
# spdr sell price $205.74
# -----------------------------------------------------------------------
# 202 SUP
# spdr purchase date: 2015-03-27
# spdr purchase price $205.74
# spdr sell date 2016-03-28
# spdr sell price $203.24
# -----------------------------------------------------------------------
# 203 SUP
# spdr purchase date: 2016-04-01
# spdr purchase price $206.92
# spdr sell date 2017-04-03
# spdr sell price $235.33
# -----------------------------------------------------------------------
# 204 SUP
# spdr purchase date: 2018-04-02
# spdr purchase price $257.47
# spdr sell date 2019-04-01
# spdr sell price $285.83
# -----------------------------------------------------------------------
# 205 SUP
# spdr purchase date: 2019-03-21
# spdr purchase price $284.73
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 206 TEX
# spdr purchase date: 2012-03-19
# spdr purchase price $140.85
# spdr sell date 2013-03-19
# spdr sell price $154.61
# -----------------------------------------------------------------------
# 207 TEX
# spdr purchase date: 2016-02-24
# spdr purchase price $193.2
# spdr sell date 2017-02-23
# spdr sell price $236.44
# -----------------------------------------------------------------------
# 208 TMO
# spdr purchase date: 2012-03-02
# spdr purchase price $137.312
# spdr sell date 2013-03-04
# spdr sell price $152.92
# -----------------------------------------------------------------------
# 209 TDW
# spdr purchase date: 2012-05-24
# spdr purchase price $132.53
# spdr sell date 2013-05-24
# spdr sell price $165.308
# -----------------------------------------------------------------------
# 210 TDW
# spdr purchase date: 2013-05-29
# spdr purchase price $165.22
# spdr sell date 2014-05-29
# spdr sell price $192.37
# -----------------------------------------------------------------------
# 211 TDW
# spdr purchase date: 2014-06-03
# spdr purchase price $192.8
# spdr sell date 2015-06-03
# spdr sell price $211.92
# -----------------------------------------------------------------------
# 212 TDW
# spdr purchase date: 2015-06-09
# spdr purchase price $208.45
# spdr sell date 2016-06-09
# spdr sell price $212.08
# -----------------------------------------------------------------------
# 213 TDW
# spdr purchase date: 2016-06-08
# spdr purchase price $212.37
# spdr sell date 2017-06-08
# spdr sell price $243.78
# -----------------------------------------------------------------------
# 214 TDW
# spdr purchase date: 2017-06-23
# spdr purchase price $243.13
# spdr sell date 2018-06-25
# spdr sell price $271.0
# -----------------------------------------------------------------------
# 215 TDW
# spdr purchase date: 2018-05-04
# spdr purchase price $266.02
# spdr sell date 2019-05-06
# spdr sell price $292.82
# -----------------------------------------------------------------------
# 216 TDW
# spdr purchase date: 2019-03-06
# spdr purchase price $277.33
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 217 TSN
# spdr purchase date: 2011-11-23
# spdr purchase price $116.56
# spdr sell date 2012-11-23
# spdr sell price $141.35
# -----------------------------------------------------------------------
# 218 TSN
# spdr purchase date: 2012-11-19
# spdr purchase price $139.13
# spdr sell date 2013-11-19
# spdr sell price $179.03
# -----------------------------------------------------------------------
# 219 UFI
# spdr purchase date: 2011-09-15
# spdr purchase price $121.43
# spdr sell date 2012-09-17
# spdr sell price $146.74
# -----------------------------------------------------------------------
# 220 UFI
# spdr purchase date: 2012-09-10
# spdr purchase price $143.51
# spdr sell date 2013-09-10
# spdr sell price $168.87
# -----------------------------------------------------------------------
# 221 UFI
# spdr purchase date: 2019-08-29
# spdr purchase price $292.58
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 222 MRO
# spdr purchase date: 2012-03-05
# spdr purchase price $136.75
# spdr sell date 2013-03-05
# spdr sell price $154.29
# -----------------------------------------------------------------------
# 223 MRO
# spdr purchase date: 2013-02-22
# spdr purchase price $151.89
# spdr sell date 2014-02-24
# spdr sell price $184.91
# -----------------------------------------------------------------------
# 224 MRO
# spdr purchase date: 2015-03-03
# spdr purchase price $211.12
# spdr sell date 2016-03-03
# spdr sell price $199.775
# -----------------------------------------------------------------------
# 225 MRO
# spdr purchase date: 2016-02-26
# spdr purchase price $195.0892
# spdr sell date 2017-02-27
# spdr sell price $237.11
# -----------------------------------------------------------------------
# 226 MRO
# spdr purchase date: 2017-02-27
# spdr purchase price $237.11
# spdr sell date 2018-02-27
# spdr sell price $274.43
# -----------------------------------------------------------------------
# 227 MRO
# spdr purchase date: 2019-02-27
# spdr purchase price $279.2
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 228 S
# spdr purchase date: 2012-02-27
# spdr purchase price $137.16
# spdr sell date 2013-02-26
# spdr sell price $150.02
# -----------------------------------------------------------------------
# 229 S
# spdr purchase date: 2015-06-09
# spdr purchase price $208.45
# spdr sell date 2016-06-09
# spdr sell price $212.08
# -----------------------------------------------------------------------
# 230 S
# spdr purchase date: 2016-05-25
# spdr purchase price $209.28
# spdr sell date 2017-05-25
# spdr sell price $241.76
# -----------------------------------------------------------------------
# 231 S
# spdr purchase date: 2018-06-08
# spdr purchase price $278.19
# spdr sell date 2019-06-10
# spdr sell price $288.97
# -----------------------------------------------------------------------
# 232 S
# spdr purchase date: 2019-06-05
# spdr purchase price $282.96
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 233 UVV
# spdr purchase date: 2011-06-06
# spdr purchase price $129.045
# spdr sell date 2012-06-06
# spdr sell price $131.97
# -----------------------------------------------------------------------
# 234 UVV
# spdr purchase date: 2012-06-06
# spdr purchase price $131.97
# spdr sell date 2013-06-06
# spdr sell price $162.73
# -----------------------------------------------------------------------
# 235 UVV
# spdr purchase date: 2013-06-04
# spdr purchase price $163.56
# spdr sell date 2014-06-04
# spdr sell price $193.19
# -----------------------------------------------------------------------
# 236 UVV
# spdr purchase date: 2014-06-03
# spdr purchase price $192.8
# spdr sell date 2015-06-03
# spdr sell price $211.92
# -----------------------------------------------------------------------
# 237 UVV
# spdr purchase date: 2015-06-08
# spdr purchase price $208.48
# spdr sell date 2016-06-08
# spdr sell price $212.37
# -----------------------------------------------------------------------
# 238 UVV
# spdr purchase date: 2016-06-07
# spdr purchase price $211.68
# spdr sell date 2017-06-07
# spdr sell price $243.66
# -----------------------------------------------------------------------
# 239 UVV
# spdr purchase date: 2018-06-05
# spdr purchase price $275.1
# spdr sell date 2019-06-05
# spdr sell price $282.96
# -----------------------------------------------------------------------
# 240 UVV
# spdr purchase date: 2019-05-28
# spdr purchase price $280.15
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 241 VSH
# spdr purchase date: 2012-03-06
# spdr purchase price $134.75
# spdr sell date 2013-03-06
# spdr sell price $154.5
# -----------------------------------------------------------------------
# 242 VSH
# spdr purchase date: 2013-02-25
# spdr purchase price $149.0
# spdr sell date 2014-02-25
# spdr sell price $184.84
# -----------------------------------------------------------------------
# 243 VSH
# spdr purchase date: 2014-02-24
# spdr purchase price $184.91
# spdr sell date 2015-02-24
# spdr sell price $211.81
# -----------------------------------------------------------------------
# 244 VSH
# spdr purchase date: 2015-02-23
# spdr purchase price $211.209
# spdr sell date 2016-02-24
# spdr sell price $193.2
# -----------------------------------------------------------------------
# 245 VSH
# spdr purchase date: 2016-02-17
# spdr purchase price $192.88
# spdr sell date 2017-02-16
# spdr sell price $234.72
# -----------------------------------------------------------------------
# 246 GHC
# spdr purchase date: 2012-03-01
# spdr purchase price $137.73
# spdr sell date 2013-03-01
# spdr sell price $152.11
# -----------------------------------------------------------------------
# 247 GHC
# spdr purchase date: 2013-03-01
# spdr purchase price $152.11
# spdr sell date 2014-03-03
# spdr sell price $184.98
# -----------------------------------------------------------------------
# 248 GHC
# spdr purchase date: 2016-03-10
# spdr purchase price $199.54
# spdr sell date 2017-03-10
# spdr sell price $237.69
# -----------------------------------------------------------------------
# 249 GHC
# spdr purchase date: 2017-03-13
# spdr purchase price $237.81
# spdr sell date 2018-03-13
# spdr sell price $276.72
# -----------------------------------------------------------------------
# 250 GHC
# spdr purchase date: 2018-02-27
# spdr purchase price $274.43
# spdr sell date 2019-02-27
# spdr sell price $279.2
# -----------------------------------------------------------------------
# 251 GHC
# spdr purchase date: 2019-03-08
# spdr purchase price $274.46
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 252 AVA
# spdr purchase date: 2012-03-08
# spdr purchase price $137.04
# spdr sell date 2013-03-08
# spdr sell price $155.44
# -----------------------------------------------------------------------
# 253 AVA
# spdr purchase date: 2013-03-04
# spdr purchase price $152.92
# spdr sell date 2014-03-04
# spdr sell price $187.58
# -----------------------------------------------------------------------
# 254 WMK
# spdr purchase date: 2018-03-21
# ...
# spdr sell price $265.15
# -----------------------------------------------------------------------
# 1372 EURN
# spdr purchase date: 2018-05-23
# spdr purchase price $273.36
# spdr sell date 2019-05-23
# spdr sell price $282.14
# -----------------------------------------------------------------------
# 1373 EURN
# spdr purchase date: 2019-04-30
# spdr purchase price $294.02
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1374 WLKP
# spdr purchase date: 2017-04-13
# spdr purchase price $232.51
# spdr sell date 2018-04-13
# spdr sell price $265.15
# -----------------------------------------------------------------------
# 1375 WLKP
# spdr purchase date: 2018-04-24
# spdr purchase price $262.98
# spdr sell date 2019-04-24
# spdr sell price $292.23
# -----------------------------------------------------------------------
# 1376 WLKP
# spdr purchase date: 2019-04-22
# spdr purchase price $290.27
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1377 FCAU
# spdr purchase date: 2019-04-01
# spdr purchase price $285.83
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1378 ATTO
# spdr purchase date: 2019-04-16
# spdr purchase price $290.16
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1379 VSLR
# spdr purchase date: 2017-04-10
# spdr purchase price $235.34
# spdr sell date 2018-04-10
# spdr sell price $265.15
# -----------------------------------------------------------------------
# 1380 VSLR
# spdr purchase date: 2018-04-10
# spdr purchase price $265.15
# spdr sell date 2019-04-10
# spdr sell price $288.29
# -----------------------------------------------------------------------
# 1381 VSLR
# spdr purchase date: 2019-03-25
# spdr purchase price $279.04
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1382 KEN
# spdr purchase date: 2018-06-18
# spdr purchase price $276.56
# spdr sell date 2019-06-18
# spdr sell price $292.4
# -----------------------------------------------------------------------
# 1383 KEN
# spdr purchase date: 2019-05-06
# spdr purchase price $292.82
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1384 CJ
# spdr purchase date: 2015-03-10
# spdr purchase price $204.98
# spdr sell date 2016-03-10
# spdr sell price $199.54
# -----------------------------------------------------------------------
# 1385 CJ
# spdr purchase date: 2016-03-28
# spdr purchase price $203.24
# spdr sell date 2017-03-27
# spdr sell price $233.62
# -----------------------------------------------------------------------
# 1386 CJ
# spdr purchase date: 2019-03-15
# spdr purchase price $281.31
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1387 VSTO
# spdr purchase date: 2017-06-02
# spdr purchase price $244.17
# spdr sell date 2018-06-04
# spdr sell price $274.9
# -----------------------------------------------------------------------
# 1388 VSTO
# spdr purchase date: 2018-06-01
# spdr purchase price $273.6
# spdr sell date 2019-06-03
# spdr sell price $274.57
# -----------------------------------------------------------------------
# 1389 VSTO
# spdr purchase date: 2019-06-03
# spdr purchase price $274.57
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1391 JAX
# spdr purchase date: 2019-04-10
# spdr purchase price $288.29
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1392 QSR
# spdr purchase date: 2015-03-18
# spdr purchase price $210.46
# spdr sell date 2016-03-18
# spdr sell price $204.38
# -----------------------------------------------------------------------
# 1393 IGT
# spdr purchase date: 2019-03-11
# spdr purchase price $278.44
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1394 SUM
# spdr purchase date: 2019-02-11
# spdr purchase price $270.62
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1395 BKI
# spdr purchase date: 2016-03-15
# spdr purchase price $202.17
# spdr sell date 2017-03-15
# spdr sell price $238.95
# -----------------------------------------------------------------------
# 1396 OR
# spdr purchase date: 2014-04-01
# spdr purchase price $188.25
# spdr sell date 2015-04-01
# spdr sell price $205.7
# -----------------------------------------------------------------------
# 1397 OR
# spdr purchase date: 2017-03-30
# spdr purchase price $236.29
# spdr sell date 2018-04-02
# spdr sell price $257.47
# -----------------------------------------------------------------------
# 1398 OR
# spdr purchase date: 2018-03-22
# spdr purchase price $263.67
# spdr sell date 2019-03-22
# spdr sell price $279.25
# -----------------------------------------------------------------------
# 1399 OR
# spdr purchase date: 2019-03-25
# spdr purchase price $279.04
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1400 EVH
# spdr purchase date: 2018-04-02
# spdr purchase price $257.47
# spdr sell date 2019-04-02
# spdr sell price $285.97
# -----------------------------------------------------------------------
# 1401 TGE
# spdr purchase date: 2018-02-28
# spdr purchase price $271.65
# spdr sell date 2019-02-28
# spdr sell price $278.68
# -----------------------------------------------------------------------
# 1402 BNED
# spdr purchase date: 2018-07-02
# spdr purchase price $271.86
# spdr sell date 2019-07-02
# spdr sell price $296.43
# -----------------------------------------------------------------------
# 1403 BNED
# spdr purchase date: 2019-06-25
# spdr purchase price $290.76
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1404 AGR
# spdr purchase date: 2018-04-02
# spdr purchase price $257.47
# spdr sell date 2019-04-02
# spdr sell price $285.97
# -----------------------------------------------------------------------
# 1405 AGR
# spdr purchase date: 2019-03-21
# spdr purchase price $284.73
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1406 GCI
# spdr purchase date: 2019-03-19
# spdr purchase price $282.4
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1407 EXTN
# spdr purchase date: 2019-03-20
# spdr purchase price $281.55
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1408 HPE
# spdr purchase date: 2018-12-13
# spdr purchase price $265.37
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1409 NBLX
# spdr purchase date: 2019-04-12
# spdr purchase price $290.16
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1410 BBU
# spdr purchase date: 2019-04-09
# spdr purchase price $287.31
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1411 AFI
# spdr purchase date: 2019-03-15
# spdr purchase price $281.31
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1412 FTS
# spdr purchase date: 2013-04-02
# spdr purchase price $156.82
# spdr sell date 2014-04-02
# spdr sell price $188.88
# -----------------------------------------------------------------------
# 1413 FTS
# spdr purchase date: 2014-04-01
# spdr purchase price $188.25
# spdr sell date 2015-04-01
# spdr sell price $205.7
# -----------------------------------------------------------------------
# 1414 FTS
# spdr purchase date: 2015-02-25
# spdr purchase price $211.63
# spdr sell date 2016-02-26
# spdr sell price $195.0892
# -----------------------------------------------------------------------
# 1415 FTS
# spdr purchase date: 2016-02-23
# spdr purchase price $192.32
# spdr sell date 2017-02-22
# spdr sell price $236.28
# -----------------------------------------------------------------------
# 1416 FTS
# spdr purchase date: 2017-02-22
# spdr purchase price $236.28
# spdr sell date 2018-02-22
# spdr sell price $270.4
# -----------------------------------------------------------------------
# 1417 FTS
# spdr purchase date: 2018-02-26
# spdr purchase price $277.9
# spdr sell date 2019-02-26
# spdr sell price $279.32
# -----------------------------------------------------------------------
# 1418 FTS
# spdr purchase date: 2019-03-15
# spdr purchase price $281.31
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1419 ASH
# spdr purchase date: 2011-12-08
# spdr purchase price $123.95
# spdr sell date 2012-12-10
# spdr sell price $142.473
# -----------------------------------------------------------------------
# 1420 ASH
# spdr purchase date: 2017-11-29
# spdr purchase price $262.71
# spdr sell date 2018-11-29
# spdr sell price $273.98
# -----------------------------------------------------------------------
# 1421 AA
# spdr purchase date: 2019-03-26
# spdr purchase price $281.12
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1422 CNDT
# spdr purchase date: 2019-04-01
# spdr purchase price $285.83
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1423 INSW
# spdr purchase date: 2019-04-08
# spdr purchase price $288.79
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1424 DXC
# spdr purchase date: 2011-06-15
# spdr purchase price $127.02
# spdr sell date 2012-06-15
# spdr sell price $134.14
# -----------------------------------------------------------------------
# 1425 DK
# spdr purchase date: 2012-04-02
# spdr purchase price $141.84
# spdr sell date 2013-04-02
# spdr sell price $156.82
# -----------------------------------------------------------------------
# 1426 DK
# spdr purchase date: 2016-03-24
# spdr purchase price $203.12
# spdr sell date 2017-03-24
# spdr sell price $233.86
# -----------------------------------------------------------------------
# 1427 KL
# spdr purchase date: 2013-07-18
# spdr purchase price $168.87
# spdr sell date 2014-07-18
# spdr sell price $197.7099
# -----------------------------------------------------------------------
# 1428 KL
# spdr purchase date: 2014-07-11
# spdr purchase price $196.61
# spdr sell date 2015-07-13
# spdr sell price $209.77
# -----------------------------------------------------------------------
# 1429 HPR
# spdr purchase date: 2013-03-11
# spdr purchase price $156.03
# spdr sell date 2014-03-11
# spdr sell price $187.23
# -----------------------------------------------------------------------
# 1430 HPR
# spdr purchase date: 2015-03-23
# spdr purchase price $210.0
# spdr sell date 2016-03-23
# spdr sell price $203.2092
# -----------------------------------------------------------------------
# 1431 HPR
# spdr purchase date: 2016-03-24
# spdr purchase price $203.12
# spdr sell date 2017-03-24
# spdr sell price $233.86
# -----------------------------------------------------------------------
# 1432 HPR
# spdr purchase date: 2017-03-16
# spdr purchase price $238.48
# spdr sell date 2018-03-16
# spdr sell price $274.2
# -----------------------------------------------------------------------
# 1433 HPR
# spdr purchase date: 2018-03-19
# spdr purchase price $270.49
# spdr sell date 2019-03-19
# spdr sell price $282.4
# -----------------------------------------------------------------------
# 1434 HPR
# spdr purchase date: 2019-03-14
# spdr purchase price $281.16
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1435 NTR
# spdr purchase date: 2019-03-26
# spdr purchase price $281.12
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1436 BH
# spdr purchase date: 2011-12-14
# spdr purchase price $121.74
# spdr sell date 2012-12-14
# spdr sell price $142.1051
# -----------------------------------------------------------------------
# 1437 BH
# spdr purchase date: 2012-12-11
# spdr purchase price $143.44
# spdr sell date 2013-12-11
# spdr sell price $178.72
# -----------------------------------------------------------------------
# 1438 BH
# spdr purchase date: 2013-12-11
# spdr purchase price $178.72
# spdr sell date 2014-12-11
# spdr sell price $204.19
# -----------------------------------------------------------------------
# 1439 BH
# spdr purchase date: 2014-12-02
# spdr purchase price $207.085
# spdr sell date 2015-12-02
# spdr sell price $208.529
# -----------------------------------------------------------------------
# 1440 BH
# spdr purchase date: 2016-03-02
# spdr purchase price $199.0
# spdr sell date 2017-03-02
# spdr sell price $238.27
# -----------------------------------------------------------------------
# 1441 BH
# spdr purchase date: 2017-03-13
# spdr purchase price $237.81
# spdr sell date 2018-03-13
# spdr sell price $276.72
# -----------------------------------------------------------------------
# 1442 BH
# spdr purchase date: 2018-03-19
# spdr purchase price $270.49
# spdr sell date 2019-03-19
# spdr sell price $282.4
# -----------------------------------------------------------------------
# 1443 BH
# spdr purchase date: 2019-03-08
# spdr purchase price $274.46
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1444 WRK
# spdr purchase date: 2011-12-06
# spdr purchase price $126.26
# spdr sell date 2012-12-06
# spdr sell price $141.98
# -----------------------------------------------------------------------
# 1445 WRK
# spdr purchase date: 2015-11-30
# spdr purchase price $208.69
# spdr sell date 2016-11-30
# spdr sell price $220.38
# -----------------------------------------------------------------------
# 1446 WRK
# spdr purchase date: 2018-11-19
# spdr purchase price $269.1
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1447 SDRL
# spdr purchase date: 2015-05-08
# spdr purchase price $211.62
# spdr sell date 2016-05-09
# spdr sell price $205.8892
# -----------------------------------------------------------------------
# 1448 SDRL
# spdr purchase date: 2016-05-18
# spdr purchase price $204.91
# spdr sell date 2017-05-18
# spdr sell price $236.77
# -----------------------------------------------------------------------
# 1449 SDRL
# spdr purchase date: 2017-05-18
# spdr purchase price $236.77
# spdr sell date 2018-05-18
# spdr sell price $271.33
# -----------------------------------------------------------------------
# 1450 SDRL
# spdr purchase date: 2018-06-19
# spdr purchase price $275.5
# spdr sell date 2019-06-19
# spdr sell price $293.06
# -----------------------------------------------------------------------
# 1451 SDRL
# spdr purchase date: 2019-04-26
# spdr purchase price $293.41
# spdr sell date 2019-09-03
# spdr sell price $290.74
# -----------------------------------------------------------------------
# 1452 XRX
# spdr purchase date: 2012-02-27
# spdr purchase price $137.16
# spdr sell date 2013-02-26
# spdr sell price $150.02
# -----------------------------------------------------------------------
# 1453 XRX
# spdr purchase date: 2013-02-25
# spdr purchase price $149.0
# spdr sell date 2014-02-25
# spdr sell price $184.84
# -----------------------------------------------------------------------
# 1454 XRX
# spdr purchase date: 2014-02-24
# spdr purchase price $184.91
# spdr sell date 2015-02-24
# spdr sell price $211.81
# -----------------------------------------------------------------------
# 1455 XRX
# spdr purchase date: 2016-02-22
# spdr purchase price $194.78
# spdr sell date 2017-02-21
# spdr sell price $236.49
# -----------------------------------------------------------------------
# 1456 XRX
# spdr purchase date: 2019-03-06
# spdr purchase price $277.33
# spdr sell date 2019-09-03
# spdr sell price $290.74

# %% [markdown]
# ## Calculation of SPDR S&P 500 ETF Holding Period Return (Long and Short)

# %%
# calculate holding period return for a unit of SPDR S&P 500 ETF (i.e. one stock of the ETF)
# the return for a long position and short position will be calculated
# note: the return be stored in a new column in stock_price_df

# create long holding period return column in stock_price_df
stock_price_df['SPDR_Long_Holding_Period_Return_(%)'] = 0
# create short holding period return column in stock_price_df
stock_price_df['SPDR_Short_Holding_Period_Return_(%)'] = 0
# calculate SPDR_Long_Holding_Period_Return_(%) and SPDR_Short_Holding_Period_Return_(%)
# note: long holding period return return = (stock sell price / stock purchase price) - 1
# note: short holding period return = (stock purchase price / stock sell price) - 1
# check if SPDR_Purchase_Price and SPDR_Sell_Price are not equal to 'N/A'
# if SPDR_Purchase_Price and SPDR_Sell_Price are equal to 'N/A', set long holding period return and short holding period return to 'N/A'
# otherwise long holding period return and short holding period return equals that of the prvious formulas above
for idx, row in stock_price_df.iterrows():
    if (row['SPDR_Purchase_Price']=='N/A') & (row['SPDR_Sell_Price']=='N/A'):
        stock_price_df.loc[idx, 'SPDR_Long_Holding_Period_Return_(%)'] = 'N/A'
        stock_price_df.loc[idx, 'SPDR_Short_Holding_Period_Return_(%)'] = 'N/A'
    else:
        stock_price_df.loc[idx, 'SPDR_Long_Holding_Period_Return_(%)'] = (row['SPDR_Sell_Price'] / row['SPDR_Purchase_Price']) - 1
        stock_price_df.loc[idx, 'SPDR_Short_Holding_Period_Return_(%)'] = (row['SPDR_Purchase_Price'] / row['SPDR_Sell_Price']) - 1

# %% [markdown]
# ## Calculation of SPDR S&P 500 ETF Annualized Holding Period Returns

# %%
# create new column to store spdr long annualized holding period returns
stock_price_df['SPDR_Long_Annualized_Holding_Period_Return_(%)'] = ''
# create new column to store spdr short annualized holding period returns
stock_price_df['SPDR_Short_Annualized_Holding_Period_Return_(%)'] = ''

for idx, row in stock_price_df.iterrows():
    if row['SPDR_Long_Holding_Period_Return_(%)']=='N/A' and row['SPDR_Short_Holding_Period_Return_(%)']=='N/A':
        stock_price_df.loc[idx, 'SPDR_Long_Annualized_Holding_Period_Return_(%)'] = 'N/A'
        stock_price_df.loc[idx, 'SPDR_Short_Annualized_Holding_Period_Return_(%)'] = 'N/A'
    else:
        purchase_date = datetime.strptime(stock_price_df.loc[idx, 'Purchase_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d')
        sell_date = datetime.strptime(stock_price_df.loc[idx, 'Sell_Date'].strftime('%Y-%m-%d'), '%Y-%m-%d')
        holding_days = (sell_date - purchase_date).days
        stock_price_df.loc[idx, 'SPDR_Long_Annualized_Holding_Period_Return_(%)'] = ((1 + row['SPDR_Long_Holding_Period_Return_(%)'])**(365/holding_days) - 1)
        stock_price_df.loc[idx, 'SPDR_Short_Annualized_Holding_Period_Return_(%)'] = ((1 + row['SPDR_Short_Holding_Period_Return_(%)'])**(365/holding_days) - 1)

# %% [markdown]
# ## Calculation of Excess Returns (Long and Short)

# %%
# note: excess return is a measure against the performance of stocks and a given benchmark (i.e. the spdr s&p 500 etf)
# note: in simple terms excess return = stock return - benchmark return 
# note: the product of excess returns is known as alpha
# note: to calculate excess returns, the annualized returns will be used

# create new column to store long (annualized) excess returns in stock_price_df
stock_price_df['Long_Excess_Returns_(%)'] = 0
# create new column to store short (annualized) excess returns in stock_price_df
stock_price_df['Short_Excess_Returns_(%)'] = 0


for idx, row in stock_price_df.iterrows():
    if row['Stock_Purchase_Price']=='N/A' and row['Stock_Sell_Price']=='N/A':
        stock_price_df.loc[idx, 'Long_Excess_Returns_(%)'] = 'N/A'
        stock_price_df.loc[idx, 'Short_Excess_Returns_(%)'] = 'N/A'
    else:
        stock_price_df.loc[idx, 'Long_Excess_Returns_(%)'] = row['Long_Annualized_Holding_Period_Return_(%)'] - \
                                                                row['SPDR_Long_Annualized_Holding_Period_Return_(%)']
        stock_price_df.loc[idx, 'Short_Excess_Returns_(%)'] = row['Short_Annualized_Holding_Period_Return_(%)'] - \
                                                                row['SPDR_Short_Annualized_Holding_Period_Return_(%)']

# %% [markdown]
# ## Portfolio Analysis

# %%
# note: various portfolio formations will be analyzed to identify the best combination of stocks
# note: a function will be defined to calculate various statistics of the various portfolios

def portfolio_analysis_statistics(portfolio_df):
    # mean of returns
    average_long_hpr = portfolio_df['Long_Holding_Period_Return_(%)'].mean()
    average_short_hpr = portfolio_df['Short_Holding_Period_Return_(%)'].mean()
    average_long_annaulized_hpr = portfolio_df['Long_Annualized_Holding_Period_Return_(%)'].mean()
    average_short_annaulized_hpr = portfolio_df['Short_Annualized_Holding_Period_Return_(%)'].mean()
    average_long_excess_returns = portfolio_df['Long_Excess_Returns_(%)'].mean()
    average_short_excess_returns = portfolio_df['Short_Excess_Returns_(%)'].mean()
    # median returns
    median_long_hpr = portfolio_df['Long_Holding_Period_Return_(%)'].median()
    median_short_hpr = portfolio_df['Short_Holding_Period_Return_(%)'].median()
    median_long_annaulized_hpr = portfolio_df['Long_Annualized_Holding_Period_Return_(%)'].median()
    median_short_annaulized_hpr = portfolio_df['Short_Annualized_Holding_Period_Return_(%)'].median()
    median_long_excess_returns = portfolio_df['Long_Excess_Returns_(%)'].median()
    median_short_excess_returns = portfolio_df['Short_Excess_Returns_(%)'].median()
    # 10th percentile returns
    percentile_10_long_hpr = portfolio_df['Long_Holding_Period_Return_(%)'].quantile(0.1)
    percentile_10_short_hpr = portfolio_df['Short_Holding_Period_Return_(%)'].quantile(0.1)
    percentile_10_long_annaulized_hpr = portfolio_df['Long_Annualized_Holding_Period_Return_(%)'].quantile(0.1)
    percentile_10_short_annaulized_hpr = portfolio_df['Short_Annualized_Holding_Period_Return_(%)'].quantile(0.1)
    percentile_10_long_excess_returns = portfolio_df['Long_Excess_Returns_(%)'].quantile(0.1)
    percentile_10_short_excess_returns = portfolio_df['Short_Excess_Returns_(%)'].quantile(0.1)
    # 25th percentile returns 
    percentile_25_long_hpr = portfolio_df['Long_Holding_Period_Return_(%)'].quantile(0.25)
    percentile_25_short_hpr = portfolio_df['Short_Holding_Period_Return_(%)'].quantile(0.25)
    percentile_25_long_annaulized_hpr = portfolio_df['Long_Annualized_Holding_Period_Return_(%)'].quantile(0.25)
    percentile_25_short_annaulized_hpr = portfolio_df['Short_Annualized_Holding_Period_Return_(%)'].quantile(0.25)
    percentile_25_long_excess_returns = portfolio_df['Long_Excess_Returns_(%)'].quantile(0.25)
    percentile_25_short_excess_returns = portfolio_df['Short_Excess_Returns_(%)'].quantile(0.25)
    # 75th percentile returns
    percentile_75_long_hpr = portfolio_df['Long_Holding_Period_Return_(%)'].quantile(0.75)
    percentile_75_short_hpr = portfolio_df['Short_Holding_Period_Return_(%)'].quantile(0.75)
    percentile_75_long_annaulized_hpr = portfolio_df['Long_Annualized_Holding_Period_Return_(%)'].quantile(0.75)
    percentile_75_short_annaulized_hpr = portfolio_df['Short_Annualized_Holding_Period_Return_(%)'].quantile(0.75)
    percentile_75_long_excess_returns = portfolio_df['Long_Excess_Returns_(%)'].quantile(0.75)
    percentile_75_short_excess_returns = portfolio_df['Short_Excess_Returns_(%)'].quantile(0.75)
    # 90th percentile returns
    percentile_90_long_hpr = portfolio_df['Long_Holding_Period_Return_(%)'].quantile(0.9)
    percentile_90_short_hpr = portfolio_df['Short_Holding_Period_Return_(%)'].quantile(0.9)
    percentile_90_long_annaulized_hpr = portfolio_df['Long_Annualized_Holding_Period_Return_(%)'].quantile(0.9)
    percentile_90_short_annaulized_hpr = portfolio_df['Short_Annualized_Holding_Period_Return_(%)'].quantile(0.9)
    percentile_90_long_excess_returns = portfolio_df['Long_Excess_Returns_(%)'].quantile(0.9)
    percentile_90_short_excess_returns = portfolio_df['Short_Excess_Returns_(%)'].quantile(0.9)

    print('number of observations:', portfolio_df.shape[0])
    print('\n')
    print('--------------------------------------------------------------------------------')
    print('mean returns')
    print('--------------------------------------------------------------------------------')
    print('long holding period return:', round((average_long_hpr), 3))
    print('short holding period return:', round((average_short_hpr), 3))
    print('long annualized holding period return:', round((average_long_annaulized_hpr), 3))
    print('short annualized holding period return:', round((average_short_annaulized_hpr), 3))
    print('long excess return:', round((average_long_excess_returns), 3))
    print('short excess return:', round((average_short_excess_returns), 3))
    print('\n')
    print('--------------------------------------------------------------------------------')
    print('median returns')
    print('--------------------------------------------------------------------------------')
    print('long holding period return:', round((median_long_hpr), 3))
    print('short holding period return:', round((median_short_hpr), 3))
    print('long annualized holding period return:', round((median_long_annaulized_hpr), 3))
    print('short annualized holding period return:', round((median_short_annaulized_hpr), 3))
    print('long excess return:', round((median_long_excess_returns), 3))
    print('short excess return:', round((median_short_excess_returns), 3))
    print('\n')
    print('--------------------------------------------------------------------------------')
    print('10th percentile returns')
    print('--------------------------------------------------------------------------------')
    print('long holding period return:', round((percentile_10_long_hpr), 3))
    print('short holding period return:', round((percentile_10_short_hpr), 3))
    print('long annualized holding period return:', round((percentile_10_long_annaulized_hpr), 3))
    print('short annualized holding period return:', round((percentile_10_short_annaulized_hpr), 3))
    print('long excess return:', round((percentile_10_long_excess_returns), 3))
    print('short excess return:', round((percentile_10_short_excess_returns), 3))
    print('\n')
    print('--------------------------------------------------------------------------------')
    print('25th percentile returns')
    print('--------------------------------------------------------------------------------')
    print('long holding period return:', round((percentile_25_long_hpr), 3))
    print('short holding period return:', round((percentile_25_short_hpr), 3))
    print('long annualized holding period return:', round((percentile_25_long_annaulized_hpr), 3))
    print('short annualized holding period return:', round((percentile_25_short_annaulized_hpr), 3))
    print('long excess return:', round((percentile_25_long_excess_returns), 3))
    print('short excess return:', round((percentile_25_short_excess_returns), 3))
    print('\n')
    print('--------------------------------------------------------------------------------')
    print('75th percentile returns')
    print('--------------------------------------------------------------------------------')
    print('long holding period return:', round((percentile_75_long_hpr), 3))
    print('short holding period return:', round((percentile_75_short_hpr), 3))
    print('long annualized holding period return:', round((percentile_75_long_annaulized_hpr), 3))
    print('short annualized holding period return:', round((percentile_75_short_annaulized_hpr), 3))
    print('long excess return:', round((percentile_75_long_excess_returns), 3))
    print('short excess return:', round((percentile_75_short_excess_returns), 3))
    print('\n')
    print('--------------------------------------------------------------------------------')
    print('90th percentile returns')
    print('--------------------------------------------------------------------------------')
    print('long holding period return:', round((percentile_90_long_hpr), 3))
    print('short holding period return:', round((percentile_90_short_hpr), 3))
    print('long annualized holding period return:', round((percentile_90_long_annaulized_hpr), 3))
    print('short annualized holding period return:', round((percentile_90_short_annaulized_hpr), 3))
    print('long excess return:', round((percentile_90_long_excess_returns), 3))
    print('short excess return:', round((percentile_90_short_excess_returns), 3))
    print('\n')
    return None

# %%
# # high book-to-market portfolio

# replace 'N/A' values with nan in stock_price_df
stock_price_df = stock_price_df.replace('N/A', np.nan)

print('HIGH BOOK-TO-MARKET PORTFOLIO (ALL F-SCORES)')
print('\n')
portfolio_analysis_statistics(stock_price_df.dropna())
# Out:
# HIGH BOOK-TO-MARKET PORTFOLIO (ALL F-SCORES)
#
#
# number of observations: 1453
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.234
# short holding period return: 0.353
# long annualized holding period return: 1013.957
# short annualized holding period return: 0.845
# long excess return: 1013.853
# short excess return: 0.935
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: -0.012
# short holding period return: 0.013
# long annualized holding period return: -0.015
# short annualized holding period return: 0.015
# long excess return: -0.118
# short excess return: 0.103
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.499
# short holding period return: -0.375
# long annualized holding period return: -0.618
# short annualized holding period return: -0.399
# long excess return: -0.687
# short excess return: -0.3
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.268
# short holding period return: -0.196
# long annualized holding period return: -0.327
# short annualized holding period return: -0.211
# long excess return: -0.412
# short excess return: -0.105
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.245
# short holding period return: 0.366
# long annualized holding period return: 0.267
# short annualized holding period return: 0.486
# long excess return: 0.14
# short excess return: 0.568
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.6
# short holding period return: 0.995
# long annualized holding period return: 0.665
# short annualized holding period return: 1.616
# long excess return: 0.578
# short excess return: 1.681

# %%
# F-SCORE = 0 portfolio 
print('F-SCORE = 0 PORTFOLIO')
print('\n')
portfolio_analysis_statistics(stock_price_df.loc[stock_price_df['F_SCORE']==0])
# Out:
# F-SCORE = 0 PORTFOLIO
#
#
# number of observations: 1
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: -0.298
# short holding period return: 0.425
# long annualized holding period return: -0.298
# short annualized holding period return: 0.425
# long excess return: -0.404
# short excess return: 0.521
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: -0.298
# short holding period return: 0.425
# long annualized holding period return: -0.298
# short annualized holding period return: 0.425
# long excess return: -0.404
# short excess return: 0.521
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.298
# short holding period return: 0.425
# long annualized holding period return: -0.298
# short annualized holding period return: 0.425
# long excess return: -0.404
# short excess return: 0.521
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.298
# short holding period return: 0.425
# long annualized holding period return: -0.298
# short annualized holding period return: 0.425
# long excess return: -0.404
# short excess return: 0.521
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.298
# short holding period return: 0.425
# long annualized holding period return: -0.298
# short annualized holding period return: 0.425
# long excess return: -0.404
# short excess return: 0.521
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.298
# short holding period return: 0.425
# long annualized holding period return: -0.298
# short annualized holding period return: 0.425
# long excess return: -0.404
# short excess return: 0.521

# %%
# F-SCORE = 1 portfolio 
print('F-SCORE = 1 PORTFOLIO')
print('\n')
portfolio_analysis_statistics(stock_price_df.loc[stock_price_df['F_SCORE']==1])
# Out:
# F-SCORE = 1 PORTFOLIO
#
#
# number of observations: 7
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: -0.03
# short holding period return: 0.685
# long annualized holding period return: -0.13
# short annualized holding period return: 1.026
# long excess return: -0.214
# short excess return: 1.1
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: -0.105
# short holding period return: 0.117
# long annualized holding period return: -0.342
# short annualized holding period return: 0.521
# long excess return: -0.447
# short excess return: 0.635
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.576
# short holding period return: -0.379
# long annualized holding period return: -0.744
# short annualized holding period return: -0.379
# long excess return: -0.815
# short excess return: -0.246
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.383
# short holding period return: -0.112
# long annualized holding period return: -0.572
# short annualized holding period return: -0.065
# long excess return: -0.61
# short excess return: 0.019
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.168
# short holding period return: 0.627
# long annualized holding period return: 0.129
# short annualized holding period return: 1.571
# long excess return: 0.029
# short excess return: 1.596
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.684
# short holding period return: 2.111
# long annualized holding period return: 0.684
# short annualized holding period return: 3.081
# long excess return: 0.527
# short excess return: 3.147

# %%
# F-SCORE = 2 portfolio 
print('F-SCORE = 2 PORTFOLIO')
print('\n')
portfolio_analysis_statistics(stock_price_df.loc[stock_price_df['F_SCORE']==2])
# Out:
# F-SCORE = 2 PORTFOLIO
#
#
# number of observations: 70
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.338
# short holding period return: 0.241
# long annualized holding period return: 0.713
# short annualized holding period return: 0.794
# long excess return: 0.623
# short excess return: 0.872
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: 0.037
# short holding period return: -0.036
# long annualized holding period return: 0.037
# short annualized holding period return: -0.036
# long excess return: -0.045
# short excess return: 0.041
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.52
# short holding period return: -0.461
# long annualized holding period return: -0.64
# short annualized holding period return: -0.522
# long excess return: -0.726
# short excess return: -0.401
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.285
# short holding period return: -0.23
# long annualized holding period return: -0.29
# short annualized holding period return: -0.276
# long excess return: -0.405
# short excess return: -0.185
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.299
# short holding period return: 0.399
# long annualized holding period return: 0.383
# short annualized holding period return: 0.408
# long excess return: 0.267
# short excess return: 0.496
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.857
# short holding period return: 1.084
# long annualized holding period return: 1.096
# short annualized holding period return: 1.778
# long excess return: 0.934
# short excess return: 1.859

# %%
# F-SCORE = 3 portfolio 
print('F-SCORE = 3 PORTFOLIO')
print('\n')
portfolio_analysis_statistics(stock_price_df.loc[stock_price_df['F_SCORE']==3])
# Out:
# F-SCORE = 3 PORTFOLIO
#
#
# number of observations: 184
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.448
# short holding period return: 0.713
# long annualized holding period return: 3.601
# short annualized holding period return: 1.106
# long excess return: 3.471
# short excess return: 1.214
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: 0.052
# short holding period return: -0.049
# long annualized holding period return: 0.052
# short annualized holding period return: -0.049
# long excess return: -0.118
# short excess return: 0.092
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.545
# short holding period return: -0.513
# long annualized holding period return: -0.674
# short annualized holding period return: -0.538
# long excess return: -0.73
# short excess return: -0.403
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.319
# short holding period return: -0.273
# long annualized holding period return: -0.343
# short annualized holding period return: -0.299
# long excess return: -0.476
# short excess return: -0.194
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.376
# short holding period return: 0.469
# long annualized holding period return: 0.427
# short annualized holding period return: 0.522
# long excess return: 0.317
# short excess return: 0.617
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 1.052
# short holding period return: 1.197
# long annualized holding period return: 1.164
# short annualized holding period return: 2.064
# long excess return: 1.016
# short excess return: 2.134

# %%
# F-SCORE = 4 portfolio 
print('F-SCORE = 4 PORTFOLIO')
print('\n')
portfolio_analysis_statistics(stock_price_df.loc[stock_price_df['F_SCORE']==4])
# Out:
# F-SCORE = 4 PORTFOLIO
#
#
# number of observations: 300
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.324
# short holding period return: 0.407
# long annualized holding period return: 4907.234
# short annualized holding period return: 1.273
# long excess return: 4907.126
# short excess return: 1.366
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: -0.028
# short holding period return: 0.029
# long annualized holding period return: -0.035
# short annualized holding period return: 0.037
# long excess return: -0.131
# short excess return: 0.122
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.546
# short holding period return: -0.446
# long annualized holding period return: -0.695
# short annualized holding period return: -0.465
# long excess return: -0.765
# short excess return: -0.318
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.325
# short holding period return: -0.212
# long annualized holding period return: -0.4
# short annualized holding period return: -0.237
# long excess return: -0.46
# short excess return: -0.117
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.269
# short holding period return: 0.481
# long annualized holding period return: 0.31
# short annualized holding period return: 0.666
# long excess return: 0.16
# short excess return: 0.736
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.805
# short holding period return: 1.201
# long annualized holding period return: 0.87
# short annualized holding period return: 2.283
# long excess return: 0.673
# short excess return: 2.357

# %%
# F-SCORE = 5 portfolio 
print('F-SCORE = 5 PORTFOLIO')
print('\n')
portfolio_analysis_statistics(stock_price_df.loc[stock_price_df['F_SCORE']==5])
# Out:
# F-SCORE = 5 PORTFOLIO
#
#
# number of observations: 354
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.221
# short holding period return: 0.212
# long annualized holding period return: 0.997
# short annualized holding period return: 0.601
# long excess return: 0.894
# short excess return: 0.689
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: 0.0
# short holding period return: -0.0
# long annualized holding period return: 0.0
# short annualized holding period return: -0.0
# long excess return: -0.1
# short excess return: 0.089
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.478
# short holding period return: -0.357
# long annualized holding period return: -0.556
# short annualized holding period return: -0.363
# long excess return: -0.61
# short excess return: -0.265
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.232
# short holding period return: -0.186
# long annualized holding period return: -0.27
# short annualized holding period return: -0.2
# long excess return: -0.365
# short excess return: -0.093
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.228
# short holding period return: 0.302
# long annualized holding period return: 0.251
# short annualized holding period return: 0.37
# long excess return: 0.119
# short excess return: 0.45
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.556
# short holding period return: 0.917
# long annualized holding period return: 0.569
# short annualized holding period return: 1.259
# long excess return: 0.449
# short excess return: 1.286

# %%
# F-SCORE = 6 portfolio 
print('F-SCORE = 6 PORTFOLIO')
print('\n')
portfolio_analysis_statistics(stock_price_df.loc[stock_price_df['F_SCORE']==6])
# Out:
# F-SCORE = 6 PORTFOLIO
#
#
# number of observations: 285
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.203
# short holding period return: 0.38
# long annualized holding period return: 0.195
# short annualized holding period return: 0.646
# long excess return: 0.102
# short excess return: 0.727
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: 0.002
# short holding period return: -0.002
# long annualized holding period return: 0.002
# short annualized holding period return: -0.002
# long excess return: -0.094
# short excess return: 0.078
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.511
# short holding period return: -0.305
# long annualized holding period return: -0.569
# short annualized holding period return: -0.363
# long excess return: -0.646
# short excess return: -0.229
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.244
# short holding period return: -0.172
# long annualized holding period return: -0.289
# short annualized holding period return: -0.202
# long excess return: -0.361
# short excess return: -0.099
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.207
# short holding period return: 0.324
# long annualized holding period return: 0.253
# short annualized holding period return: 0.406
# long excess return: 0.136
# short excess return: 0.501
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.44
# short holding period return: 1.047
# long annualized holding period return: 0.569
# short annualized holding period return: 1.321
# long excess return: 0.375
# short excess return: 1.405

# %%
# F-SCORE = 7 portfolio 
print('F-SCORE = 7 PORTFOLIO')
print('\n')
portfolio_analysis_statistics(stock_price_df.loc[stock_price_df['F_SCORE']==7])
# Out:
# F-SCORE = 7 PORTFOLIO
#
#
# number of observations: 175
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.012
# short holding period return: 0.244
# long annualized holding period return: -0.023
# short annualized holding period return: 0.936
# long excess return: -0.126
# short excess return: 1.024
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: -0.063
# short holding period return: 0.067
# long annualized holding period return: -0.081
# short annualized holding period return: 0.089
# long excess return: -0.188
# short excess return: 0.186
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.445
# short holding period return: -0.329
# long annualized holding period return: -0.631
# short annualized holding period return: -0.365
# long excess return: -0.684
# short excess return: -0.233
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.254
# short holding period return: -0.155
# long annualized holding period return: -0.369
# short annualized holding period return: -0.157
# long excess return: -0.434
# short excess return: -0.043
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.184
# short holding period return: 0.341
# long annualized holding period return: 0.186
# short annualized holding period return: 0.585
# long excess return: 0.064
# short excess return: 0.627
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.491
# short holding period return: 0.801
# long annualized holding period return: 0.576
# short annualized holding period return: 1.71
# long excess return: 0.408
# short excess return: 1.776

# %%
# F-SCORE = 8 portfolio 
print('F-SCORE = 8 PORTFOLIO')
print('\n')
portfolio_analysis_statistics(stock_price_df.loc[stock_price_df['F_SCORE']==8])
# Out:
# F-SCORE = 8 PORTFOLIO
#
#
# number of observations: 70
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: -0.032
# short holding period return: 0.178
# long annualized holding period return: -0.061
# short annualized holding period return: 0.309
# long excess return: -0.151
# short excess return: 0.389
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: -0.061
# short holding period return: 0.065
# long annualized holding period return: -0.067
# short annualized holding period return: 0.072
# long excess return: -0.16
# short excess return: 0.178
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.37
# short holding period return: -0.257
# long annualized holding period return: -0.525
# short annualized holding period return: -0.274
# long excess return: -0.602
# short excess return: -0.184
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.214
# short holding period return: -0.162
# long annualized holding period return: -0.284
# short annualized holding period return: -0.17
# long excess return: -0.362
# short excess return: -0.067
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.194
# short holding period return: 0.272
# long annualized holding period return: 0.205
# short annualized holding period return: 0.397
# long excess return: 0.085
# short excess return: 0.477
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.346
# short holding period return: 0.588
# long annualized holding period return: 0.378
# short annualized holding period return: 1.105
# long excess return: 0.282
# short excess return: 1.177

# %%
# F-SCORE = 9 portfolio 
print('F-SCORE = 9 PORTFOLIO')
print('\n')
portfolio_analysis_statistics(stock_price_df.loc[stock_price_df['F_SCORE']==9])
# Out:
# F-SCORE = 9 PORTFOLIO
#
#
# number of observations: 9
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.118
# short holding period return: -0.021
# long annualized holding period return: 0.149
# short annualized holding period return: -0.038
# long excess return: 0.001
# short excess return: 0.089
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: 0.228
# short holding period return: -0.185
# long annualized holding period return: 0.228
# short annualized holding period return: -0.185
# long excess return: 0.099
# short excess return: -0.072
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.186
# short holding period return: -0.27
# long annualized holding period return: -0.186
# short annualized holding period return: -0.288
# long excess return: -0.302
# short excess return: -0.136
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.033
# short holding period return: -0.229
# long annualized holding period return: -0.033
# short annualized holding period return: -0.269
# long excess return: -0.156
# short excess return: -0.097
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.298
# short holding period return: 0.034
# long annualized holding period return: 0.367
# short annualized holding period return: 0.034
# long excess return: 0.156
# short excess return: 0.144
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.37
# short holding period return: 0.29
# long annualized holding period return: 0.405
# short annualized holding period return: 0.29
# long excess return: 0.216
# short excess return: 0.394

# %%
# high F-SCORE portfolio (F_SCORE of 8 or 9)
print('HIGH F-SCORE PORTFOLIO (F-SCORE = 8 and F-SCORE = 9)')
print('\n')
portfolio_analysis_statistics(stock_price_df.loc[(stock_price_df['F_SCORE']==8) | (stock_price_df['F_SCORE']==9)])
# Out:
# HIGH F-SCORE PORTFOLIO (F-SCORE = 8 and F-SCORE = 9)
#
#
# number of observations: 79
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: -0.015
# short holding period return: 0.155
# long annualized holding period return: -0.037
# short annualized holding period return: 0.269
# long excess return: -0.134
# short excess return: 0.355
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: -0.036
# short holding period return: 0.037
# long annualized holding period return: -0.036
# short annualized holding period return: 0.037
# long excess return: -0.149
# short excess return: 0.144
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.373
# short holding period return: -0.267
# long annualized holding period return: -0.503
# short annualized holding period return: -0.276
# long excess return: -0.609
# short excess return: -0.184
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.213
# short holding period return: -0.183
# long annualized holding period return: -0.276
# short annualized holding period return: -0.188
# long excess return: -0.35
# short excess return: -0.071
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.223
# short holding period return: 0.27
# long annualized holding period return: 0.231
# short annualized holding period return: 0.381
# long excess return: 0.1
# short excess return: 0.43
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.363
# short holding period return: 0.596
# long annualized holding period return: 0.382
# short annualized holding period return: 1.013
# long excess return: 0.282
# short excess return: 1.127

# %%
# low F-SCORE portfolio (F_SCORE of 0 or 1)
print('LOW F-SCORE PORTFOLIO (F-SCORE = 0 and F-SCORE = 1)')
print('\n')
portfolio_analysis_statistics(stock_price_df.loc[(stock_price_df['F_SCORE']==0) | (stock_price_df['F_SCORE']==1)])
# Out:
# LOW F-SCORE PORTFOLIO (F-SCORE = 0 and F-SCORE = 1)
#
#
# number of observations: 8
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: -0.064
# short holding period return: 0.652
# long annualized holding period return: -0.151
# short annualized holding period return: 0.951
# long excess return: -0.237
# short excess return: 1.028
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: -0.201
# short holding period return: 0.271
# long annualized holding period return: -0.32
# short annualized holding period return: 0.473
# long excess return: -0.426
# short excess return: 0.578
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.538
# short holding period return: -0.354
# long annualized holding period return: -0.733
# short annualized holding period return: -0.354
# long excess return: -0.799
# short excess return: -0.213
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.363
# short holding period return: -0.029
# long annualized holding period return: -0.507
# short annualized holding period return: 0.042
# long excess return: -0.541
# short excess return: 0.087
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.058
# short holding period return: 0.574
# long annualized holding period return: -0.0
# short annualized holding period return: 1.182
# long excess return: -0.053
# short excess return: 1.197
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.609
# short holding period return: 1.767
# long annualized holding period return: 0.609
# short annualized holding period return: 2.898
# long excess return: 0.444
# short excess return: 2.959

# %%
# go long on high F-SCORE portfolio and short low F-SCORE portfolio
high_low_f_score_portfolio_df = stock_price_df.loc[(stock_price_df['F_SCORE']<2) | (stock_price_df['F_SCORE']>7)]

# define variables to store returns
hpr = 0
annualized_hpr = 0
excess_return = 0

for idx, row in high_low_f_score_portfolio_df.iterrows():
    if row['F_SCORE']==0 or row['F_SCORE']==1:
        hpr = hpr + row['Short_Holding_Period_Return_(%)']
        annualized_hpr = annualized_hpr + row['Short_Annualized_Holding_Period_Return_(%)']
        excess_return = excess_return + row['Short_Excess_Returns_(%)']        
    else:
        hpr = hpr + row['Long_Holding_Period_Return_(%)']
        annualized_hpr = annualized_hpr + row['Long_Annualized_Holding_Period_Return_(%)']
        excess_return = excess_return + row['Long_Excess_Returns_(%)']    

# calculate averages of returns
average_hpr = hpr / high_low_f_score_portfolio_df.shape[0]
average_annualized_hpr = annualized_hpr / high_low_f_score_portfolio_df.shape[0]
average_excess_return = excess_return / high_low_f_score_portfolio_df.shape[0]

print('LONG HIGH F-SCORE PORTFOLIO (F-SCORE = 8 and F-SCORE = 9) and SHORT LOW F-SCORE PORTFOLIO (F-SCORE = 0 and F-SCORE = 1)')
print('\n')
print('---------------------------------------------------------------------------------------')
print('average holding period return:', round(average_hpr, 3))
print('average annaulized holding period return:', round(average_annualized_hpr, 3))
print('average excess return:', round(average_excess_return, 3))
# Out:
# LONG HIGH F-SCORE PORTFOLIO (F-SCORE = 8 and F-SCORE = 9) and SHORT LOW F-SCORE PORTFOLIO (F-SCORE = 0 and F-SCORE = 1)
#
#
# ---------------------------------------------------------------------------------------
# average holding period return: 0.046
# average annaulized holding period return: 0.054
# average excess return: -0.027

# %%
# all b/m companies returns without outlier
stock_price_no_outlier_df = stock_price_df.loc[stock_price_df['Long_Annualized_Holding_Period_Return_(%)']!=1472071.0572556225]
print('HIGH BOOK-TO-MARKET PORTFOLIO EXCLUDING OUTLIER (ALL F-SCORES)')
print('\n')
portfolio_analysis_statistics(stock_price_no_outlier_df.dropna())
# Out:
# HIGH BOOK-TO-MARKET PORTFOLIO EXCLUDING OUTLIER (ALL F-SCORES)
#
#
# number of observations: 1452
#
#
# --------------------------------------------------------------------------------
# mean returns
# --------------------------------------------------------------------------------
# long holding period return: 0.234
# short holding period return: 0.353
# long annualized holding period return: 0.832
# short annualized holding period return: 0.847
# long excess return: 0.728
# short excess return: 0.936
#
#
# --------------------------------------------------------------------------------
# median returns
# --------------------------------------------------------------------------------
# long holding period return: -0.013
# short holding period return: 0.013
# long annualized holding period return: -0.015
# short annualized holding period return: 0.015
# long excess return: -0.118
# short excess return: 0.103
#
#
# --------------------------------------------------------------------------------
# 10th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.499
# short holding period return: -0.375
# long annualized holding period return: -0.618
# short annualized holding period return: -0.398
# long excess return: -0.687
# short excess return: -0.292
#
#
# --------------------------------------------------------------------------------
# 25th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: -0.268
# short holding period return: -0.195
# long annualized holding period return: -0.327
# short annualized holding period return: -0.21
# long excess return: -0.413
# short excess return: -0.104
#
#
# --------------------------------------------------------------------------------
# 75th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.243
# short holding period return: 0.366
# long annualized holding period return: 0.266
# short annualized holding period return: 0.487
# long excess return: 0.139
# short excess return: 0.569
#
#
# --------------------------------------------------------------------------------
# 90th percentile returns
# --------------------------------------------------------------------------------
# long holding period return: 0.6
# short holding period return: 0.995
# long annualized holding period return: 0.661
# short annualized holding period return: 1.617
# long excess return: 0.576
# short excess return: 1.681

# %% [markdown]
# ## Save stock_price_df to CSV File

# %%
# save stock_price_df to csv file
stock_price_df.to_csv('stock_price_df.csv', index=False)

# %% [markdown]
# ## Close WRDS Data Connection

# %%
# close connection to wrds
db.close()
